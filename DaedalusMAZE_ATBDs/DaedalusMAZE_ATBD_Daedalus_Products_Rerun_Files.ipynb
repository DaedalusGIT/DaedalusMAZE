# %% [markdown]
# # Daedalus Derived Product Estimations Based on GCMs
#
# ### Table of Contents
# * [Table of all Derived Products](#Table_Products)
# * [Descriptions of Derived Products](#Descriptions)
# * [Code Description](#Code)
#
# ### Table of all Derived Products
# <a class="anchor" id="Table_Products"></a>
#
#  <p style='text-align: justify;'>
# The following derived products, which involve the output from more than one instruments or other significant processing of raw instrument data, will be calculated by Daedalus:
#
#
# |A/A|**List of Derived Products**|Symbolic Description (not actually <br> used formulas) | Corresponding Section in <br> DAED_Ph0Sc01_D1|
# |---|:---|:---:|---|
# |**1**|**..........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |1.a|Joule Heating $q_{j}$  |$ q_{j}=\vec{j}·(\vec{E}+ \vec{u_{n}}⨯\vec{B}) $|(4.1.2.3)
# |1.b| Ohmic Heating $q_{Ω}$ |$ q_{Ω} = \sigma_{P}  | \vec{E}+ \vec{u_{n}}⨯ \vec{B} | ^{2} $|(4.1.2.4)
# |1.c|Frictional Heating ($q_{f}$) |$ q_{f} =m_{i} ν_{in} N_{e} |v_{i} - u_{n}|^{2}$|(4.1.2.5)
# |1.d|Poynting Vector ($S$) <br> in the neutral gas frame|$ \vec{S} =(\vec{E}+ \vec{u_{n}}⨯ \vec{B})×∆\vec{B}/μ_{0}$|
# |**2**|**..........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |2.a|In-situ current density $j$|$ \vec{j} $|
# |2.b|Magnetic Forcing (MF)|$ \vec{j}× \vec{B} $| (4.1.3)
# |2.c|Field Aligned Currents (FAC)| $\Delta\vec{B}/(μ_{0}\Delta x)$|(4.1.9)
# |**3**|**..........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |3.a|Conductivities|$σ_{P}$, $σ_{H}$, $σ_{ǁ}$|(4.1.4)
# |3.b|Ion-Neutral Cross Sections|$σ_{in}$|(4.1.5)
# |3.c|Ion-Neutral Collision Frequencies |$\nu_{in}$|(4.1.5)
# |**4**|**..........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |4.a|Heating by e- impact ionization (EI), <br> has this scientific meaning only in darkness.|$34eVaNe^{2}$|(4.1.6)
# |4.b|Heat transfer to the neutral <br> gas by ion and e- cooling (II)|C ($N_{e}$, $T_{i}$, $T_{e}$, $N_{n}$, $T_{n}$)|(4.1.7)
# |**5**|**...........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |5.a|Total Electron Content (TEC), slanted and vertical|$sTEC$, $vTEC$|(4.1.9)
# |**6**|**...........................................................................................**|**..........................................................................................**|**..........................................................................................**|
# |6.a|Gravity wave scales||
#
#
#
# ### Descriptions of Derived Products
# <a class="anchor" id="Descriptions"></a>
# <p style='text-align: justify;'>
#
# #### 1. Joule, Ohmic, Frictional heating and Poynting Flux
# <p style='text-align: justify;'>
# The first three derived products Joule, Ohmic, and Frictional heating, in this context designate three different methods to measure the same physical process, the local dissipation of energy in the magnetized, partially ionized upper atmosphere. Because Daedalus provides the complete set of neutral wind, ion drift and electric field vectors, plus the electron density and ion composition, there are actually three such methods to derive the dissipation (Joule heating) from the combined instrument data. The methods are expected to perform differently depending on altitude and instrument characterstics, therefore all three products will be derived.
# <p style='text-align: justify;'>
# Previously Sangalli et al. (2009) estimated heating rates from measurements obtained with the JOULE-II sounding rocket using a method similar to the first method above. Otherwise estimation of the electromagnetic energy transfer into the LTI with satellites resorted to deriving the Poynting vector at the satellite location above the LTI (described in several publications, e.g. Cosgrove et al., 2014). For Daedalus the Poynting vector is of course also provided, and this will complement the Joule heating products particularly when the satellite is above about 150 km height. The three methods to derive heating rates and the Poynting vector address the science objective associated with the energetics of the LTI.
#
#
# #### 2. Magnetic Forcing
# <p style='text-align: justify;'>
# Related to energetics, but distinct from it, are questions of the dynamics and momentum balance in the LTI. The corresponding Daedalus derived product is the magnetic or j ⃗×B ⃗ force, sometimes also called Lorentz force or Magnetic Forcing.
#
# #### 3. Conductivities
# <p style='text-align: justify;'>
# Conductivities are widely used and needed parameters, for data assimilation methods and computer simulations, the analysis of electric fields, field-aligned currents (FACs) and their closure below the height where they are typically measured. The conductivities may be presented as a 3x3 tensor σ ⃡, with Ohm’s law written as j ⃗=σ ⃡∙E ⃗. However, the tensor contains only three distinct parameters, namely the Pedersen, Hall, and parallel conductivities σ_P, σ_H, and σ_ǁ, which will be provided as Daedalus derived products. The variability of conductivities stems mainly from that of the electron density N_e, but also the neutral density N_n, the magnetic field strength B and temperature dependent ion-neutral collisional cross sections σ_in enter the equations for σ_P, σ_H, and σ_ǁ.
#
# #### 4. Ion-neutral collisional cross sections and collision frequencies
# <p style='text-align: justify;'>
# Daedalus provides the measurements needed to derive Joule heating rates with a certain redundancy leading to the three different methods. Because all methods should give the same result, this allows to adjust the ion-neutral collisional cross sections σ_in and collision frequencies ν_in, which are needed in two of the methods, “Frictional” and “Ohmic” heating. σ_in and ν_in are normally taken from published tables, for example in the text book by Schunk and Nagy (2009). The values in these tables for σ_in typically originate from measurements in the laboratory, not always performed under the similar conditions as in the ionosphere (often at lower temperatures), and with measurement uncertainties. Daedalus offers the opportunity to update the values of these widely used cross sections. In a sense it repeats these laboratory measurements but under ionospheric conditions. In practice this will give results mainly near the peak of the Joule heating rate at about 120 km altitude, plus/minus about a scale height (≈9 km).
#
# #### 5. Heating by electron impact ionization
# <p style='text-align: justify;'>
# Ionization and recombination in the LTI produces heat (in addition to the Joule heating which is the main theme of the Daedalus mission). The main causes of the ionization are the global absorption of solar EUV radiation, wavelengths 10-120 nm, and the collisional impact of energetic particles, mainly electrons, from space at high latitudes. Under the condition that convection is negligible the local heat production can be estimated from the measured N_e using model values for the recombination coefficients (confirm Bates, 1988) and a representative number of the heat produced per ionization and recombination. Laboratory measurements have suggested that this number is about 34 eV for electron impact (Rees, 1989). Although unconfirmed one can assume that even in case of ionospheric ionization by EUV also roughly 34 eV of heat are dissipated. The Daedalus product can be compared and will complement measurements of the EUV flux (Kazachevskaya et al., 2004) and of the energetic electron particle flux on satellites above the LTI (including Daedalus itself), and the F10.7 at the ground, which is a proxy for the EUV flux.
#
# #### 6. Heat transfer to the neutral gas by ion and electron cooling
# <p style='text-align: justify;'>
# The friction between ions and neutrals as well as ionization results in different temperatures of ions, electrons and the neutral gas, and collisional heat transfer between these components. The rates can be derived from observed temperatures and collisional cross sections. Among other this product provides additional consistency checks for other products: the cooling rate of ions to neutrals should be roughly half of the Joule heating, and that of electrons to neutrals and ions should nearly match the heating estimate described in the previous section.
#
# #### 7. Field-aligned currents
# <p style='text-align: justify;'>
# Field-aligned currents are a standard product of satellites possessing a magnetometer, and methods to derive FACs are well established. Daedalus will adopt the single spacecraft method used for the corresponding Swarm products.
#
# #### 8. Total Electron Content (TEC)
# <p style='text-align: justify;'>
# The slanted and vertical TEC are standard products when GNSS signals are received.
#
# ### Code Description
# <a class="anchor" id="Code"></a>
#
# Two models were used in the following simulations, NCAR's  Thermosphere-Ionosphere- Electrodynamics General Circulation Model (TIE-GCM)[1] and International Geomagnetic Reference Field (IGRF12)[2]. <br>
#
# #### 1. Electric field
# <p style='text-align: justify;'>
#
# The component of the electric field perpendiculat to the magnetic field is derived from the ExB ion drifts, provided by TIE-GCM according to equation:
#
# $$\vec{E_{\bot }}=-\vec{v_{i}}x\vec{B}        \label{eq:E_field} \tag{1}$$
#
# the magnetic field vector $\vec{B}$ is derived from IGRF. Let us use star sympol to denote parameters expressed in the reference frames of the neutrals, and with the subscript $\bot$ denote the component perpendicular to the magnetic field. If there is a wind of velocity $\vec{u_{n}}$, the electric field in the neutral reference frame is expressed as:
#
# $$\vec{E^{*}}=\vec{E}+\vec{u_{n}}\times \vec{B}  \tag{2}$$
#
# #### 2. Gyrofrequencies
# <p style='text-align: justify;'>
#
# The gyrofrequencies of the electrons and the ions are calculated as:
#
# $$\Omega_{j}= \frac{eB}{m_{j}} \tag{3}$$
#
# where $j=e,O^{+},O_{2}^{+}$.
#
# #### 3. Collision frequencies
# <p style='text-align: justify;'>
#
# The next step is to calculate the ion-neutral $(\nu_{in})$ and electron-neutral $(\nu_{en})$ collision frequencies. The same formulas that are used in the TIE-GCM model internally were used in the simulations. The formulas are derived from Schunk and Nagy (2000)[3].
#
#
# $$\nu_{O_2^+-O}=2.31 \cdot 10^{-10} N_{O} \label{eq:VO2p_Ο} \tag{4}$$
# $$\nu_{O_2^+-O_2}=2.59 \cdot 10^{-11} N_{O_2} \sqrt{\frac{T_{i}}{2} + \frac{T_{n}}{2}} \left(- 0.073 \log_{10}{\left(\frac{T_{i}}{2} + \frac{T_{n}}{2} \right)} + 1\right)^{2}\label{eq:VO2p_Ο2} \tag{5}$$
# $$\nu_{O_2^+-N_2}=4.31 \cdot 10^{-10} N_{N_2}             \label{eq:VO2p_Ν2} \tag{6}$$
#
# $$\nu_{O^+-O}=3.67 \cdot 10^{-11} N_{O}  \sqrt{\frac{T_{i}}{2} + \frac{T_{n}}{2}} \left(- 0.064 \log_{10}{\left(\frac{T_{i}}{2} + \frac{T_{n}}{2} \right)} + 1\right)^{2} fb             \label{eq:VOp_Ο} \tag{7}$$
#
# $$\nu_{O^+-O_2}=6.64 \cdot 10^{-10} N_{O2}\label{eq:VOp_Ο2} \tag{8}$$
#
# $$\nu_{O^+-N_2}=6.82 \cdot 10^{-10} N_{N2}\label{eq:VOp_N2} \tag{9}$$
#
# $$\nu_{in}=\nu_{O_2^+-O}+\nu_{O_2^+-O_2}+\nu_{O_2^+-N_2}+\nu_{O^+-O}+\nu_{O^+-N_2}+\nu_{O^+-N_2} \tag{10}$$
#
# $$\nu_{en}=2.33 \cdot 10^{-11} N_{N_2} T_{e} \left(1 - 0.000121 T_{e}\right) + \\8.9 \cdot 10^{-11} N_{O} \sqrt{T_{e}} \left(0.00057 T_{e} + 1\right) +\\ 1.82 \cdot 10^{-10} N_{O_2} \sqrt{T_{e}} \left(0.036 \sqrt{T_{e}} + 1\right)\label{eq:Ven} \tag{11}$$
#
# #### 4. Gyro to Collision frequency ratios
#
# $$r_{j}=\frac{\nu_{jn}}{\Omega_{j}}\label{eq:r_Op} \tag{12}$$
# where $j=e,O^{+},O_{2}^{+}$.
#
# #### 5.Ion-Neutral collision cross sections
#
#
# $$ \sigma_{in}= \frac{\nu_{in}}{N_{n} \sqrt{2 k_{B} T_{i} / m_{i}}} \tag{13}$$
#
# where $N_{n}$ is the neutral number density, $k_{B}$ is Boltzmann's constant, $T_{i}$ is the ion temperature and $m_{i}$ is the ion mass.
#
# #### 6.Conductivities
#
# The Pedersen $σ_{P}$, Hall $σ_{H}$ and Parallel $σ_{||}$ condcutivities are derived from the following formulas:
#
# $  \sigma_{P} = \frac{q_{e}}{B} \left(N_e  \frac{r_{e}}{r_{e}^{2} + 1} + N_{O^+}  \frac{ r_{O^+}}{r_{O^+}^{2} + 1} + N_{O_2^+} \frac{ r_{O_2^+}}{r_{O_2^+}^{2} + 1}\right) \label{eq:Pedersen}\tag{14}$
#
#
# $ \sigma_{H}=\frac{q_{e}}{B} \left(N_e  \frac{1}{r_{e}^{2} + 1} -N_{O_2^+}  \frac{1}{r_{O_2^+}^{2} + 1} - N_{O^+} \frac{1}{r_{O^+}^{2} + 1}\right)\label{eq:Hall} \tag{15}$
#
# $ \sigma_{\parallel}=N_e  \frac{ q_{e}^{2}}{\nu_{en} m_{e}}\label{eq:Parallel} \tag{16}$
#
# where $N_{j}$ is the corresponding number desity in $m^{-3}$.
#
# #### 7.Ion and Electron velocities
#
# Expressions for the ion and electorn velocities were derived by solving the coresponding momentum equations:
#
# $$ \vec{v_{i\bot}^{*}}= \frac{\nu_{in} \Omega_{i} \vec{E_{\bot}^{*}} - \Omega_{i}^2 \hat{b} x \vec{E_{\bot}^{*}} }{B(\nu_{in}^2+\Omega_{i}^2)} \tag{17}$$
#
# $$ \vec{v_{e\bot}^{*}}= \frac{-\nu_{en\bot} \Omega_{e} \vec{E_{\bot}^{*}} - \Omega_{e}^2 \hat{b} x \vec{E_{\bot}^{*}} }{B(\nu_{en\bot}^2+\Omega_{e}^2)} \tag{18}$$
#
# where $\hat{b}$ is a unit vector along the magnetic field line.
#
# #### 8. Heating rates
#
# According to Poynting's theorem, at high latitudes the electormagnetic interaction between the ionosphere and magnetosphere can be expressed as:
#
# $$ \frac{\partial w}{\partial t} + \nabla \cdot{\frac{\vec{E} \times \vec{B}}{\mu_0}}+ \vec{J} \cdot \vec{E} =0 \tag{19}$$
#
# where $w$ is the electromagnetic energy density and $\mu_0$ is the magnetic permeability of free space.<br>
#
# For a static case, the first term in (18) vanishes, so equation (18) becomes:
#
# $$ \nabla \cdot{\frac{\vec{E} \times \vec{B}}{\mu_0}}+ \vec{J} \cdot \vec{E} =0 \tag{20}$$
#
# which means that the Poynting flux flowing in or out of a unit volume in the ionosphere, is compensated by the energy dissipated ($\vec{J} \cdot \vec{E} >0 $) or generated ($\vec{J} \cdot \vec{E} <0 $) within this volume. The parallel to the magnetic field component of the electirc field $\vec{E_{||}}$, is much smaller than the perpendicular component in the ionosphere, thus $\vec{E_{||}}\approx 0$. In that sense the rate of energy transfer to the medium becomes:
#
# $$ \vec{J} \cdot \vec{E} \approx \vec{J_{\bot}} \cdot \vec{E} \tag{21}$$
#  In the neutral reference frame, (20) becomes:
#
# $$\vec{J_{\bot}} \cdot \vec{E} = \vec{J_{\bot}} \cdot \vec{E^{*}}+\vec{u_{n}} \cdot (\vec{J}  \times \vec{B}) \tag{22}$$
#
# the first term in the right hand of (21), $\vec{J_{\bot}} \cdot \vec{E^{*}}$ is the Joule heating rate $q_{j}$, while the second term $\vec{u_{n}} \cdot (\vec{J}  \times \vec{B})$ is the mechanical power i.e. the rate of work done by the Ampere force $\vec{J}  \times \vec{B}$ on the neutral gases. Taking into account Ohm's law, we derive another expression for the heating rate, the Ohmic heating rate $q_{\Omega}$ :
#
# $$ q_{\Omega}= \sigma_{P}(\vec{E}+\vec{u_{n}}\times \vec{B})^2 \tag{23} $$
#
#
# Analysing further $q_{\Omega}$:
#
# $$\sigma_{P}(\vec{E}+\vec{u_{n}}\times \vec{B})^2 = \sigma_{P} E^2 + \sigma_{P} |\vec{u_{n}}\times \vec{B}|^2 - 2 \sigma_{P}\vec{u_{n}}\cdot (\vec{E}\times \vec{B}) \tag{24}    $$
#
# the first term in the right hand side of (23) i.e. $\sigma_{P} E^2$ is the heating rate in the absence of neutrla winds, while the other two terms, i.e. $\sigma_{P} |\vec{u_{n}}\times \vec{B}|^2 - 2 \sigma_{P}\vec{u_{n}}\cdot (\vec{E}\times \vec{B})$ is the contribution of the neutral winds to the total heating rate. Following Lu et al.(1995)[4] terminology, we name the first one convenction heating $q_{c}$, and the wind contribution as wind heating $q_{w}$, i.e.:
#
# $$q_{c}=\sigma_{P} E^2 \tag{25}    $$
#
# $$q_{w}=\sigma_{P} |\vec{u_{n}}\times \vec{B}|^2 - 2 \sigma_{P}\vec{u_{n}}\cdot (\vec{E}\times \vec{B}) \tag{26}    $$
#
# Another way to express the total heating rate is to address it as frictional heating $q_{f}$:
#
# $$q_{f}=m_{i} N_{e} \nu_{in} |\vec{v_{i\bot}^*}|^2 = m_{i} N_{e} \nu_{in} |\vec{v_{i\bot}} -\vec{u_{n\bot}} |^2 \tag{27}    $$
#
# where $m_{i}$ is the ion mass. <br>
#
# Using the current definition:
#
# $$\vec{J_{\bot}}=eN_{e}(\vec{V_{i\bot}} - \vec{V_{e\bot}})=eN_{e}(\vec{V_{i\bot}^*} - \vec{V_{e\bot}^*}) \tag{28}  $$
#
# assuming magnetised electron, perpendicular to B:
#
# $$ \vec{V_{e\bot}^*}= \frac{\vec{E^*}\times \vec{B}}{B^2} \Rightarrow \vec{V_{e\bot}} = \vec{u_{n\bot}}+ \frac{(\vec{E}+ \vec{u_n} \times \vec{B}) \times \vec{B}}{B^2}  \tag{29} $$
#
# thus the Joule heating $q_{j}$ can be expressed as:
#
# $$ q_{j}=eN_{e}\Big( (\vec{V_i}-\vec{u_n})-\frac{(\vec{E}+ \vec{u_n} \times \vec{B}) \times \vec{B}}{B^2}) \cdot (\vec{E}+ \vec{u_n} \times \vec{B}) \Big) \tag{30}  $$
#
# usnig the identity $ (\vec{a} \times \vec{b}) \cdot \vec{a}= 0 $:
#
# $$q_j=eN_{e} (\vec{V_i}-\vec{u_n}) \cdot (\vec{E_{\bot}}+ \vec{u_n} \times \vec{B})  \tag{31}  $$
# or
# $$q_j=eN_{e}\vec{V_i^*} \cdot \vec{E_{\bot}^*} \tag{32}  $$
#
#
# #### 9. Perpendicular currents
#
# From the ionospheric Ohm's law:
#
# $$ \vec{J_{\bot}}= \sigma_{P} \vec{E_{\bot}^*} + \sigma_{H} \hat{b} \times \vec{E_{\bot}^*}   \tag{33}$$
#
# where: <br>
#
# $$ \vec{J_{P}}= \sigma_{P} \vec{E_{\bot}^*}   \tag{34}$$
#  is the Pedersen current density, and:
#
#  $$ \vec{J_{H}}=  \sigma_{H} \hat{b} \times \vec{E_{\bot}^*}   \tag{35}$$
#
#  is the Hall current density.
#
#
#
#
# <br><br><br>
# [1]Qian, Liying, et al. "The NCAR TIE-GCM: A community model of the coupled thermosphere/ionosphere system." Modeling the ionosphere-thermosphere system 201 (2014): 73-83.<br>
# [2]Thébault, Erwan, et al. "International geomagnetic reference field: the 12th generation." Earth, Planets and Space 67.1 (2015): 79.<br>
# [3]Schunk, R., & Nagy, A. (2000). Ionospheres: Physics, Plasma Physics, and Chemistry (Cambridge Atmospheric and Space Science Series). Cambridge: Cambridge University Press. doi:10.1017/CBO9780511551772<br>
# [4]Lu, G., Richmond, A. D., Emery, B. A., & Roble, R. G. (1995). Magnetosphere-ionosphere-thermosphere coupling: Effect of neutral winds on energy-transfer and field-aligned current. Journal Of Geophysical Research-Space Physics, 100, 19643-19659. doi:10.1029/95JA00766
# </p>

# %%
#import required packages
import sys
sys.path.insert(1, "../SourceCode")
import DaedalusGlobals as DaedalusGlobals
from netCDF4 import Dataset
import numpy as np
import datetime
import pyglow
from ipywidgets import*
import ipywidgets as widgets
import warnings
import glob
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from mpl_toolkits.basemap import Basemap, shiftgrid, addcyclic
import matplotlib.mlab as mlab
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata
from pylab import *
from matplotlib.patches import Polygon
import time
import pandas as pd
import image
from scipy.special import erf
import matplotlib.colors as colors
from matplotlib import ticker, cm
#Allocations
Ohmic1=[]
zg1=[]
Joule1=[]
Frictional1=[]
nO1=[]
nO21=[]
nN21=[]
Ne1=[]
NOp1=[]
NO2p1=[]
sigmaHall1=[]
sigmaPed1=[]
sigmaHall1TIEGCM=[]
sigmaPed1TIEGCM=[]
sigma01=[]
omega_e1=[]
omega_Op1=[]
vOp1=[]
ven1=[]
omega_O2p1=[]
JH_rhov=[]
vNOp1=[]
NNOp1=[]
omega_NOp1=[]
vO2p1=[]
vin1=[]
vi_op_x1=[]
vi_op_y1=[]
vi_op_z1=[]
vi_o2p_x1=[]
vi_o2p_y1=[]
vi_o2p_z1=[]
vi_nop_x1=[]
vi_nop_y1=[]
vi_nop_z1=[]
unvx1=[]
unvy1=[]
unvz1=[]
ExBx1=[]
ExBy1=[]
ExBz1=[]
ve_x1=[]
ve_y1=[]
ve_z1=[]
E_e=[]
E_n=[]
E_u=[]
J_pe=[]
J_pn=[]
J_pu=[]
J_he=[]
J_hn=[]
J_hu=[]
T_e=[]
T_i=[]
T_n=[]
J_p_Ohmice=[]
J_p_Ohmicn=[]
J_p_Ohmicu=[]
J_dene=[]
J_denn=[]
J_denu=[]
cross_sectionf=[]
Pressure=[]
ohmic_pressure=[]
pressure_ohmic=[]
lat_out=[]
lon_out=[]
wind1=[]
convection1=[]
ohms_ohmic=[]
Ee_TIEGCM1=[]
En_TIEGCM1=[]
Eu_TIEGCM1=[]
QAMIE1=[]
QWIND1=[]
cross_op_sectionf=[]
cross_nop_sectionf=[]
cross_o2p_sectionf=[]
qDTop_o=[]
qDTop_o2=[]
qDTop_n2=[]
qDTop_he=[]
qDTo2p_o=[]
qDTo2p_o2=[]
qDTo2p_n2=[]
qDTo2p_he=[]
qDTnop_o=[]
qDTnop_o2=[]
qDTnop_n2=[]
qDTnop_he=[]
qDTop_n=[]
qDTo2p_n=[]
qDTnop_n=[]
qDTi_n=[]
Argon=[]
Helium=[]
NitricOxide=[]
Nitrogen_ion=[]
Le_N2_rot=[]
Le_O2_rot=[]
Le_O_fine=[]
Le_O_1D=[]
Le_O2_vib=[]
qDTe_o=[]
qDTe_o2=[]
qDTe_n2=[]
qDTe_he=[]
qDTe_n=[]
Le1=[]
vei=[]
qDTe_op=[]
qDTe_o2p=[]
qDTe_np=[]
qDTe_nop=[]
qDTe_i=[]
vop_n_SB=[]
vo2p_n_SB=[]

Nef=np.zeros((72, 144),order='F')
NOf=np.zeros((72, 144),order='F')
NO2f=np.zeros((72, 144),order='F')
NN2f=np.zeros((72, 144),order='F')
NNOpf=np.zeros((72, 144),order='F')
Evert=np.zeros((72, 144),order='F')
Evertx=np.zeros((72, 144),order='F')
Everty=np.zeros((72, 144),order='F')
Evertz=np.zeros((72, 144),order='F')
NOpf=np.zeros((72, 144),order='F')
NO2pf=np.zeros((72, 144),order='F')
Omega_ef=np.zeros((72, 144),order='F')
Omega_Opf=np.zeros((72, 144),order='F')
vOpf=np.zeros((72, 144),order='F')
venf=np.zeros((72, 144),order='F')
sigmaPedf=np.zeros((72, 144),order='F')
sigmaPedf_T=np.zeros((72, 144),order='F')
sigmaHallf=np.zeros((72, 144),order='F')
sigmaHallf_T=np.zeros((72, 144),order='F')
TIEGCM_PEDf=np.zeros((72, 144),order='F')
TIEGCM_HALLf=np.zeros((72, 144),order='F')
Potf=np.zeros((72, 144),order='F')
vi_starxf_op=np.zeros((72, 144),order='F')
vi_staryf_op=np.zeros((72, 144),order='F')
vi_starzf_op=np.zeros((72, 144),order='F')
vi_starxf_o2p=np.zeros((72, 144),order='F')
vi_staryf_o2p=np.zeros((72, 144),order='F')
vi_starzf_o2p=np.zeros((72, 144),order='F')
vi_starxf_nop=np.zeros((72, 144),order='F')
vi_staryf_nop=np.zeros((72, 144),order='F')
vi_starzf_nop=np.zeros((72, 144),order='F')
Bxf=np.zeros((72, 144),order='F')
Byf=np.zeros((72, 144),order='F')
Bzf=np.zeros((72, 144),order='F')
zgf=np.zeros((72, 144),order='F')
Ohmic=np.zeros((72, 144),order='F')
Joule=np.zeros((72, 144),order='F')
Frictional=np.zeros((72, 144),order='F')
Ohmic_TIEGCM=np.zeros((72, 144),order='F')
unvertxf=np.zeros((72, 144),order='F')
unvertyf=np.zeros((72, 144),order='F')
unvertzf=np.zeros((72, 144),order='F')
ExB_x=np.zeros((72, 144),order='F')
ExB_y=np.zeros((72, 144),order='F')
ExB_z=np.zeros((72, 144),order='F')
ExBx_calc=np.zeros((72, 144),order='F')
ExBy_calc=np.zeros((72, 144),order='F')
ExBz_calc=np.zeros((72, 144),order='F')
NO2pf=np.zeros((72, 144),order='F')
Omega_NOpf=np.zeros((72, 144),order='F')
Omega_O2pf=np.zeros((72, 144),order='F')
vO2pf=np.zeros((72, 144),order='F')
vinf=np.zeros((72, 144),order='F')
JH_rho=np.zeros((72, 144),order='F')
sigma_par=np.zeros((72, 144),order='F')
J_densx=np.zeros((72, 144),order='F')
J_densy=np.zeros((72, 144),order='F')
J_densz=np.zeros((72, 144),order='F')
J_Ohmx=np.zeros((72, 144),order='F')
J_Ohmy=np.zeros((72, 144),order='F')
J_Ohmz=np.zeros((72, 144),order='F')
vee_out=np.zeros((72, 144),order='F')
ven_out=np.zeros((72, 144),order='F')
veu_out=np.zeros((72, 144),order='F')
maplat=np.zeros((72),order='F')
maplon=np.zeros((144),order='F')
maptime=np.zeros((24),order='F')
J_Pede=np.zeros((72, 144),order='F')
J_Pedn=np.zeros((72, 144),order='F')
J_Pedu=np.zeros((72, 144),order='F')
J_Halle=np.zeros((72, 144),order='F')
J_Halln=np.zeros((72, 144),order='F')
J_Hallu=np.zeros((72, 144),order='F')
J_Ohme=np.zeros((72, 144),order='F')
J_Ohmn=np.zeros((72, 144),order='F')
J_Ohmu=np.zeros((72, 144),order='F')
vi_mag_op=np.zeros((72, 144),order='F')
vi_mag_o2p=np.zeros((72, 144),order='F')
vi_mag_nop=np.zeros((72, 144),order='F')
J_mag=np.zeros((72, 144),order='F')
Unef=np.zeros((72, 144),order='F')
Unnf=np.zeros((72, 144),order='F')
Unuf=np.zeros((72, 144),order='F')
JxBe=np.zeros((72, 144),order='F')
JxBn=np.zeros((72, 144),order='F')
JxBu=np.zeros((72, 144),order='F')
QAMIE_T=np.zeros((72, 144),order='F')
QWIND_T=np.zeros((72, 144),order='F')
Ti_Out=np.zeros((72, 144),order='F')
Te_Out=np.zeros((72, 144),order='F')
Tn_Out=np.zeros((72, 144),order='F')
Press_Ohmic=np.zeros((72, 144),order='F')
cross_section=np.zeros((72, 144),order='F')
cross_section_op=np.zeros((72, 144),order='F')
cross_section_o2p=np.zeros((72, 144),order='F')
cross_section_nop=np.zeros((72, 144),order='F')
Convenction_heating_Out=np.zeros((72, 144),order='F')
Wind_heating_Out=np.zeros((72, 144),order='F')
Ohmic_heating_OhmsLaw_Out=np.zeros((72, 144),order='F')
Mechanical_power_Out=np.zeros((72, 144),order='F')
Energy_Out=np.zeros((72, 144),order='F')
Pressure_2D=np.zeros((72, 144),order='F')
Ohmic_Press=np.zeros((72, 144),order='F')
vNOpf=np.zeros((72, 144),order='F')
qDTop_of=np.zeros((72, 144),order='F')
qDTop_o2f=np.zeros((72, 144),order='F')
qDTop_n2f=np.zeros((72, 144),order='F')
qDTo2p_of=np.zeros((72, 144),order='F')
qDTo2p_o2f=np.zeros((72, 144),order='F')
qDTo2p_n2f=np.zeros((72, 144),order='F')
qDTnop_of=np.zeros((72, 144),order='F')
qDTnop_o2f=np.zeros((72, 144),order='F')
qDTnop_n2f=np.zeros((72, 144),order='F')
qDTop_nf=np.zeros((72, 144),order='F')
qDTo2p_nf=np.zeros((72, 144),order='F')
qDTnop_nf=np.zeros((72, 144),order='F')
qDTi_nf=np.zeros((72, 144),order='F')

Nefl=np.zeros((57, 72),order='F')
NOfl=np.zeros((57, 72),order='F')
NO2fl=np.zeros((57, 72),order='F')
NN2fl=np.zeros((57, 72),order='F')
NNOpfl=np.zeros((57, 72),order='F')
Evertl=np.zeros((57, 72),order='F')
Evertxl=np.zeros((57, 72),order='F')
Evertyl=np.zeros((57, 72),order='F')
Evertzl=np.zeros((57, 72),order='F')
NOpfl=np.zeros((57, 72),order='F')
NO2pfl=np.zeros((57, 72),order='F')
Omega_efl=np.zeros((57, 72),order='F')
Omega_Opfl=np.zeros((57, 72),order='F')
vOpfl=np.zeros((57, 72),order='F')
venfl=np.zeros((57, 72),order='F')
sigmaPedfl=np.zeros((57, 72),order='F')
sigmaPedf_Tl=np.zeros((57, 72),order='F')
sigmaHallfl=np.zeros((57, 72),order='F')
sigmaHallf_Tl=np.zeros((57, 72),order='F')
TIEGCM_PEDfl=np.zeros((57, 72),order='F')
TIEGCM_HALLfl=np.zeros((57, 72),order='F')
Potfl=np.zeros((57, 72),order='F')
vi_starxf_opl=np.zeros((57, 72),order='F')
vi_staryf_opl=np.zeros((57, 72),order='F')
vi_starzf_opl=np.zeros((57, 72),order='F')
vi_starxf_o2pl=np.zeros((57, 72),order='F')
vi_staryf_o2pl=np.zeros((57, 72),order='F')
vi_starzf_o2pl=np.zeros((57, 72),order='F')
vi_starxf_nopl=np.zeros((57, 72),order='F')
vi_staryf_nopl=np.zeros((57, 72),order='F')
vi_starzf_nopl=np.zeros((57, 72),order='F')
Bxfl=np.zeros((57, 72),order='F')
Byfl=np.zeros((57, 72),order='F')
Bzfl=np.zeros((57, 72),order='F')
zgfl=np.zeros((57, 72),order='F')
Ohmicl=np.zeros((57, 72),order='F')
Joulel=np.zeros((57, 72),order='F')
Frictionall=np.zeros((57, 72),order='F')
Ohmic_TIEGCMl=np.zeros((57, 72),order='F')
unvertxfl=np.zeros((57, 72),order='F')
unvertyfl=np.zeros((57, 72),order='F')
unvertzfl=np.zeros((57, 72),order='F')
ExB_xl=np.zeros((57, 72),order='F')
ExB_yl=np.zeros((57, 72),order='F')
ExB_zl=np.zeros((57, 72),order='F')
ExBx_calcl=np.zeros((57, 72),order='F')
ExBy_calcl=np.zeros((57, 72),order='F')
ExBz_calcl=np.zeros((57, 72),order='F')
NO2pfl=np.zeros((57, 72),order='F')
Omega_NOpfl=np.zeros((57, 72),order='F')
Omega_O2pfl=np.zeros((57, 72),order='F')
vO2pfl=np.zeros((57, 72),order='F')
vinfl=np.zeros((57, 72),order='F')
JH_rhol=np.zeros((57, 72),order='F')
sigma_parl=np.zeros((57, 72),order='F')
J_densxl=np.zeros((57, 72),order='F')
J_densyl=np.zeros((57, 72),order='F')
J_denszl=np.zeros((57, 72),order='F')
J_Ohmxl=np.zeros((57, 72),order='F')
J_Ohmyl=np.zeros((57, 72),order='F')
J_Ohmzl=np.zeros((57, 72),order='F')
vee_outl=np.zeros((57, 72),order='F')
ven_outl=np.zeros((57, 72),order='F')
veu_outl=np.zeros((57, 72),order='F')
maplatl=np.zeros((72),order='F')
# maplon1=np.zeros((144),order='F')
mapaltl=np.zeros((57),order='F')
maptimel=np.zeros((24),order='F')
J_Pedel=np.zeros((57, 72),order='F')
J_Pednl=np.zeros((57, 72),order='F')
J_Pedul=np.zeros((57, 72),order='F')
J_Hallel=np.zeros((57, 72),order='F')
J_Hallnl=np.zeros((57, 72),order='F')
J_Hallul=np.zeros((57, 72),order='F')
J_Ohmel=np.zeros((57, 72),order='F')
J_Ohmnl=np.zeros((57, 72),order='F')
J_Ohmul=np.zeros((57, 72),order='F')
vi_mag_opl=np.zeros((57, 72),order='F')
vi_mag_o2pl=np.zeros((57, 72),order='F')
vi_mag_nopl=np.zeros((57, 72),order='F')
J_magl=np.zeros((57, 72),order='F')
Unefl=np.zeros((57, 72),order='F')
Unnfl=np.zeros((57, 72),order='F')
Unufl=np.zeros((57, 72),order='F')
JxBel=np.zeros((57, 72),order='F')
JxBnl=np.zeros((57, 72),order='F')
JxBul=np.zeros((57, 72),order='F')
QAMIE_Tl=np.zeros((57, 72),order='F')
QWIND_Tl=np.zeros((57, 72),order='F')
Ti_Outl=np.zeros((57, 72),order='F')
Te_Outl=np.zeros((57, 72),order='F')
Tn_Outl=np.zeros((57, 72),order='F')
Press_Ohmicl=np.zeros((57, 72),order='F')
cross_sectionl=np.zeros((57, 72),order='F')
cross_section_opl=np.zeros((57, 72),order='F')
cross_section_o2pl=np.zeros((57, 72),order='F')
cross_section_nopl=np.zeros((57, 72),order='F')
Convenction_heating_Outl=np.zeros((57, 72),order='F')
Wind_heating_Outl=np.zeros((57, 72),order='F')
Ohmic_heating_OhmsLaw_Outl=np.zeros((57, 72),order='F')
Mechanical_power_Outl=np.zeros((57, 72),order='F')
Energy_Outl=np.zeros((57, 72),order='F')
Pressure_2Dl=np.zeros((57, 72),order='F')
Ohmic_Pressl=np.zeros((57, 72),order='F')
vNOpfl=np.zeros((57, 72),order='F')
qDTop_ofl=np.zeros((57, 72),order='F')
qDTop_o2fl=np.zeros((57, 72),order='F')
qDTop_n2fl=np.zeros((57, 72),order='F')
qDTo2p_ofl=np.zeros((57, 72),order='F')
qDTo2p_o2fl=np.zeros((57, 72),order='F')
qDTo2p_n2fl=np.zeros((57, 72),order='F')
qDTnop_ofl=np.zeros((57, 72),order='F')
qDTnop_o2fl=np.zeros((57, 72),order='F')
qDTnop_n2fl=np.zeros((57, 72),order='F')
qDTop_nfl=np.zeros((57, 72),order='F')
qDTo2p_nfl=np.zeros((57, 72),order='F')
qDTnop_nfl=np.zeros((57, 72),order='F')
qDTi_nfl=np.zeros((57, 72),order='F')

#Transformation from ENU to ECEF
def enu_ecef(lat_phi, lon_lmd, Fe, Fn, Fup):
    fac = np.pi / 180
    lat_phi = lat_phi * fac
    lon_lmd = lon_lmd * fac

    north_temp_unit = [-np.cos(lon_lmd) * np.sin(lat_phi), - np.sin(lon_lmd) * np.sin(lat_phi), np.cos(lat_phi)]
    east_temp_unit = [-np.sin(lon_lmd), np.cos(lon_lmd), 0]
    up_temp_unit = [np.cos(lon_lmd) * np.cos(lat_phi), np.sin(lon_lmd) * np.cos(lat_phi), np.sin(lat_phi)]

    Fnorth_vector = [Fn * north_temp_unit[0], Fn * north_temp_unit[1], Fn * north_temp_unit[2]]
    Feast_vector = [Fe * east_temp_unit[0], Fe * east_temp_unit[1], Fe * east_temp_unit[2]]
    Fup_vector = [Fup * up_temp_unit[0], Fup * up_temp_unit[1], Fup * up_temp_unit[2]]

    Fx = Fnorth_vector[0] + Feast_vector[0] + Fup_vector[0]
    Fy = Fnorth_vector[1] + Feast_vector[1] + Fup_vector[1]
    Fz = Fnorth_vector[2] + Feast_vector[2] + Fup_vector[2]

    return Fx, Fy, Fz

#Transformation from ECEF to ENU
def ecef_enu(lat_phi, lon_lmd, Fx, Fy, Fz):
    fac = np.pi / 180
    lat_phi = lat_phi * fac
    lon_lmd = lon_lmd * fac
    
    x_temp_unit=[-np.sin(lon_lmd), -np.cos(lon_lmd)*np.sin(lat_phi),np.cos(lon_lmd)*np.cos(lat_phi)]
    y_temp_unit=[np.cos(lon_lmd),-np.sin(lon_lmd)*np.sin(lat_phi),np.sin(lon_lmd)*np.cos(lat_phi)]
    z_temp_unit=[0, np.cos(lat_phi),np.sin(lat_phi)]

    Fx_vector = [Fx * x_temp_unit[0], Fx * x_temp_unit[1], Fx * x_temp_unit[2]]
    Fy_vector = [Fy * y_temp_unit[0], Fy * y_temp_unit[1], Fy * y_temp_unit[2]]
    Fz_vector = [Fz * z_temp_unit[0], Fz * z_temp_unit[1], Fz * z_temp_unit[2]]

    Fe = Fx_vector[0] + Fy_vector[0] + Fz_vector[0]
    Fn = Fx_vector[1] + Fy_vector[1] + Fz_vector[1]
    Fu = Fx_vector[2] + Fy_vector[2] + Fz_vector[2]

    return Fe, Fn, Fu

 # calculate geocentric latitude from geodetic latitude (WGS84)
def geo_lat2geod_lat(phi):
    a = 6378137  # meter semi major axis of earth
    f = 1 / 298.257  # flattening
    b = a - f * a  # semi minor axis
    e = ((a ** 2 - b ** 2) ** (1 / 2)) / a
    phi_rad = np.deg2rad(phi)
    geod_lat = np.arctan(np.tan(phi_rad) / (1 - e ** 2))
    geod_lat = np.rad2deg(geod_lat)
    return geod_lat  # in degrees

#Geographic to Geodetic transformation
def geo2geod(lat_geo_phi, lon_geo_lmd, alt_geo):
    lat_geod_phi = geo_lat2geod_lat(lat_geo_phi)  # degrees
    lon_geod_lmd = lon_geo_lmd  # degrees
    alt_geod = alt_geo  # km
    return lat_geod_phi, lon_geod_lmd, alt_geod

#Calculation of products for map plotting
def run_map(tiegcm_file,timer_value,pressure_level):
    # Initializations
    start_time = time.time()
    time_igrf = datetime.datetime(2015, 3, 15, 0, 0, 0)  # first time step of the TIEGCM run
    timer = 0  # counter used for incrementing TIEGCM timestep
    deltalmd = 2.5  # TIEGCM grid resolution in deg
    deltaphi = 2.5  # TIEGCM grid resolution in deg
    Re = 6378.1370  # Earths Radius (km)
    electron = 1.602176565 * 10 ** (- 19) #electron charge in C
    boltzmann_si=1.38064852 * 10**(-23)
    boltzmann=1.380645852 * 10 ** (-16) #Boltzmann constant in cm^2*g*s^(-2)*K^(-1)
    me=9.10938356 * 10 ** (- 31) #electron mass in kg
    mO=16 # Oxygen atomic mass in g/mol
    mN2=28  #N2 molecular mass in g/mol
    mO2=32 #O2 molecular mass in g/mol
    mNO=30 #NO molecular mass in g/mol
    NA=6.02214086 * 10 ** 23 #Avogadro's constant in mol^-1
    fcor=1.5 #Burnside facor (default=1.5)
    
    #Input file
    TIEGCM = Dataset(tiegcm_file)

    # Get data from TIEGCM Model file
    glat = TIEGCM.variables['lat'][:] #geographic latitude in deg
    glon = TIEGCM.variables['lon'][:] #geographic longitude in deg
    glev = TIEGCM.variables['lev'][:] #interface levels
    gtime = TIEGCM.variables['time'][:] #time in minutes since 2015 March 15 00:00:00
    zg = TIEGCM.variables['ZGMID'][:] #Geometric height in cm
    Ne_all = TIEGCM.variables['NE'][:]  # electron density in cm^-3
    Ne_mid = TIEGCM.variables['ELECDEN'][:]  # electron density in cm^-3
    PED_all = TIEGCM.variables['PEDERSEN'][:] #Pedersen conductivity in Si/m
    HALL_all= TIEGCM.variables['HALL'][:] #Hall conductivity in Si/m
    Un_east = TIEGCM.variables['UN'][:]  # neutral zonal wind (+East) in cm/s
    Un_north = TIEGCM.variables['VN'][:]  # neutral meridional wind (+North) in cm/s
    Un_up = TIEGCM.variables['WN_lev'][:]  # neutral vertical wind (+Up) in cm/s
    Ui_east = TIEGCM.variables['Ui_lev'][:]  # zonal ExB velocity in cm/s
    Ui_north = TIEGCM.variables['Vi_lev'][:]  # meridional ExB velocity in cm/s
    Ui_up = TIEGCM.variables['Wi_lev'][:]  # vertical ExB velocity in cm/s
    Poten_all=TIEGCM.variables['POTEN'][:] #electric potential in V
    barm_all=TIEGCM.variables['BARM'][:] #Mean molecular weight in g/mol
    P0=TIEGCM.variables['p0'][:] #Reference pressure in millibar
    Zh=TIEGCM.variables['Z'][:] #dimensionless variable (for pressure calculations)
    Tn_all=TIEGCM.variables['TN'][:] #Neutral Temperature in K
    Te_all=TIEGCM.variables['TE'][:] #Electron Temperature in K
    Ti_all=TIEGCM.variables['TI'][:] #Ion Temperature in K
    nO_all=TIEGCM.variables['O1'][:] #neutral atomic oxygen density in mmr
    nO2_all=TIEGCM.variables['O2'][:] #neutral molecular oxygen density in mmr
    NOp_all=TIEGCM.variables['OP'][:] #O+ density in cm^-3
    den_all=TIEGCM.variables['DEN'][:] #Density
    nO_all_cm3=TIEGCM.variables['O_CM3'][:] #neutral atomic oxygen density in mmr
    nO2_all_cm3=TIEGCM.variables['O2_CM3'][:] #neutral molecular oxygen density in mmr
    NO2p_all=TIEGCM.variables['O2P'][:] #O+ density in cm^-3
    Np_all=TIEGCM.variables['NPLUS'][:] #N+ density in cm^-3
    NNOp_all=TIEGCM.variables['NOP_LAM'][:] #NO+ density in cm^-3
    N2_all_cm3=TIEGCM.variables['N2_CM3'][:] #N2 density in cm^-3
    EEX=TIEGCM.variables['EEX'][:] 
    EEY=TIEGCM.variables['EEY'][:] 
    EEZ=TIEGCM.variables['EEZ'][:] 
    QAMIE=TIEGCM.variables['QAMIE'][:] 
    QWIND=TIEGCM.variables['QWIND'][:]
    TIEGCM.close() #close input file


    for timer in range(timer_value,timer_value+1):
        time_plot=gtime[timer]
        maptime[timer]=time_plot
        
        for lev in range(pressure_level, pressure_level+1):
        
            for lat in range(0, len(glat)):

                for lon in range(0, len(glon)):
                    
                    ########################################################################
#                   Coordinates
                    ########################################################################
                    
                    # GEO coordinates of desired point
                    alt_p = zg[timer, lev, lat, lon] / 1e5 #cm to km
                    zgf[lat, lon]=alt_p #output 
                    lat_p = glat[lat]   #deg
                    lon_p = glon[lon]   #deg
                    maplat[lat]=glat[lat] #output 
                    maplon[lon]=glon[lon] #output 
                    timeg=gtime[timer] #minutes
                    #time
                    time_p = time_igrf + datetime.timedelta(minutes=timeg)               
                   
                    #Pressure levels
                    Z=glev[lev]
                    
                    pressuref=P0*np.exp(-Z) #pressure in millibars
                    pressuref_Pa=pressuref*100 #pressure in Pascals
                    Pressure_2D[lat,lon]=pressuref_Pa
                    
                    #Electric Potential (V)
                    Pot=Poten_all[timer, lev, lat, lon]
                    Potf[lat, lon]=Pot #output 
                    
                    ########################################################################
#                   Temperatures and densities
                    ########################################################################

                    #Temperatures
                    Tn=Tn_all[timer, lev, lat, lon]     #Kelvin
                    Te=Te_all[timer, lev, lat, lon]     #Kelvin
                    Ti=Ti_all[timer, lev, lat, lon]     #Kelvin
                    
                    Ti_Out[lat,lon]=Ti
                    Te_Out[lat,lon]=Te
                    Tn_Out[lat,lon]=Tn
                    
                    #mean molecular mass g/mol
                    barm=barm_all[timer, lev, lat, lon]

                    #Conversion factor (mmr->cm^(-3))
                    Nbarm=(P0*np.exp(-Z)*barm*1000)/(boltzmann*Tn)

                    #neutral Densities (cm^-3)
                    NO=nO_all_cm3[timer, lev, lat, lon] #cm^-3
                    NOf[lat, lon]=NO* (10 ** 6) #output m^-3
                    NO2=nO2_all_cm3[timer, lev, lat, lon] #cm^-3                 
                    NO2f[lat, lon]=NO2* (10 ** 6) #output m^-3
                    NN2=N2_all_cm3[timer, lev, lat, lon] #cm^-3
                    NN2f[lat, lon]=NN2* (10 ** 6) #output m^-3

                    # electron density
                    Ne = Ne_all[timer, lev, lat, lon] * (10 ** 6)  # m^-3
                    Nef[lat, lon]=Ne #output m^-3
                    Necm=Ne_all[timer, lev, lat, lon] # (cm^-3)

                    #ion Densities
                    NOp=NOp_all[timer, lev, lat, lon]  #cm^-3
                    NO2p=NO2p_all[timer, lev, lat, lon]  #cm^-3
                    NOpf[lat, lon]=NOp #output 
                    NO2pf[lat, lon]=NOp #output 
                    NNOp=Necm-NOp+NO2p  #if O2+ density is available in the input file
                    NNOpf[lat, lon]=NNOp #output 
                    
                    
                    MO=mO/(NA*1000)  # Atomic oxygen mass in kg
                    MO2=(2*mO)/(NA*1000) # Molecular oxygen mass in kg
                    MNO=(mNO)/(NA*1000) #Nitric oxide mass in kg
                    
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #neutral wind 
                    Une=Un_east[timer, lev, lat, lon]
                    Unn=Un_north[timer, lev, lat, lon]
                    Unu=Un_up[timer, lev, lat, lon]

                    Un_x = Une / 100  # m/s
                    Un_y = Unn / 100  # m/s
                    Un_z = Unu / 100  # m/s
                    Un = [Un_x, Un_y, Un_z] # neutral wind in ENU in m/s
                    
                    Unef[lat,lon]=Un_x #output (ENU)
                    Unnf[lat,lon]=Un_y #output (ENU)  
                    Unuf[lat,lon]=Un_z #output (ENU)  
                    

                    # ExB velocity from ENU to ECEF
                    Uie=Ui_east[timer, lev, lat, lon]
                    Uin=Ui_north[timer, lev, lat, lon]
                    Uiu=Ui_up[timer, lev, lat, lon]

                    Ui_x = Uie / 100  # m/sec
                    Ui_y = Uin / 100  # m/sec
                    Ui_z = Uiu / 100  # m/sec
                    Ui = [Ui_x, Ui_y, Ui_z]  # ExB in ENU in m/s
                    
                    ########################################################################
#                   Magnetic and Electric fields
                    ########################################################################
                    
                    # Magnetic Field from ENU to ECEF
                    pt = pyglow.Point(time_p, lat_p, lon_p, alt_p) # pyglow igrf
                    pt.run_igrf()
                    Be = pt.Bx
                    Bn = pt.By
                    Bu = pt.Bz
                    B = [Be, Bn, Bu]  # vector of magnetic field ENU in Telsa
                    Bxf[lat, lon]=Be #output (ENU)
                    Byf[lat, lon]=Bn #output (ENU)
                    Bzf[lat, lon]=Bu #output (ENU)
                    
                    Bx, By, Bz = enu_ecef(lat_p, lon_p, Be, Bn, Bu)  # Tesla in ECEF
                    B = [Bx, By, Bz]  # vector of magnetic field ECEF in Telsa

                    # Magnetic field unit vector
                    bnorm = np.sqrt(Bx * Bx + By * By + Bz * Bz)
                    b_unit = [Bx / bnorm, By / bnorm, Bz / bnorm]
#                     bnorm = np.sqrt(Be * Be + Bn * Bn + Bu * Bu) #ENU
#                     b_unit = [Be / bnorm, Bn / bnorm, Bu / bnorm] #ENU
                    
#                     #Electric Field perpendicular to the magnetic field
#                     Evert=-np.cross(Ui,B)  #V/m
#                     Ee=Evert[0]
#                     En=Evert[1]
#                     Eu=Evert[2]
                    
#                     enorm=np.sqrt(En*En+Eu*Eu+Ee*Ee)
#                     e_unit=[Ee / enorm, En / enorm, Eu / enorm]
                    
#                     Evertx[lat, lon]=Ee #ENU
#                     Everty[lat, lon]=En #ENU
#                     Evertz[lat, lon]=Eu #ENU

                    #neutral wind perpendicular to the magnetic field
                    Unvert=np.cross(Un,b_unit)
                    Unvertx=Unvert[0]
                    Unverty=Unvert[1]
                    Unvertz=Unvert[2]
                    Unvertmag=np.sqrt(Unvert[0] * Unvert[0] + Unvert[1] * Unvert[1] + Unvert[2] * Unvert[2])
                    
                    unvertxf[lat, lon]=Unvertx #output
                    unvertyf[lat, lon]=Unverty #output
                    unvertzf[lat, lon]=Unvertz #output
                    
#                     TIEGCM_Electric Fields
                    Ee_TIEGCM=EEX[timer, lev, lat, lon]*100
                    En_TIEGCM=EEY[timer, lev, lat, lon]*100
                    Eu_TIEGCM=EEZ[timer, lev, lat, lon]*100
                    ETIEGCM=[Ee_TIEGCM,En_TIEGCM,Eu_TIEGCM]
                    Ee_T, En_T, Eu_T = enu_ecef(lat_p, lon_p,Ee_TIEGCM,En_TIEGCM, Eu_TIEGCM)
                    Evert2=[Ee_T,En_T,Eu_T]
                    
                    E_T_vert=np.cross(Evert2,b_unit)
                    Ee_T_vert=E_T_vert[0]
                    En_T_vert=E_T_vert[1]
                    Eu_T_vert=E_T_vert[2]
                                        
                    
                    #Perpendicular electric field in neutral atmosphere reference frame                                        
                    Estar=E_T_vert+np.cross(Unvert,B)
                                                           
                    Evertx[lat, lon]=Ee_TIEGCM #ENU
                    Everty[lat, lon]=En_TIEGCM  #ENU
                    Evertz[lat, lon]=Eu_TIEGCM  #ENU


                    #Calculate ExB velocities 
                    ExBcalc=np.cross(E_T_vert,b_unit)/(bnorm)
                    ExBx_calc[lat, lon]=ExBcalc[0]
                    ExBy_calc[lat, lon]=ExBcalc[1]
                    ExBz_calc[lat, lon]=ExBcalc[2]
                    
                    ########################################################################
#                   Gyrofrequencies and collision frequencies
                    ########################################################################

                    #gyrofrequencies (Hz)
                    bgauss=bnorm*10000
                    qeomeo10=1.7588028*10**7
                    qeoNa010=9.6489*10**3
                    rmassinv_op=1/mO
                    rmassinv_nop=1/mNO
                    rmassinv_o2p=1/mO2 
                    
                    omega_op=qeoNa010*bgauss*rmassinv_op
                    omega_o2p=qeoNa010*bgauss*rmassinv_o2p
                    omega_nop=qeoNa010*bgauss*rmassinv_nop
                    omega_op_inv=1/omega_op
                    omega_o2p_inv=1/omega_o2p
                    omega_nop_inv=1/omega_nop
                    omega_e=qeomeo10*bgauss
                    omega_e_inv=1/omega_e
                    
                    Omega_ef[lat, lon]=omega_e #output
                    Omega_Opf[lat, lon]=omega_op #output
                    Omega_O2pf[lat, lon]=omega_o2p #output
                    Omega_NOpf[lat, lon]=omega_nop #output
                    
                    #collision frequencies (Hz)
                    temps=(Ti+Tn)/2
                    rnu_o2p_o2=2.59 * (10**(-11))* np.sqrt(temps)*((1-0.073*np.log10(temps))**2)
                    rnu_op_o2=6.64 * (10**(-10))
                    rnu_nop_o2=4.27 * (10**(-10))
                    

                    
                    rnu_o2p_o=2.31*(10**(-10))
                    rnu_op_o=3.67 * (10**(-11)) * np.sqrt(temps)*((1-0.064*np.log10(temps))**2)*fcor
                    rnu_nop_o=2.44 * (10**(-10))
                    
                    rnu_o2p_n2=4.13*(10**(-10))
                    rnu_op_n2=6.82 * (10**(-10))
                    rnu_nop_n2=4.34*(10**(-10))
                    
                    rnu_o2p=(rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2)*omega_o2p_inv
                    rnu_op=(rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2)*omega_op_inv
                    rnu_nop=(rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2)*omega_nop_inv
                    
                    vOp=rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2
                    vO2p=rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2
                    vNOp=rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2
                    vin=vOp+vO2p+vNOp
                    
                    vop_o=rnu_op_o*NO
                    vop_o2=rnu_op_o2*NO2
                    vop_n2=rnu_op_n2*NN2
                    vo2p_o=rnu_o2p_o*NO
                    vo2p_o2=rnu_o2p_o2*NO2
                    vo2p_n2=rnu_o2p_n2*NN2
                    vnop_o=rnu_nop_o*NO
                    vnop_o2=rnu_nop_o2*NO2
                    vnop_n2=rnu_nop_n2*NN2
                    
                    ven=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))
                    
                    rnu_ne=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))*omega_e_inv
                    rnu_ne=4*rnu_ne
                    
                    vOpf[lat, lon]=vOp #Output file
                    venf[lat, lon]=ven #Output file
                    vO2pf[lat, lon]=vO2p #Output file
                    vNOpf[lat,lon]=vNOp 
                    vinf[lat, lon]=vin #Output file
                    

                    
                    ########################################################################
#                   Conductivities
                    ########################################################################
    
                    qe_fac=(electron*10**10)/bgauss
                    Necm2=NOp+NO2p+NNOp
                    sigmaPed=qe_fac*((NOp*rnu_op/(1+rnu_op**2))+(NO2p*rnu_o2p/(1+rnu_o2p**2)) \
                                    +(NNOp*rnu_nop/(1+rnu_nop**2))+Necm2*rnu_ne/(1+rnu_ne**2))
                    
                    sigmaHall=qe_fac*(Necm2/(1+rnu_ne**2)-NOp/(1+rnu_op**2)-NO2p/(1+rnu_o2p**2)-NNOp/(1+rnu_nop**2))
                    
                    sigmaPedf[lat, lon]=sigmaPed*10**(5) #output 10^-5 Si/m
                    sigmaHallf[lat, lon]=sigmaHall*10**(5) #output 10^-5 Si/m

                    #Parallel conductivity
                    sigma0=(Ne*electron*electron)/(me*ven)*10**(5) #output 10^-5 Si/m
                    sigma_par[lat, lon]=sigma0
                    
                    #TIEGCM conductivities
                    sP_tiegcm=PED_all[timer, lev, lat, lon]
                    sH_tiegcm=HALL_all[timer, lev, lat, lon]
                    sigmaPedf_T[lat, lon]=sP_tiegcm*10**(5) #output 10^-5 Si/m
                    sigmaHallf_T[lat, lon]=sH_tiegcm*10**(5) #output 10^-5 Si/m
                    
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #Ion Velocity in neutral reference frame (formula derived through ion momentum equation)
                    #O+
                    vi_op_star=(vOp*omega_op*Estar+omega_op**2*(np.cross(Estar,b_unit)))/(bnorm*(vOp**2+omega_op**2))
                    vi_op_starx=vi_op_star[0] #m/s
                    vi_op_stary=vi_op_star[1] #m/s
                    vi_op_starz=vi_op_star[2] #m/s
                    vi_op_starmag=np.sqrt(vi_op_star[0] * vi_op_star[0] + vi_op_star[1] * vi_op_star[1] + vi_op_star[2] * vi_op_star[2])

                    vie_op=vi_op_starx+Unvertx #from neutral frame to ENU
                    vin_op=vi_op_stary+Unverty #from neutral frame to ENU
                    viu_op=vi_op_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_op=np.sqrt(vie_op*vie_op+vin_op*vin_op+viu_op*viu_op)
                    e_unit_op=[vie_op / vinorm_op, vin_op / vinorm_op, viu_op / vinorm_op]
                    
                    vi_mag_op[lat, lon]=vinorm_op
                    vi_starxf_op[lat, lon]=vie_op #output
                    vi_staryf_op[lat, lon]=vin_op #output
                    vi_starzf_op[lat, lon]=viu_op #output
                    
                    #O2+
                    vi_o2p_star=(vO2p*omega_o2p*Estar+omega_o2p**2*(np.cross(Estar,b_unit)))/(bnorm*(vO2p**2+omega_o2p**2))
                    vi_o2p_starx=vi_o2p_star[0] #m/s
                    vi_o2p_stary=vi_o2p_star[1] #m/s
                    vi_o2p_starz=vi_o2p_star[2] #m/s
                    vi_o2p_starmag=np.sqrt(vi_o2p_star[0] * vi_o2p_star[0] + vi_o2p_star[1] * vi_o2p_star[1] + vi_o2p_star[2] * vi_o2p_star[2])

                    vie_o2p=vi_o2p_starx+Unvertx #from neutral frame to ENU
                    vin_o2p=vi_o2p_stary+Unverty #from neutral frame to ENU
                    viu_o2p=vi_o2p_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_o2p=np.sqrt(vie_o2p*vie_o2p+vin_o2p*vin_o2p+viu_o2p*viu_o2p)
                    e_unit_o2p=[vie_o2p / vinorm_o2p, vin_o2p / vinorm_o2p, viu_o2p / vinorm_o2p]
                    
                    vi_mag_o2p[lat, lon]=vinorm_o2p
                    vi_starxf_o2p[lat, lon]=vie_o2p #output
                    vi_staryf_o2p[lat, lon]=vin_o2p #output
                    vi_starzf_o2p[lat, lon]=viu_o2p #output
                    
                    #NO+
                    vi_nop_star=(vNOp*omega_nop*Estar+omega_nop**2*(np.cross(Estar,b_unit)))/(bnorm*(vNOp**2+omega_nop**2))
                    vi_nop_starx=vi_nop_star[0] #m/s
                    vi_nop_stary=vi_nop_star[1] #m/s
                    vi_nop_starz=vi_nop_star[2] #m/s
                    vi_nop_starmag=np.sqrt(vi_nop_star[0] * vi_nop_star[0] + vi_nop_star[1] * vi_nop_star[1] + vi_nop_star[2] * vi_nop_star[2])

                    vie_nop=vi_nop_starx+Unvertx #from neutral frame to ENU
                    vin_nop=vi_nop_stary+Unverty #from neutral frame to ENU
                    viu_nop=vi_nop_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_nop=np.sqrt(vie_nop*vie_nop+vin_nop*vin_nop+viu_nop*viu_nop)
                    e_unit_nop=[vie_nop / vinorm_nop, vin_nop / vinorm_nop, viu_nop / vinorm_nop]
                    
                    vi_mag_nop[lat, lon]=vinorm_nop
                    vi_starxf_nop[lat, lon]=vie_nop #output
                    vi_staryf_nop[lat, lon]=vin_nop #output
                    vi_starzf_nop[lat, lon]=viu_nop #output
                    
                    #Electron Velocity in neutral reference frame (formula derived through electron momentum equation)
                    ve_star=(-ven*omega_e*Estar+omega_e**2*(np.cross(Estar,b_unit)))/(bnorm*(ven**2+omega_e**2))
                    ve_starx=ve_star[0] #m/s
                    ve_stary=ve_star[1] #m/s
                    ve_starz=ve_star[2] #m/s
                    ve_starmag=np.sqrt(ve_star[0] * ve_star[0] + ve_star[1] * ve_star[1] + ve_star[2] * ve_star[2])

                    ve_xtemp=ve_starx+Unvertx #from neutral frame to ENU
                    ve_ytemp=ve_stary+Unverty #from neutral frame to ENU
                    ve_ztemp=ve_starz+Unvertz #from neutral frame to ENU
                  
                    vee_out[lat, lon]=ve_xtemp
                    ven_out[lat, lon]=ve_ytemp
                    veu_out[lat, lon]=ve_ztemp    
                    
                    ########################################################################
#                     Magnetic parameters
                    ########################################################################
    
                    dipmag=np.arctan(Bz/np.sqrt(By**2+Bx**2))
                    sndip=np.sin(dipmag)
                    decmag=np.arctan2(By,Bx)
                    sndec=np.sin(decmag)
                    sn2dec=sndec**2
                    csdec=np.cos(decmag)
                    tm1=sn2dec+(1-sn2dec)*sndip**2
                    tm2=(1-sn2dec)+sn2dec*sndip**2
                    tm3=sndec*csdec*(1-sndip**2)
                    
                    ##########################################################################
#                   Ohmic Heating 
                    ########################################################################## 
                                        
                    A=E_T_vert+np.cross(Unvert,B)
#                     L=np.sqrt(A[0] * A[0] + A[1] * A[1] + A[2] * A[2])

                    Ohmic2=sP_tiegcm*np.dot(A,A)
#                     Ohmic2=sigmaPed*L*L
                    Ohmic[lat, lon]=Ohmic2*1000 #mW/m^3
    
                    ##########################################################################
#                     Joule Heating - Frictional Heating
                    ##########################################################################
    
                    Joule_op=electron*NOp*(10**6)*np.dot(vi_op_star,A)
                    Joule_o2p=electron*NO2p*(10**6)*np.dot(vi_o2p_star,A)
                    Joule_nop=electron*NNOp*(10**6)*np.dot(vi_nop_star,A)
                    Joule1=Joule_op+Joule_o2p+Joule_nop
                    Joule[lat, lon]=Joule1*1000 #mW/m^3
                    
                    Frictional_op=MO*NOp*(10**6)*vOp*vi_op_starmag*vi_op_starmag
                    Frictional_o2p=MO2*NO2p*(10**6)*vO2p*vi_o2p_starmag*vi_o2p_starmag
                    Frictional_nop=MNO*NNOp*(10**6)*vNOp*vi_nop_starmag*vi_nop_starmag
                    Frictional1=Frictional_op+Frictional_o2p+Frictional_nop
                    Frictional[lat, lon]=Frictional1*1000 #mW/m^3
                    
                    rho=den_all[timer, lev, lat, lon]*1000
                    JH_rho[lat, lon]=(Ohmic2/rho)*1000 #mW/kg
                    
                    ##########################################################################
#                   Convection Heating - Wind Correction
                    ##########################################################################
                                        
                    UNxB=np.cross(Unvert,B)
                    UNxBmag=np.sqrt(UNxB[0] * UNxB[0] + UNxB[1] * UNxB[1] + UNxB[2] * UNxB[2])
                    ExB=np.cross(E_T_vert,B)


                    Convenction_heating=sigmaPed*np.dot(E_T_vert,E_T_vert)
                    Convenction_heating_Out[lat, lon]=Convenction_heating*1000 #mW/m^3
                    
#                     Wind_heating=sigmaPed*UNxBmag*UNxBmag-2*sigmaPed*np.dot(Un,ExB)
                    Wind_heating=sP_tiegcm*bnorm**2*(tm2*Un_x**2+tm1*Un_y**2-2*tm3*Un_x*Un_y-2*(Un_x*Ui_x+Un_y*Ui_y))
                    Wind_heating_Out[lat, lon]=Wind_heating*1000 #mW/m^3
        
                    #TIEGCM QWIND and QAMIE
                    QAMIE1=QAMIE[timer, lev, lat, lon]
                    QAMIE_T[lat,lon]=QAMIE1
                    QWIND1=QWIND[timer, lev, lat, lon]
                    QWIND_T[lat,lon]=QWIND1                               
                    
                    Ohmic_heating_OhmsLaw=Convenction_heating+Wind_heating
                    Ohmic_heating_OhmsLaw_Out[lat, lon]=Ohmic_heating_OhmsLaw*1000 #mW/m^3
                    
                    ##########################################################################
#                   Ohmic per Pressure/ Pressure per Ohmic
                    ##########################################################################
                                   
                    Ohmic_pressure=(Ohmic2/pressuref_Pa)
                    Ohmic_Press[lat,lon]=Ohmic_pressure
                
                    pressure_ohmic_tmp=(1/Ohmic_pressure)
                    Press_Ohmic[lat,lon]=pressure_ohmic_tmp
                    
                    ##########################################################################
#                   Electric Currents
                    ##########################################################################
                    
                    #perpendicular electric current density (A/m^2) (Ohm's LaW)
                    J_p_Ohmic=sigmaPed*Estar+sigmaHall*np.cross(b_unit,Estar)
                    J_p_Ohmicx=J_p_Ohmic[0]
                    J_p_Ohmicy=J_p_Ohmic[1]
                    J_p_Ohmicz=J_p_Ohmic[2]
                    
                    #Pedersen and Hall currents
                    J_Pedersen=sigmaPed*Estar
                    J_Hall=sigmaHall*np.cross(b_unit,Estar)
                    
                    Jpe=J_Pedersen[0]
                    Jpn=J_Pedersen[1]
                    Jpu=J_Pedersen[2]
                    Jhe=J_Hall[0]
                    Jhn=J_Hall[1]
                    Jhu=J_Hall[2]

                    
                    #####################
                    Jpnorm=np.sqrt(Jpn*Jpn+Jpu*Jpu+Jpe*Jpe)
                    Jp_unit=[Jpe / Jpnorm, Jpn / Jpnorm, Jpu / Jpnorm]
                    
                    Jhnorm=np.sqrt(Jhn*Jhn+Jhu*Jhu+Jhe*Jhe)
                    Jh_unit=[Jhe / Jhnorm, Jhn / Jhnorm, Jhu / Jhnorm]
                    
                    J_Pede[lat,lon]=Jpe #output 
                    J_Pedn[lat,lon]=Jpn #output  
                    J_Pedu[lat,lon]=Jpu #output 
                    J_Halle[lat,lon]=Jhe #output 
                    J_Halln[lat,lon]=Jhn #output 
                    J_Hallu[lat,lon]=Jhu #output 
                    J_Ohme[lat, lon]=Jpe+Jhe #output 
                    J_Ohmn[lat, lon]=Jpn+Jhn #output 
                    J_Ohmu[lat, lon]=Jpu+Jhu #output 
                    
                    J_mag[lat,lon]=np.sqrt((Jpe+Jhe)**2+(Jpn+Jhn)**2+(Jpu+Jhu)**2) #output 

                    #perpendicular electric current density (A/m^2) (densities)
                    J_den=electron*Ne*(vi_op_star-ve_star)
                    J_denx=J_den[0]
                    J_deny=J_den[1]
                    J_denz=J_den[2]
                    
                    ##########################################################################
#                   JxB forcing
                    ##########################################################################

                    JxB=np.cross(J_p_Ohmic,B)
                    JxBe[lat, lon]=JxB[0]
                    JxBn[lat, lon]=JxB[1]
                    JxBu[lat, lon]=JxB[2]
                    
                    ##########################################################################
#                   Mechanical Power and Energy
                    ##########################################################################
                    
                    Mechanical_power=np.dot(Un,JxB)
                    Mechanical_power_Out[lat, lon]=Mechanical_power
                    Energy=Ohmic_heating_OhmsLaw+Mechanical_power
                    Energy_Out[lat, lon]=Energy
                    
                    ##########################################################################
#                   Cross Sections
                    ##########################################################################
                    N_neutral=(NO2+NN2+NO)*10**6
                    MN2=(mN2)/(NA*1000)
                    M_ion=MO+MO2+MNO
                    
                    cross=(vin/N_neutral)/(np.sqrt((2*boltzmann*Ti)/M_ion))
                    cross_section[lat,lon]=cross
                    
                    cross_op=(vOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO))
                    cross_section_op[lat,lon]=cross_op
                    
                    cross_o2p=(vO2p/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO2))
                    cross_section_o2p[lat,lon]=cross_o2p
                    
                    cross_nop=(vNOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MNO))
                    cross_section_nop[lat,lon]=cross_nop
                    
                    warnings.simplefilter('ignore')
                    
                    #print(Ohmic2*1000,Ohmic_heating_OhmsLaw*1000,Convenction_heating*1000,Wind_heating*1000 )
                    
                    
                    ##########################################################################
#                     Ion heating rates
                    ##########################################################################
    
                    qDTop_o=3*NOp*(10 ** 6)*boltzmann_si*vop_o*(MO/(MO+MO))*(Ti-Tn)
                    qDTop_o2=3*NOp*(10 ** 6)*boltzmann_si*vop_o2*(MO/(MO2+MO))*(Ti-Tn)
                    qDTop_n2=3*NOp*(10 ** 6)*boltzmann_si*vop_n2*(MO/(MN2+MO))*(Ti-Tn)
                    qDTo2p_o=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o*(MO2/(MO+MO2))*(Ti-Tn)
                    qDTo2p_o2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o2*(MO2/(MO2+MO2))*(Ti-Tn)
                    qDTo2p_n2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_n2*(MO2/(MN2+MO2))*(Ti-Tn)
                    qDTnop_o=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o*(MNO/(MO+MNO))*(Ti-Tn)
                    qDTnop_o2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o2*(MNO/(MO2+MNO))*(Ti-Tn)
                    qDTnop_n2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_n2*(MNO/(MN2+MNO))*(Ti-Tn)
                    
                    qDTop_n=qDTop_o+qDTop_o2+qDTop_n2
                    qDTo2p_n=qDTo2p_o+qDTo2p_o2+qDTo2p_n2
                    qDTnop_n=qDTnop_o+qDTnop_o2+qDTnop_n2
                    
                    qDTi_n=qDTop_n+qDTo2p_n+qDTnop_n
                    
                    qDTop_of[lat,lon]=qDTop_o
                    qDTop_o2f[lat,lon]=qDTop_o2
                    qDTop_n2f[lat,lon]=qDTop_n2
                    qDTo2p_of[lat,lon]=qDTo2p_o
                    qDTo2p_o2f[lat,lon]=qDTo2p_o2
                    qDTo2p_n2f[lat,lon]=qDTo2p_n2
                    qDTnop_of[lat,lon]=qDTnop_o
                    qDTnop_o2f[lat,lon]=qDTnop_o2
                    qDTnop_n2f[lat,lon]=qDTnop_n2
                    
                    qDTop_nf[lat,lon]=qDTop_n
                    qDTo2p_nf[lat,lon]=qDTo2p_n
                    qDTnop_nf[lat,lon]=qDTnop_n
                    
                    qDTi_nf[lat,lon]=qDTi_n*1000 #mW/m^3

                    
    print("Calculation executed!")
    print("Total run time: %s seconds" % (time.time() - start_time))
  
    
    
    
    
    
def run(tiegcm_file,lat_value,lon_value,timer_value):
    # Initializations
    start_time = time.time()
    time_igrf = datetime.datetime(2015, 3, 15, 0, 0, 0)  # first time step of the TIEGCM run
    timer = 0  # counter used for incrementing TIEGCM timestep
    deltalmd = 2.5  # TIEGCM grid resolution in deg
    deltaphi = 2.5  # TIEGCM grid resolution in deg
    Re = 6378.1370  # Earths Radius (km)
    electron = 1.602176565 * 10 ** (- 19) #electron charge in C
    boltzmann_si=1.38064852 * 10**(-23)
    boltzmann=1.380645852 * 10 ** (-16) #Boltzmann constant in cm^2*g*s^(-2)*K^(-1)
    me=9.10938356 * 10 ** (- 31) #electron mass in kg
    mO=16 # Oxygen atomic mass in g/mol
    mN2=28  #N2 molecular mass in g/mol
    mO2=32 #O2 molecular mass in g/mol
    mNO=30 #NO molecular mass in g/mol
    NA=6.02214086 * 10 ** 23 #Avogadro's constant in mol^-1
    fcor=1.5 #Burnside facor (default=1.5)
    #TIEGCM = Dataset(DaedalusGlobals.TIEGCM_Files_Path +"TIEGCM_EVT1_2015_StPatricksDay_HAO/tiegcm_dres.s_mar2015_amie_v1_31.nc")
    TIEGCM = Dataset(tiegcm_file)
    # Get data from TIEGCM Model file
    glat = TIEGCM.variables['lat'][:] #geographic latitude in deg
    glon = TIEGCM.variables['lon'][:] #geographic longitude in deg
    glev = TIEGCM.variables['lev'][:] #interface levels
    gtime = TIEGCM.variables['time'][:] #time in minutes since 2015 March 15 00:00:00
    zg = TIEGCM.variables['ZGMID'][:] #Geometric height in cm
    Ne_all = TIEGCM.variables['NE'][:]  # electron density in cm^-3
    Ne_mid = TIEGCM.variables['ELECDEN'][:]  # electron density in cm^-3
    PED_all = TIEGCM.variables['PEDERSEN'][:] #Pedersen conductivity in Si/m
    HALL_all= TIEGCM.variables['HALL'][:] #Hall conductivity in Si/m
    Un_east = TIEGCM.variables['UN'][:]  # neutral zonal wind (+East) in cm/s
    Un_north = TIEGCM.variables['VN'][:]  # neutral meridional wind (+North) in cm/s
    Un_up = TIEGCM.variables['WN_lev'][:]  # neutral vertical wind (+Up) in cm/s
    Ui_east = TIEGCM.variables['Ui_lev'][:]  # zonal ExB velocity in cm/s
    Ui_north = TIEGCM.variables['Vi_lev'][:]  # meridional ExB velocity in cm/s
    Ui_up = TIEGCM.variables['Wi_lev'][:]  # vertical ExB velocity in cm/s
    Poten_all=TIEGCM.variables['POTEN'][:] #electric potential in V
    barm_all=TIEGCM.variables['BARM'][:] #Mean molecular weight in g/mol
    P0=TIEGCM.variables['p0'][:] #Reference pressure in millibar
    Zh=TIEGCM.variables['Z'][:] #dimensionless variable (for pressure calculations)
    Tn_all=TIEGCM.variables['TN'][:] #Neutral Temperature in K
    Te_all=TIEGCM.variables['TE'][:] #Electron Temperature in K
    Ti_all=TIEGCM.variables['TI'][:] #Ion Temperature in K
    nO_all=TIEGCM.variables['O1'][:] #neutral atomic oxygen density in mmr
    nO2_all=TIEGCM.variables['O2'][:] #neutral molecular oxygen density in mmr
    NOp_all=TIEGCM.variables['OP'][:] #O+ density in cm^-3
    den_all=TIEGCM.variables['DEN'][:] #Density
    nO_all_cm3=TIEGCM.variables['O_CM3'][:] #neutral atomic oxygen density in mmr
    nO2_all_cm3=TIEGCM.variables['O2_CM3'][:] #neutral molecular oxygen density in mmr
    NO2p_all=TIEGCM.variables['O2P'][:] #O+ density in cm^-3
    Np_all=TIEGCM.variables['NPLUS'][:] #N+ density in cm^-3
    NNOp_all=TIEGCM.variables['NOP_LAM'][:] #NO+ density in cm^-3
    N2_all_cm3=TIEGCM.variables['N2_CM3'][:] #O+ density in cm^-3
    EEX=TIEGCM.variables['EEX'][:] 
    EEY=TIEGCM.variables['EEY'][:] 
    EEZ=TIEGCM.variables['EEZ'][:] 
    QAMIE=TIEGCM.variables['QAMIE'][:] 
    QWIND=TIEGCM.variables['QWIND'][:]
    Argon_all=TIEGCM.variables['AR'][:]
    Helium_all=TIEGCM.variables['HE'][:]
    NitricOxide_all=TIEGCM.variables['NO'][:]
    Nitrogen_ion_all=TIEGCM.variables['NPLUS'][:]
    xnmbar_all=TIEGCM.variables['XNMBAR'][:]
    
    
    TIEGCM.close() #close input file
    



    #for timer in range(0, len(gtime)):
    for timer in range(timer_value,timer_value+1):
        time_plot=gtime[timer]
        maptime[timer]=time_plot

        for lev in range(0, len(glev)):
        #for lev in range(53, 54):
            
            #for lat in range(0, len(glat)):
            for lat in range(lat_value, lat_value+1):

                #for lon in range(0, len(glon)):
                for lon in range(lon_value, lon_value+1):
                    
                    ########################################################################
#                   Coordinates
                    ########################################################################
                    
                    alt_p = zg[timer, lev, lat, lon] / 1e5 #cm to km
                    lat_p=glat[lat]
                    lon_p = glon[lon]
                    lat_out.append(lat_p)
                    lon_out.append(lon_p)
                    zg1.append(alt_p)
                    timeg=gtime[timer]
                    #time
                    time_p = time_igrf + datetime.timedelta(minutes=timeg)

                    #Pressure levels
                    Z=glev[lev]
                    
                    #Pressure
                    pressuref=P0*np.exp(-Z) #pressure in millibars
                    pressuref_Pa=pressuref*100 #pressure in Pascals
                    Pressure.append(pressuref_Pa)
                    
                    #Electric Potential (V)
                    Pot=Poten_all[timer, lev, lat, lon]
                    
                    ########################################################################
#                   Temperatures and densities
                    ########################################################################

                    #Temperatures
                    Tn=Tn_all[timer, lev, lat, lon]     #Kelvin
                    Te=Te_all[timer, lev, lat, lon]     #Kelvin
                    Ti=Ti_all[timer, lev, lat, lon]     #Kelvin
                    
                    T_e.append(Te)
                    T_i.append(Ti)
                    T_n.append(Tn)

                    #mean molecular mass g/mol
                    barm=barm_all[timer, lev, lat, lon]
                    
                    #neutral Densities (cm^-3)
                    NO=nO_all_cm3[timer, lev, lat, lon] #cm^-3
                    NO2=nO2_all_cm3[timer, lev, lat, lon] #cm^-3                 
                    NN2=N2_all_cm3[timer, lev, lat, lon] #cm^-3
                    
                    nO1.append(NO)
                    nO21.append(NO2)
                    nN21.append(NN2)
                    
                    # electron density
                    Ne = Ne_mid[timer, lev, lat, lon] * (10 ** 6)  # m^-3
                    Necm=Ne_mid[timer, lev, lat, lon] 
                    Ne1.append(Ne*(10**(-6)))

                    #ion Densities
                    NOp=NOp_all[timer, lev, lat, lon]  #cm^-3
                    NO2p=NO2p_all[timer, lev, lat, lon]  #cm^-3
                    NOp1.append(NOp)
                    NO2p1.append(NO2p)
                    NNOp=NNOp_all[timer, lev, lat, lon]   #if O2+ density is available in the input file
                    NNOp1.append(NNOp) #output 

                    MO=mO/(NA*1000)  # Atomic oxygen mass in kg
                    MO2=(2*mO)/(NA*1000) # Molecular oxygen mass in kg
                    MNO=(mNO)/(NA*1000) #Nitric oxide mass in kg
                    MHe=4/(NA*1000)
                    MN=14/(NA*1000)
                    
                    #Conversion factor (mmr->cm^(-3))
                    Nbarm=(P0*np.exp(-Z)*barm*1000)/(boltzmann*Tn)
                    
                    Ar_argon=39.948
                    XNMBAR_f=xnmbar_all[timer, lev, lat, lon]
                    ARG=Argon_all[timer, lev, lat, lon]
                    HEL=Helium_all[timer, lev, lat, lon]
                    NITRIC=NitricOxide_all[timer, lev, lat, lon]
                    argon_f=(XNMBAR_f*ARG)/Ar_argon
                    Argon.append(argon_f)
                    Ar_helium=4.002
                    helium_f=(XNMBAR_f*HEL)/Ar_helium
                    Helium.append(helium_f)
                    Ar_NO=30
                    NO_f=(XNMBAR_f*NITRIC)/Ar_NO
                    NitricOxide.append(NO_f)
                    Nplus=Nitrogen_ion_all[timer, lev, lat, lon]
                    Nitrogen_ion.append(Nplus)
                    
                    ########################################################################
#                   Velocities
                    ########################################################################
                   

                    #neutral wind from ENU to ECEF
                    Un_x, Un_y, Un_z = enu_ecef(lat_p, lon_p, Un_east[timer, lev, lat, lon], Un_north[timer, lev, lat, lon],
                                                Un_up[timer, lev, lat, lon])  # cm/s on ECEF
                    Un_x = Un_x / 100  # m/s
                    Un_y = Un_y / 100  # m/s
                    Un_z = Un_z / 100  # m/s
                    Un = [Un_x, Un_y, Un_z] # neutral wind in ECEF in m/s

                    # ExB velocity from ENU to ECEF
                    Ui_x, Ui_y, Ui_z = enu_ecef(lat_p, lon_p, Ui_east[timer, lev, lat, lon], Ui_north[timer, lev, lat, lon],
                                                Ui_up[timer, lev, lat, lon])  # cm/s on ECEF
                    Ui_x = Ui_x / 100  # m/sec
                    Ui_y = Ui_y / 100  # m/sec
                    Ui_z = Ui_z / 100  # m/sec
                    Ui = [Ui_x, Ui_y, Ui_z]  # ExB in ECEF in m/s
                    
                    ########################################################################
#                   Magnetic and Electric fields
                    ########################################################################
                    
                    # Magnetic Field from ENU to ECEF
                    pt = pyglow.Point(time_p, lat_p, lon_p, alt_p)
                    pt.run_igrf()
                    Be = pt.Bx
                    Bn = pt.By
                    Bu = pt.Bz
                    Bx, By, Bz = enu_ecef(lat_p, lon_p, Be, Bn, Bu)  # Tesla in ECEF
                    B = [Bx, By, Bz]  # vector of magnetic field ECEF in Telsa
               
                    # Magnetic field unit vector
                    bnorm = np.sqrt(Bx * Bx + By * By + Bz * Bz)
                    b_unit = [Bx / bnorm, By / bnorm, Bz / bnorm]

                    #neutral wind perpendicular to the magnetic field
                    Unvert=np.cross(Un,b_unit)
                    Unvertx=Unvert[0]
                    Unverty=Unvert[1]
                    Unvertz=Unvert[2]
                    Unvertmag=np.sqrt(Unvert[0] * Unvert[0] + Unvert[1] * Unvert[1] + Unvert[2] * Unvert[2])
                    unvx1.append(Unvertx)
                    unvy1.append(Unverty)
                    unvz1.append(Unvertz)

                    #Electric Field perpendicular to the magnetic field
                    Evert=-np.cross(Ui,B)  #V/m
                    
                    Ee,En,Eu = ecef_enu(lat_p, lon_p, Evert[0], Evert[1], Evert[2])
                    
#                     Ee=Evert[0]
#                     En=Evert[1]
#                     Eu=Evert[2]

                    E_e.append(Ee)
                    E_n.append(En)
                    E_u.append(Eu)
                                       
                    #Perpendicular electric field in neutral atmosphere reference frame
#                     Estar=Evert+np.cross(Unvert,B)  #V/m
                                        #TIEGCM_Electric_field
                    Ee_TIEGCM=EEX[timer, lev, lat, lon]*100
                    En_TIEGCM=EEY[timer, lev, lat, lon]*100
                    Eu_TIEGCM=EEZ[timer, lev, lat, lon]*100
                    ETIEGCM=[Ee_TIEGCM,En_TIEGCM,Eu_TIEGCM]
                    Ee_T, En_T, Eu_T = enu_ecef(lat_p, lon_p,Ee_TIEGCM,En_TIEGCM, Eu_TIEGCM)
                    Evert2=[Ee_T,En_T,Eu_T]
                    
                    E_T_vert=np.cross(Evert2,b_unit)
                    Ee_T_vert=E_T_vert[0]
                    En_T_vert=E_T_vert[1]
                    Eu_T_vert=E_T_vert[2]
                    Ee_TIEGCM1.append(Ee_TIEGCM)
                    En_TIEGCM1.append(En_TIEGCM)
                    Eu_TIEGCM1.append(Eu_TIEGCM)
                                        
                    #Calculate ExB velocities in ECEF
                    ExBcalc=np.cross(E_T_vert,b_unit)/(bnorm)
                    ExBx1.append(ExBcalc[0])
                    ExBy1.append(ExBcalc[1])
                    ExBz1.append(ExBcalc[2])
                                        
                    Estar=E_T_vert+np.cross(Unvert,B)

                    ########################################################################
#                   Gyrofrequencies and collision frequencies
                    ########################################################################
                   
                    #gyrofrequencies (Hz)
                    bgauss=bnorm*10000
                    qeomeo10=1.7588028*10**7
                    qeoNa010=9.6489*10**3
                    rmassinv_op=1/mO
                    rmassinv_nop=1/mNO
                    rmassinv_o2p=1/mO2
                    
                    omega_op=qeoNa010*bgauss*rmassinv_op
                    omega_o2p=qeoNa010*bgauss*rmassinv_o2p
                    omega_nop=qeoNa010*bgauss*rmassinv_nop
                    omega_op_inv=1/omega_op
                    omega_o2p_inv=1/omega_o2p
                    omega_nop_inv=1/omega_nop
                    omega_e=qeomeo10*bgauss
                    omega_e_inv=1/omega_e
                    
                    omega_e1.append(omega_e)
                    omega_Op1.append(omega_op)
                    omega_O2p1.append(omega_o2p)
                    omega_NOp1.append(omega_nop)
                    
            
                    #collision frequencies (Hz)
                    temps=(Ti+Tn)/2
                    
                    rnu_o2p_o2=2.59 * (10**(-11))* np.sqrt(temps)*((1-0.073*np.log10(temps))**2)
                    rnu_op_o2=6.64 * (10**(-10))
                    rnu_nop_o2=4.27 * (10**(-10))
                    rnu_np_o2=7.25 * (10**(-10))
                    
                    rnu_o2p_o=2.31*(10**(-10))
                    rnu_op_o=3.67 * (10**(-11)) * np.sqrt(temps)*((1-0.064*np.log10(temps))**2)*fcor
                    rnu_nop_o=2.44 * (10**(-10))
                    rnu_np_o=4.42 * (10**(-10))
                    
                    rnu_o2p_n2=4.13*(10**(-10))
                    rnu_op_n2=6.82 * (10**(-10))
                    rnu_nop_n2=4.34*(10**(-10))
                    rnu_np_n2=7.47*(10**(-10))
                    
                    rnu_o2p_he=0.7* (10**(-10))
                    rnu_op_he=1.32* (10**(-10))
                    rnu_nop_he=0.74* (10**(-10))
                    rnu_np_he=1.49*(10**(-10))
                    
                    rnu_o2p=(rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2)*omega_o2p_inv
                    rnu_op=(rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2)*omega_op_inv
                    rnu_nop=(rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2)*omega_nop_inv
                    
                    
                    vOp=rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2
                    vO2p=rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2
                    vNOp=rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2
                    vin=vOp+vO2p+vNOp
                    
                   
                    vop_o=rnu_op_o*NO
                    vop_o2=rnu_op_o2*NO2
                    vop_n2=rnu_op_n2*NN2
                    vo2p_o=rnu_o2p_o*NO
                    vo2p_o2=rnu_o2p_o2*NO2
                    vo2p_n2=rnu_o2p_n2*NN2
                    vnop_o=rnu_nop_o*NO
                    vnop_o2=rnu_nop_o2*NO2
                    vnop_n2=rnu_nop_n2*NN2
                    vop_he=rnu_op_he*helium_f
                    vo2p_he=rnu_o2p_he*helium_f
                    vnop_he=rnu_nop_he*helium_f
                    vnp_o=rnu_np_o*NO
                    vnp_o2=rnu_np_o2*NO2
                    vnp_n2=rnu_np_n2*NN2
                    vnp_he=rnu_np_he*helium_f
                    
                    
                    ven=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))
                    
                    ve_n2=2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te)))
                    ve_o=8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te)))
                    ve_o2=1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te))))
                    ve_he=4.6* (10**(-10))*helium_f*np.sqrt(Te)
                    
                    rnu_ne=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))*omega_e_inv
                    rnu_ne=4*rnu_ne
                    
                    vOp1.append(vOp)
                    vO2p1.append(vO2p)
                    vNOp1.append(vNOp)
                    vin1.append(vin)
                    
                    #electron-ion (Coulomb collisions)
                    
                    ve_op=(54.5*NOp)/(Te**(1.5))
                    ve_o2p=(54.5*NO2p)/(Te**(1.5))
                    ve_nop=(54.5*NNOp)/(Te**(1.5))
                    ve_np=(54.5*Nplus)/(Te**(1.5))
                    ve_i=ve_op+ve_o2p+ve_nop+ve_np
                    vei.append(ve_i)
                    

                    
                    ########################################################################
#                   Conductivities
                    ########################################################################                
                    
                    qe_fac=(electron*10**10)/bgauss
                    Necm2=NOp+NO2p+NNOp
                    sigmaPed=qe_fac*((NOp*rnu_op/(1+rnu_op**2))+(NO2p*rnu_o2p/(1+rnu_o2p**2)) \
                                    +(NNOp*rnu_nop/(1+rnu_nop**2))+Necm2*rnu_ne/(1+rnu_ne**2))
                    
                    sigmaHall=qe_fac*(Necm2/(1+rnu_ne**2)-NOp/(1+rnu_op**2)-NO2p/(1+rnu_o2p**2)-NNOp/(1+rnu_nop**2))
                    

                    sigmaPed1.append(sigmaPed)

                    sigmaHall1.append(sigmaHall)


                    #Parallel conductivity
                    sigma0=(Ne*electron*electron)/(me*ven)
                    sigma01.append(sigma0)
                    
                    sP_tiegcm=PED_all[timer, lev, lat, lon]
                    sH_tiegcm=HALL_all[timer, lev, lat, lon]
                    sigmaPed1TIEGCM.append(sP_tiegcm)
                    sigmaHall1TIEGCM.append(sH_tiegcm)
                    
                    ########################################################################
#                   Velocities
                    ########################################################################
                    
                    #Ion Velocity in neutral reference frame (formula derived through ion momentum equation)
                    vi_op_star=(vOp*omega_op*Estar+omega_op**2*(np.cross(Estar,b_unit)))/(bnorm*(vOp**2+omega_op**2))
                    vi_op_starx=vi_op_star[0] #m/s
                    vi_op_stary=vi_op_star[1] #m/s
                    vi_op_starz=vi_op_star[2] #m/s
                    vi_op_starmag=np.sqrt(vi_op_star[0] * vi_op_star[0] + vi_op_star[1] * vi_op_star[1] + vi_op_star[2] * vi_op_star[2])

                    vi_op_x=vi_op_starx+Unvertx #from neutral frame to ECEF
                    vi_op_y=vi_op_stary+Unverty #from neutral frame to ECEF
                    vi_op_z=vi_op_starz+Unvertz #from neutral frame to ECEF
                    vi_op=[vi_op_x,vi_op_y,vi_op_z]
                    vi_op_x1.append(vi_op_x)
                    vi_op_y1.append(vi_op_y)
                    vi_op_z1.append(vi_op_z)
                    
                    vi_o2p_star=(vO2p*omega_o2p*Estar+omega_o2p**2*(np.cross(Estar,b_unit)))/(bnorm*(vO2p**2+omega_o2p**2))
                    vi_o2p_starx=vi_o2p_star[0] #m/s
                    vi_o2p_stary=vi_o2p_star[1] #m/s
                    vi_o2p_starz=vi_o2p_star[2] #m/s
                    vi_o2p_starmag=np.sqrt(vi_o2p_star[0] * vi_o2p_star[0] + vi_o2p_star[1] * vi_o2p_star[1] + vi_o2p_star[2] * vi_o2p_star[2])

                    vi_o2p_x=vi_o2p_starx+Unvertx #from neutral frame to ECEF
                    vi_o2p_y=vi_o2p_stary+Unverty #from neutral frame to ECEF
                    vi_o2p_z=vi_o2p_starz+Unvertz #from neutral frame to ECEF
                    vi_o2p=[vi_o2p_x,vi_o2p_y,vi_o2p_z]
                    vi_o2p_x1.append(vi_o2p_x)
                    vi_o2p_y1.append(vi_o2p_y)
                    vi_o2p_z1.append(vi_o2p_z)
                    
                    vi_nop_star=(vNOp*omega_nop*Estar+omega_nop**2*(np.cross(Estar,b_unit)))/(bnorm*(vNOp**2+omega_nop**2))
                    vi_nop_starx=vi_nop_star[0] #m/s
                    vi_nop_stary=vi_nop_star[1] #m/s
                    vi_nop_starz=vi_nop_star[2] #m/s
                    vi_nop_starmag=np.sqrt(vi_nop_star[0] * vi_nop_star[0] + vi_nop_star[1] * vi_nop_star[1] + vi_nop_star[2] * vi_nop_star[2])

                    vi_nop_x=vi_nop_starx+Unvertx #from neutral frame to ECEF
                    vi_nop_y=vi_nop_stary+Unverty #from neutral frame to ECEF
                    vi_nop_z=vi_nop_starz+Unvertz #from neutral frame to ECEF
                    vi_nop_x1.append(vi_nop_x)
                    vi_nop_y1.append(vi_nop_y)
                    vi_nop_z1.append(vi_nop_z)

                    #Electron Velocity in neutral reference frame (formula derived through electron momentum equation)
                    ve_star=(-ven*omega_e*Estar+omega_e**2*(np.cross(Estar,b_unit)))/(bnorm*(ven**2+omega_e**2))
                    ve_starx=ve_star[0] #m/s
                    ve_stary=ve_star[1] #m/s
                    ve_starz=ve_star[2] #m/s
                    ve_starmag=np.sqrt(ve_star[0] * ve_star[0] + ve_star[1] * ve_star[1] + ve_star[2] * ve_star[2])

                    ve_xtemp=ve_starx+Unvertx #from neutral frame to ECEF
                    ve_ytemp=ve_stary+Unverty #from neutral frame to ECEF
                    ve_ztemp=ve_starz+Unvertz #from neutral frame to ECEF

                                      
                    ve_x1.append(ve_xtemp)
                    ve_y1.append(ve_ytemp)
                    ve_z1.append(ve_ztemp)


                    ########################################################################
#                     Magnetic parameters
                    ########################################################################
    
                    dipmag=np.arctan(Bz/np.sqrt(By**2+Bx**2))
                    sndip=np.sin(dipmag)
                    decmag=np.arctan2(By,Bx)
                    sndec=np.sin(decmag)
                    sn2dec=sndec**2
                    csdec=np.cos(decmag)
                    tm1=sn2dec+(1-sn2dec)*sndip**2
                    tm2=(1-sn2dec)+sn2dec*sndip**2
                    tm3=sndec*csdec*(1-sndip**2)
    
                    ##########################################################################
#                   Ohmic Heating 
                    ##########################################################################     
        
                    # heating rates (W/m^3)
                    A=E_T_vert+np.cross(Unvert,B)
#                     L=np.sqrt(A[0] * A[0] + A[1] * A[1] + A[2] * A[2])

                    Ohmic=sP_tiegcm*np.dot(A,A)
                    Ohmic1.append(Ohmic)
#                     Ohmic2=sigmaPed*L*L

                    
                    ##########################################################################
#                     Joule Heating - Frictional Heating
                    ##########################################################################
                    Joule_op=electron*NOp*(10**6)*np.dot(vi_op_star,A)
                    Joule_o2p=electron*NO2p*(10**6)*np.dot(vi_o2p_star,A)
                    Joule_nop=electron*NNOp*(10**6)*np.dot(vi_nop_star,A)
                    Joule=Joule_op+Joule_o2p+Joule_nop
                    Joule1.append(Joule)
                    Frictional_op=MO*NOp*(10**6)*vOp*vi_op_starmag*vi_op_starmag
                    Frictional_o2p=MO2*NO2p*(10**6)*vO2p*vi_o2p_starmag*vi_o2p_starmag
                    Frictional_nop=MNO*NNOp*(10**6)*vNOp*vi_nop_starmag*vi_nop_starmag
                    Frictional=Frictional_op+Frictional_o2p+Frictional_nop

                    Frictional1.append(Frictional)
                    # Ohmic_TIEGCM[timer, lev, lat, lon]=TIEGCM_PED*L*L
                    rho=den_all[timer, lev, lat, lon]*1000
                    JH_rhovert=Ohmic/rho #W/kg
                    JH_rhov.append(JH_rhovert)

                    ##########################################################################
#                   Convection Heating - Wind Correction
                    ##########################################################################
                    ExB=np.cross(E_T_vert,B)
                    UNxB=np.cross(Unvert,B)
                    UNxBmag=np.sqrt(UNxB[0] * UNxB[0] + UNxB[1] * UNxB[1] + UNxB[2] * UNxB[2])
                    
                    Convenction_heating=sP_tiegcm*np.dot(E_T_vert,E_T_vert)
                    convection1.append(Convenction_heating)
#                     Wind_heating=sP_tiegcm*UNxBmag*UNxBmag-2*sP_tiegcm*np.dot(Un,ExB)
#                     Wind_heating=sP_tiegcm*((Bx**2+By**2)*Un_x**2+(By**2+Bz**2)*Un_y**2-2*Bx*By*Un_x*Un_y -\
#                                            2*bnorm**2*Ui_x*Un_x-2*bnorm**2*Ui_y*Un_y)
                    Wind_heating=sP_tiegcm*bnorm**2*(tm2*Un_x**2+tm1*Un_y**2-2*tm3*Un_x*Un_y-2*(Un_x*Ui_x+Un_y*Ui_y))
                    wind1.append(Wind_heating)
                    
                    QAMIEf=QAMIE[timer, lev, lat, lon]/1000
                    QAMIE1.append(QAMIEf)
                    QWINDf=QWIND[timer, lev, lat, lon]/1000
                    QWIND1.append(QWINDf)
                                                            
                    Ohmic_heating_OhmsLaw=QAMIEf+QWINDf
                    ohms_ohmic.append(Ohmic_heating_OhmsLaw)
                    
                    ##########################################################################
#                   Ohmic per Pressure/ Pressure per Ohmic
                    ##########################################################################

                    
                    ohmic_pressure_tmp=Ohmic/pressuref_Pa
                    ohmic_pressure.append(ohmic_pressure_tmp)
                    
                    pressure_ohmic_tmp=pressuref_Pa/Ohmic
                    pressure_ohmic.append(pressure_ohmic_tmp)
                    
                    ##########################################################################
#                   Electric Currents
                    ##########################################################################
                    
                    J_Pedersen=sigmaPed*Estar
                    J_Hall=sigmaHall*np.cross(b_unit,Estar)
                    
                    Jpe,Jpn,Jpu = ecef_enu(lat_p, lon_p, J_Pedersen[0], J_Pedersen[1],J_Pedersen[2])
                    Jhe,Jhn,Jhu = ecef_enu(lat_p, lon_p, J_Hall[0], J_Hall[1],J_Hall[2])
                    
                    J_pe.append(Jpe)
                    J_pn.append(Jpn)
                    J_pu.append(Jpu)
                    J_he.append(Jhe)
                    J_hn.append(Jhn)
                    J_hu.append(Jhu)

                    #perpendicular electric current density (A/m^2) (Ohm's LaW)
                    J_p_Ohmic=sigmaPed*Estar+sigmaHall*np.cross(b_unit,Estar)
                    J_p_Ohmicx=J_p_Ohmic[0]
                    J_p_Ohmicy=J_p_Ohmic[1]
                    J_p_Ohmicz=J_p_Ohmic[2]
                    
                    JOhme,JOhmn,JOhmu= ecef_enu(lat_p, lon_p, J_p_Ohmic[0], J_p_Ohmic[1],J_p_Ohmic[2])
                    
                    J_p_Ohmice.append(JOhme)
                    J_p_Ohmicn.append(JOhmn)
                    J_p_Ohmicu.append(JOhmu)
                    
                    

                    #perpendicular electric current density (A/m^2) (from current definition)
                    J_den=electron*Ne*(vi_op_star-ve_star)
                    J_denx=J_den[0]
                    J_deny=J_den[1]
                    J_denz=J_den[2]
                    
                    J_p_den_e,J_p_den_n,J_p_den_u= ecef_enu(lat_p, lon_p, J_den[0], J_den[1],J_den[2])
                    J_dene.append(J_p_den_e)
                    J_denn.append(J_p_den_n)
                    J_denu.append(J_p_den_u)

#                     #JxB forcing
#                     # JxB=np.cross(J_p_Ohmic,B)
#                     # JxBx=JxB[0]
#                     # JxBy=JxB[1]
#                     # JxBz=JxB[2]
                    
                    ##########################################################################
#                   Collision cross sections
                    ##########################################################################
    
                    N_neutral=(NO2+NN2+NO)*10**6
                    MN2=(mN2)/(NA*1000)
                    M_ion=MO+MO2+MNO
                    
                    cross=(vin/N_neutral)/(np.sqrt((2*boltzmann*Ti)/M_ion))
                    cross_sectionf.append(cross)
                    
                    cross_op=(vOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO))
                    cross_op_sectionf.append(cross_op)
                    
                    cross_o2p=(vO2p/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO2))
                    cross_o2p_sectionf.append(cross_o2p)
                    
                    cross_nop=(vNOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MNO))
                    cross_nop_sectionf.append(cross_nop)
                    
                    ##########################################################################
#                     Ion heating rates
                    ##########################################################################
    
                    qDTop_of=3*NOp*(10 ** 6)*boltzmann_si*vop_o*(MO/(MO+MO))*(Ti-Tn)
                    qDTop_o2f=3*NOp*(10 ** 6)*boltzmann_si*vop_o2*(MO/(MO2+MO))*(Ti-Tn)
                    qDTop_n2f=3*NOp*(10 ** 6)*boltzmann_si*vop_n2*(MO/(MN2+MO))*(Ti-Tn)
                    qDTop_hef=3*NOp*(10 ** 6)*boltzmann_si*vop_he*(MO/(MHe+MO))*(Ti-Tn)
                    qDTo2p_of=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o*(MO2/(MO+MO2))*(Ti-Tn)
                    qDTo2p_o2f=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o2*(MO2/(MO2+MO2))*(Ti-Tn)
                    qDTo2p_n2f=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_n2*(MO2/(MN2+MO2))*(Ti-Tn)
                    qDTo2p_hef=3*NO2p*(10 ** 6)*boltzmann_si*vop_he*(MO2/(MHe+MO2))*(Ti-Tn)
                    qDTnop_of=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o*(MNO/(MO+MNO))*(Ti-Tn)
                    qDTnop_o2f=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o2*(MNO/(MO2+MNO))*(Ti-Tn)
                    qDTnop_n2f=3*NNOp*(10 ** 6)*boltzmann_si*vnop_n2*(MNO/(MN2+MNO))*(Ti-Tn)
                    qDTnop_hef=3*NNOp*(10 ** 6)*boltzmann_si*vop_he*(MNO/(MHe+MNO))*(Ti-Tn)
                    
                    qDTop_nf=qDTop_of+qDTop_o2f+qDTop_n2f+qDTop_hef
                    qDTo2p_nf=qDTo2p_of+qDTo2p_o2f+qDTo2p_n2f+qDTo2p_hef
                    qDTnop_nf=qDTnop_of+qDTnop_o2f+qDTnop_n2f+qDTnop_hef
                    
                    
                    qDTi_nf=qDTop_nf+qDTo2p_nf+qDTnop_nf
                    
                    qDTop_o.append(qDTop_of)
                    qDTop_o2.append(qDTop_o2f)
                    qDTop_n2.append(qDTop_n2f)
                    qDTop_he.append(qDTop_hef)
                    qDTo2p_o.append(qDTo2p_of)
                    qDTo2p_o2.append(qDTo2p_o2f)
                    qDTo2p_n2.append(qDTo2p_n2f)
                    qDTo2p_he.append(qDTo2p_hef)
                    qDTnop_o.append(qDTnop_of)
                    qDTnop_o2.append(qDTnop_o2f)
                    qDTnop_n2.append(qDTnop_n2f)
                    qDTnop_he.append(qDTnop_hef)
                    
                    qDTop_n.append(qDTop_nf)
                    qDTo2p_n.append(qDTo2p_nf)
                    qDTnop_n.append(qDTnop_nf)
                    
                    qDTi_n.append(qDTi_nf)
                    
                    ##########################################################################
#                   Cooling rates
                    ##########################################################################                    
                    #N2 rotation
                    Le_N2_rotf=((3.5*10**(-14)*Necm*NN2*(Te-Tn))/np.sqrt(Te))*1.60217662*10**(-13)
                    Le_N2_rot.append(Le_N2_rotf)
                    #O2 rotation
                    Le_O2_rotf=((5.2*10**(-15)*Necm*NO2*(Te-Tn))/np.sqrt(Te))*1.60217662*10**(-13)
                    Le_O2_rot.append(Le_O2_rotf)
                    #O2 vibration
                    
                    logQ_Te=-19.9171+0.0267*Te-3.9960*(10**(-5))*(Te**2) \
                            +3.5187*(10**(-8))*(Te**3)-1.9228*(10**(-11))*(Te**4) \
                            +6.6865*(10**(-15))*(Te**5)-1.4791*(10**(-18))*(Te**6) \
                            +2.0127*(10**(-22))*(Te**7)-1.5346*(10**(-26))*(Te**8) \
                            +5.0148*(10**(-31))*(Te**9)
                    Q_Te=10**(logQ_Te)
                            
                    
                    
                    Le_O2_vibf=(Necm*NO2*Q_Te*(1-np.exp(2239*(Te**(-1)-Tn**(-1)))))*1.60217662*10**(-13) 
                    Le_O2_vib.append(Le_O2_vibf)
                    
                    #N2 vibration
                    
                    
                    
                    #O fine structure
                    D=5+np.exp(-326.6/Tn)+3*np.exp(-227.7/Tn)
                    S21=1.863*10**(-11)
                    S20=1.191*10**(-11)
                    S10=8.249*10**(-16)*Te**(0.6)*np.exp(-227.7/Tn)
                    
                    Le_O_finef=(((Necm*NO)/D)*((S10*(1-np.exp(98.9*(1/Te-1/Tn)))) \
                                               +S20*(1-np.exp(326.6*(1/Te-1/Tn))) \
                                               +S21*(1-np.exp(227.7*(1/Te-1/Tn)))))*1.60217662*10**(-13)                  
                    Le_O_fine.append(Le_O_finef)
                    
                    #O(1D) excitation
                    d_i=2.4*10**4+0.3*(Te-1500)-1.947*(10**(-5))*(Te-1500)*(Te-4000)
                    
                    Le_O_1Df=(1.57*10**(-12)*Necm*NO*np.exp(d_i*((Te-3000)/(3000*Te))) \
                              *(np.exp(-22713*((Te-Tn)/(Te*Tn)))-1))*1.60217662*10**(-13)
                    Le_O_1D.append(Le_O_1Df)
                    
                    #electron cooling rates sum
                    Lef=Le_N2_rotf+Le_O2_rotf+Le_O2_vibf+Le_O_finef+Le_O_1Df
                    Le1.append(Lef)
                    
                    #Electron neutral elastic collisions
                    qDTe_of=3*Necm*(10 ** 6)*boltzmann_si*ve_o*(me/(me+MO))*(Te-Tn)
                    qDTe_o2f=3*Necm*(10 ** 6)*boltzmann_si*ve_o2*(me/(me+MO2))*(Te-Tn)
                    qDTe_n2f=3*Necm*(10 ** 6)*boltzmann_si*ve_n2*(me/(me+MN2))*(Te-Tn)
                    qDTe_hef=3*Necm*(10 ** 6)*boltzmann_si*ve_he*(me/(me+MHe))*(Te-Tn)
                    
                    qDTe_n_elastic=qDTe_of+qDTe_o2f+qDTe_n2f+qDTe_hef
                    
                    qDTe_o.append(qDTe_of)
                    qDTe_o2.append(qDTe_o2f)
                    qDTe_n2.append(qDTe_n2f)
                    qDTe_he.append(qDTe_hef)
                    qDTe_n.append(qDTe_n_elastic)
                    
                    #electron-ion collisons
                    
                    Te_op=(me*Ti+MO*Te)/(MO+me)
                    mu_eop=(me*MO)/(me+MO)
                    ue_op=np.sqrt((vi_op_starx-ve_starx)**2+(vi_op_stary-ve_stary)**2+(vi_op_starz-ve_starz)**2)
                    eps_eop=ue_op/np.sqrt(2*boltzmann_si*Te_op/mu_eop)
                    Psi_eop=np.exp(-eps_eop**2)
                    Phi_eop= ((3*np.sqrt(np.pi))/4)*((erf(eps_eop))/(eps_eop**3))-1.5*(eps_eop**(-2))*np.exp(-eps_eop**2)
                    
#                     print(Psi_eop,Phi_eop)
                    qDTe_opf=3*Necm*(10 ** 6)*boltzmann_si*ve_op*(me/(me+MO))*(Te-Ti)*Psi_eop+\
                            (Necm*(10 ** 6)*ve_op*(me*MO/(me+MO)))*Phi_eop
                    
                    qDTe_o2pf=3*Necm*(10 ** 6)*boltzmann_si*ve_o2p*(me/(me+MO2))*(Te-Ti)
                    qDTe_nopf=3*Necm*(10 ** 6)*boltzmann_si*ve_nop*(me/(me+MNO))*(Te-Ti)
                    qDTe_npf=3*Necm*(10 ** 6)*boltzmann_si*ve_np*(me/(me+MN))*(Te-Ti)
                    qDTe_if=qDTe_opf+qDTe_o2pf+qDTe_nopf+qDTe_npf
                    qDTe_op.append(qDTe_opf)
                    qDTe_o2p.append(qDTe_o2pf)
                    qDTe_np.append(qDTe_npf)
                    qDTe_nop.append(qDTe_nopf)  
                    qDTe_i.append(qDTe_if)
                    
                    #Stephan's cross section formula
                    A1=E_T_vert+np.cross(vi_op,B)
                    A1mag=np.sqrt(A1[0]**2+A1[1]**2+A1[2]**2)
                    vi_op2=np.cross(vi_op,b_unit)
                    B1=vi_op-Unvert
                    B1mag=np.sqrt(B1[0]**2+B1[1]**2+B1[2]**2)
                    vop_n_SBf=(electron/MO)*(A1mag/B1mag)
                    vop_n_SB.append(vop_n_SBf)
                    
                    A12=E_T_vert+np.cross(vi_o2p,B)
                    A1mag2=np.sqrt(A12[0]**2+A12[1]**2+A12[2]**2)
                    vi_o2p2=np.cross(vi_o2p,b_unit)
                    B12=vi_o2p-Unvert
                    B1mag2=np.sqrt(B12[0]**2+B12[1]**2+B12[2]**2)
                    vo2p_n_SBf=(electron/MO2)*(A1mag2/B1mag2)
                    vo2p_n_SB.append(vo2p_n_SBf)
                    warnings.simplefilter('ignore')

                    
    print("Calculation executed!")
    print("Total run time: %s seconds" % (time.time() - start_time))

#Calculation of products for map plotting
def lat_alt(tiegcm_file,timer_value,lon_value):
    # Initializations
    start_time = time.time()
    time_igrf = datetime.datetime(2015, 3, 15, 0, 0, 0)  # first time step of the TIEGCM run
    timer = 0  # counter used for incrementing TIEGCM timestep
    deltalmd = 2.5  # TIEGCM grid resolution in deg
    deltaphi = 2.5  # TIEGCM grid resolution in deg
    Re = 6378.1370  # Earths Radius (km)
    electron = 1.602176565 * 10 ** (- 19) #electron charge in C
    boltzmann_si=1.38064852 * 10**(-23)
    boltzmann=1.380645852 * 10 ** (-16) #Boltzmann constant in cm^2*g*s^(-2)*K^(-1)
    me=9.10938356 * 10 ** (- 31) #electron mass in kg
    mO=16 # Oxygen atomic mass in g/mol
    mN2=28  #N2 molecular mass in g/mol
    mO2=32 #O2 molecular mass in g/mol
    mNO=30 #NO molecular mass in g/mol
    NA=6.02214086 * 10 ** 23 #Avogadro's constant in mol^-1
    fcor=1.5 #Burnside facor (default=1.5)
    
    #Input file
    TIEGCM = Dataset(tiegcm_file)

    # Get data from TIEGCM Model file
    glat = TIEGCM.variables['lat'][:] #geographic latitude in deg
    glon = TIEGCM.variables['lon'][:] #geographic longitude in deg
    glev = TIEGCM.variables['lev'][:] #interface levels
    gtime = TIEGCM.variables['time'][:] #time in minutes since 2015 March 15 00:00:00
    zg = TIEGCM.variables['ZGMID'][:] #Geometric height in cm
    Ne_all = TIEGCM.variables['NE'][:]  # electron density in cm^-3
    Ne_mid = TIEGCM.variables['ELECDEN'][:]  # electron density in cm^-3
    PED_all = TIEGCM.variables['PEDERSEN'][:] #Pedersen conductivity in Si/m
    HALL_all= TIEGCM.variables['HALL'][:] #Hall conductivity in Si/m
    Un_east = TIEGCM.variables['UN'][:]  # neutral zonal wind (+East) in cm/s
    Un_north = TIEGCM.variables['VN'][:]  # neutral meridional wind (+North) in cm/s
    Un_up = TIEGCM.variables['WN_lev'][:]  # neutral vertical wind (+Up) in cm/s
    Ui_east = TIEGCM.variables['Ui_lev'][:]  # zonal ExB velocity in cm/s
    Ui_north = TIEGCM.variables['Vi_lev'][:]  # meridional ExB velocity in cm/s
    Ui_up = TIEGCM.variables['Wi_lev'][:]  # vertical ExB velocity in cm/s
    Poten_all=TIEGCM.variables['POTEN'][:] #electric potential in V
    barm_all=TIEGCM.variables['BARM'][:] #Mean molecular weight in g/mol
    P0=TIEGCM.variables['p0'][:] #Reference pressure in millibar
    Zh=TIEGCM.variables['Z'][:] #dimensionless variable (for pressure calculations)
    Tn_all=TIEGCM.variables['TN'][:] #Neutral Temperature in K
    Te_all=TIEGCM.variables['TE'][:] #Electron Temperature in K
    Ti_all=TIEGCM.variables['TI'][:] #Ion Temperature in K
    nO_all=TIEGCM.variables['O1'][:] #neutral atomic oxygen density in mmr
    nO2_all=TIEGCM.variables['O2'][:] #neutral molecular oxygen density in mmr
    NOp_all=TIEGCM.variables['OP'][:] #O+ density in cm^-3
    den_all=TIEGCM.variables['DEN'][:] #Density
    nO_all_cm3=TIEGCM.variables['O_CM3'][:] #neutral atomic oxygen density in mmr
    nO2_all_cm3=TIEGCM.variables['O2_CM3'][:] #neutral molecular oxygen density in mmr
    NO2p_all=TIEGCM.variables['O2P'][:] #O+ density in cm^-3
    Np_all=TIEGCM.variables['NPLUS'][:] #N+ density in cm^-3
    NNOp_all=TIEGCM.variables['NOP_LAM'][:] #NO+ density in cm^-3
    N2_all_cm3=TIEGCM.variables['N2_CM3'][:] #N2 density in cm^-3
    EEX=TIEGCM.variables['EEX'][:] 
    EEY=TIEGCM.variables['EEY'][:] 
    EEZ=TIEGCM.variables['EEZ'][:] 
    QAMIE=TIEGCM.variables['QAMIE'][:] 
    QWIND=TIEGCM.variables['QWIND'][:]
    TIEGCM.close() #close input file


    for timer in range(timer_value,timer_value+1):
        time_plot=gtime[timer]
        maptimel[timer]=time_plot
        
        for lev in range(0, len(glev)-1):
        
            for lat in range(0, len(glat)):

                for lon in range(lon_value, lon_value+1):
                    
                    ########################################################################
#                   Coordinates
                    ########################################################################
                    
                    # GEO coordinates of desired point
                    alt_p = zg[timer, lev, lat, lon] / 1e5 #cm to km
                    zgfl[lev, lat]=alt_p #output 
                    lat_p = glat[lat]   #deg
                    lon_p = glon[lon]   #deg
                    timeg=gtime[timer] #minutes
                    maplatl[lat]=glat[lat] #output 
#                     maplonl[lon]=glon[lon]
                    mapaltl[lev]=alt_p
                    #time
                    time_p = time_igrf + datetime.timedelta(minutes=timeg)               
                   
                    #Pressure levels
                    Z=glev[lev]
                    
                    pressuref=P0*np.exp(-Z) #pressure in millibars
                    pressuref_Pa=pressuref*100 #pressure in Pascals
#                     Pressure_2Dl[lat,lon]=pressuref_Pa
                    
                    #Electric Potential (V)
                    Pot=Poten_all[timer, lev, lat, lon]
                    Potfl[lev, lat]=Pot #output 
                    
                    ########################################################################
#                   Temperatures and densities
                    ########################################################################

                    #Temperatures
                    Tn=Tn_all[timer, lev, lat, lon]     #Kelvin
                    Te=Te_all[timer, lev, lat, lon]     #Kelvin
                    Ti=Ti_all[timer, lev, lat, lon]     #Kelvin
                    
                    Ti_Outl[lev, lat]=Ti
                    Te_Outl[lev, lat]=Te
                    Tn_Outl[lev, lat]=Tn
                    
                    #mean molecular mass g/mol
                    barm=barm_all[timer, lev, lat, lon]

                    #Conversion factor (mmr->cm^(-3))
                    Nbarm=(P0*np.exp(-Z)*barm*1000)/(boltzmann*Tn)

                    #neutral Densities (cm^-3)
                    NO=nO_all_cm3[timer, lev, lat, lon] #cm^-3
                    NOfl[lev, lat]=NO* (10 ** 6) #output m^-3
                    NO2=nO2_all_cm3[timer, lev, lat, lon] #cm^-3                 
                    NO2fl[lev, lat]=NO2* (10 ** 6) #output m^-3
                    NN2=N2_all_cm3[timer, lev, lat, lon] #cm^-3
                    NN2fl[lev, lat]=NN2* (10 ** 6) #output m^-3

                    # electron density
                    Ne = Ne_all[timer, lev, lat, lon] * (10 ** 6)  # m^-3
                    Nefl[lev, lat]=Ne #output m^-3
                    Necm=Ne_all[timer, lev, lat, lon] # (cm^-3)

                    #ion Densities
                    NOp=NOp_all[timer, lev, lat, lon]  #cm^-3
                    NO2p=NO2p_all[timer, lev, lat, lon]  #cm^-3
                    NOpfl[lev, lat]=NOp #output 
                    NO2pfl[lev, lat]=NOp #output 
                    NNOp=Necm-NOp+NO2p  #if O2+ density is available in the input file
                    NNOpfl[lev, lat]=NNOp #output 
                    
                    
                    MO=mO/(NA*1000)  # Atomic oxygen mass in kg
                    MO2=(2*mO)/(NA*1000) # Molecular oxygen mass in kg
                    MNO=(mNO)/(NA*1000) #Nitric oxide mass in kg
                    
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #neutral wind 
                    Une=Un_east[timer, lev, lat, lon]
                    Unn=Un_north[timer, lev, lat, lon]
                    Unu=Un_up[timer, lev, lat, lon]

                    Un_x = Une / 100  # m/s
                    Un_y = Unn / 100  # m/s
                    Un_z = Unu / 100  # m/s
                    Un = [Un_x, Un_y, Un_z] # neutral wind in ENU in m/s
                    
                    Unefl[lev, lat]=Un_x #output (ENU)
                    Unnfl[lev, lat]=Un_y #output (ENU)  
                    Unufl[lev, lat]=Un_z #output (ENU)  
                    

                    # ExB velocity from ENU to ECEF
                    Uie=Ui_east[timer, lev, lat, lon]
                    Uin=Ui_north[timer, lev, lat, lon]
                    Uiu=Ui_up[timer, lev, lat, lon]

                    Ui_x = Uie / 100  # m/sec
                    Ui_y = Uin / 100  # m/sec
                    Ui_z = Uiu / 100  # m/sec
                    Ui = [Ui_x, Ui_y, Ui_z]  # ExB in ENU in m/s
                    
                    ########################################################################
#                   Magnetic and Electric fields
                    ########################################################################
                    
                    # Magnetic Field from ENU to ECEF
                    pt = pyglow.Point(time_p, lat_p, lon_p, alt_p) # pyglow igrf
                    pt.run_igrf()
                    Be = pt.Bx
                    Bn = pt.By
                    Bu = pt.Bz
                    B = [Be, Bn, Bu]  # vector of magnetic field ENU in Telsa
                    Bxfl[lev, lat]=Be #output (ENU)
                    Byfl[lev, lat]=Bn #output (ENU)
                    Bzfl[lev, lat]=Bu #output (ENU)
                    
                    Bx, By, Bz = enu_ecef(lat_p, lon_p, Be, Bn, Bu)  # Tesla in ECEF
                    B = [Bx, By, Bz]  # vector of magnetic field ECEF in Telsa

                    # Magnetic field unit vector
                    bnorm = np.sqrt(Bx * Bx + By * By + Bz * Bz)
                    b_unit = [Bx / bnorm, By / bnorm, Bz / bnorm]
#                     bnorm = np.sqrt(Be * Be + Bn * Bn + Bu * Bu) #ENU
#                     b_unit = [Be / bnorm, Bn / bnorm, Bu / bnorm] #ENU
                    
#                     #Electric Field perpendicular to the magnetic field
#                     Evert=-np.cross(Ui,B)  #V/m
#                     Ee=Evert[0]
#                     En=Evert[1]
#                     Eu=Evert[2]
                    
#                     enorm=np.sqrt(En*En+Eu*Eu+Ee*Ee)
#                     e_unit=[Ee / enorm, En / enorm, Eu / enorm]
                    
#                     Evertx[lat, lon]=Ee #ENU
#                     Everty[lat, lon]=En #ENU
#                     Evertz[lat, lon]=Eu #ENU

                    #neutral wind perpendicular to the magnetic field
                    Unvert=np.cross(Un,b_unit)
                    Unvertx=Unvert[0]
                    Unverty=Unvert[1]
                    Unvertz=Unvert[2]
                    Unvertmag=np.sqrt(Unvert[0] * Unvert[0] + Unvert[1] * Unvert[1] + Unvert[2] * Unvert[2])
                    
                    unvertxfl[lev, lat]=Unvertx #output
                    unvertyfl[lev, lat]=Unverty #output
                    unvertzfl[lev, lat]=Unvertz #output
                    
#                     TIEGCM_Electric Fields
                    Ee_TIEGCM=EEX[timer, lev, lat, lon]*100
                    En_TIEGCM=EEY[timer, lev, lat, lon]*100
                    Eu_TIEGCM=EEZ[timer, lev, lat, lon]*100
                    ETIEGCM=[Ee_TIEGCM,En_TIEGCM,Eu_TIEGCM]
                    Ee_T, En_T, Eu_T = enu_ecef(lat_p, lon_p,Ee_TIEGCM,En_TIEGCM, Eu_TIEGCM)
                    Evert2=[Ee_T,En_T,Eu_T]
                    
                    E_T_vert=np.cross(Evert2,b_unit)
                    Ee_T_vert=E_T_vert[0]
                    En_T_vert=E_T_vert[1]
                    Eu_T_vert=E_T_vert[2]
                                        
                    
                    #Perpendicular electric field in neutral atmosphere reference frame                                        
                    Estar=E_T_vert+np.cross(Unvert,B)
                                                           
                    Evertxl[lev, lat]=Ee_TIEGCM #ENU
                    Evertyl[lev, lat]=En_TIEGCM  #ENU
                    Evertzl[lev, lat]=Eu_TIEGCM  #ENU


                    #Calculate ExB velocities 
                    ExBcalc=np.cross(E_T_vert,b_unit)/(bnorm)
                    ExBx_calcl[lev, lat]=ExBcalc[0]
                    ExBy_calcl[lev, lat]=ExBcalc[1]
                    ExBz_calcl[lev, lat]=ExBcalc[2]
                    
                    ########################################################################
#                   Gyrofrequencies and collision frequencies
                    ########################################################################

                    #gyrofrequencies (Hz)
                    bgauss=bnorm*10000
                    qeomeo10=1.7588028*10**7
                    qeoNa010=9.6489*10**3
                    rmassinv_op=1/mO
                    rmassinv_nop=1/mNO
                    rmassinv_o2p=1/mO2 
                    
                    omega_op=qeoNa010*bgauss*rmassinv_op
                    omega_o2p=qeoNa010*bgauss*rmassinv_o2p
                    omega_nop=qeoNa010*bgauss*rmassinv_nop
                    omega_op_inv=1/omega_op
                    omega_o2p_inv=1/omega_o2p
                    omega_nop_inv=1/omega_nop
                    omega_e=qeomeo10*bgauss
                    omega_e_inv=1/omega_e
                    
                    Omega_efl[lev, lat]=omega_e #output
                    Omega_Opfl[lev, lat]=omega_op #output
                    Omega_O2pfl[lev, lat]=omega_o2p #output
                    Omega_NOpfl[lev, lat]=omega_nop #output
                    
                    #collision frequencies (Hz)
                    temps=(Ti+Tn)/2
                    rnu_o2p_o2=2.59 * (10**(-11))* np.sqrt(temps)*((1-0.073*np.log10(temps))**2)
                    rnu_op_o2=6.64 * (10**(-10))
                    rnu_nop_o2=4.27 * (10**(-10))
                    

                    
                    rnu_o2p_o=2.31*(10**(-10))
                    rnu_op_o=3.67 * (10**(-11)) * np.sqrt(temps)*((1-0.064*np.log10(temps))**2)*fcor
                    rnu_nop_o=2.44 * (10**(-10))
                    
                    rnu_o2p_n2=4.13*(10**(-10))
                    rnu_op_n2=6.82 * (10**(-10))
                    rnu_nop_n2=4.34*(10**(-10))
                    
                    rnu_o2p=(rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2)*omega_o2p_inv
                    rnu_op=(rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2)*omega_op_inv
                    rnu_nop=(rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2)*omega_nop_inv
                    
                    vOp=rnu_op_o2*NO2+rnu_op_o*NO+rnu_op_n2*NN2
                    vO2p=rnu_o2p_o2*NO2+rnu_o2p_o*NO+rnu_o2p_n2*NN2
                    vNOp=rnu_nop_o2*NO2+rnu_nop_o*NO+rnu_nop_n2*NN2
                    vin=vOp+vO2p+vNOp
                    
                    vop_o=rnu_op_o*NO
                    vop_o2=rnu_op_o2*NO2
                    vop_n2=rnu_op_n2*NN2
                    vo2p_o=rnu_o2p_o*NO
                    vo2p_o2=rnu_o2p_o2*NO2
                    vo2p_n2=rnu_o2p_n2*NN2
                    vnop_o=rnu_nop_o*NO
                    vnop_o2=rnu_nop_o2*NO2
                    vnop_n2=rnu_nop_n2*NN2
                    
                    ven=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))
                    
                    rnu_ne=(2.33 * (10**(-11))*NN2*Te*(1-(1.21*(10**(-4)*Te))) \
                        + 1.82 * (10**(-10))*NO2*np.sqrt(Te)*(1+(3.6*(10**(-2)*np.sqrt(Te)))) \
                        +8.9 * (10**(-11))*NO*np.sqrt(Te)*(1+(5.7*(10**(-4)*Te))))*omega_e_inv
                    rnu_ne=4*rnu_ne
                    
                    vOpfl[lev, lat]=vOp #Output file
                    venfl[lev, lat]=ven #Output file
                    vO2pfl[lev, lat]=vO2p #Output file
                    vNOpfl[lev, lat]=vNOp 
                    vinfl[lev, lat]=vin #Output file
                    

                    
                    ########################################################################
#                   Conductivities
                    ########################################################################
    
                    qe_fac=(electron*10**10)/bgauss
                    Necm2=NOp+NO2p+NNOp
                    sigmaPed=qe_fac*((NOp*rnu_op/(1+rnu_op**2))+(NO2p*rnu_o2p/(1+rnu_o2p**2)) \
                                    +(NNOp*rnu_nop/(1+rnu_nop**2))+Necm2*rnu_ne/(1+rnu_ne**2))
                    
                    sigmaHall=qe_fac*(Necm2/(1+rnu_ne**2)-NOp/(1+rnu_op**2)-NO2p/(1+rnu_o2p**2)-NNOp/(1+rnu_nop**2))
                    
                    sigmaPedfl[lev, lat]=sigmaPed*10**(5) #output 10^-5 Si/m
                    sigmaHallfl[lev, lat]=sigmaHall*10**(5) #output 10^-5 Si/m

                    #Parallel conductivity
                    sigma0=(Ne*electron*electron)/(me*ven)*10**(5) #output 10^-5 Si/m
                    sigma_parl[lev, lat]=sigma0
                    
                    #TIEGCM conductivities
                    sP_tiegcm=PED_all[timer, lev, lat, lon]
                    sH_tiegcm=HALL_all[timer, lev, lat, lon]
                    sigmaPedf_Tl[lev, lat]=sP_tiegcm*10**(5) #output 10^-5 Si/m
                    sigmaHallf_Tl[lev, lat]=sH_tiegcm*10**(5) #output 10^-5 Si/m
                    
                    ########################################################################
#                   Velocities
                    ########################################################################

                    #Ion Velocity in neutral reference frame (formula derived through ion momentum equation)
                    #O+
                    vi_op_star=(vOp*omega_op*Estar+omega_op**2*(np.cross(Estar,b_unit)))/(bnorm*(vOp**2+omega_op**2))
                    vi_op_starx=vi_op_star[0] #m/s
                    vi_op_stary=vi_op_star[1] #m/s
                    vi_op_starz=vi_op_star[2] #m/s
                    vi_op_starmag=np.sqrt(vi_op_star[0] * vi_op_star[0] + vi_op_star[1] * vi_op_star[1] + vi_op_star[2] * vi_op_star[2])

                    vie_op=vi_op_starx+Unvertx #from neutral frame to ENU
                    vin_op=vi_op_stary+Unverty #from neutral frame to ENU
                    viu_op=vi_op_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_op=np.sqrt(vie_op*vie_op+vin_op*vin_op+viu_op*viu_op)
                    e_unit_op=[vie_op / vinorm_op, vin_op / vinorm_op, viu_op / vinorm_op]
                    
                    vi_mag_opl[lev, lat]=vinorm_op
                    vi_starxf_opl[lev, lat]=vie_op #output
                    vi_staryf_opl[lev, lat]=vin_op #output
                    vi_starzf_opl[lev, lat]=viu_op #output
                    
                    #O2+
                    vi_o2p_star=(vO2p*omega_o2p*Estar+omega_o2p**2*(np.cross(Estar,b_unit)))/(bnorm*(vO2p**2+omega_o2p**2))
                    vi_o2p_starx=vi_o2p_star[0] #m/s
                    vi_o2p_stary=vi_o2p_star[1] #m/s
                    vi_o2p_starz=vi_o2p_star[2] #m/s
                    vi_o2p_starmag=np.sqrt(vi_o2p_star[0] * vi_o2p_star[0] + vi_o2p_star[1] * vi_o2p_star[1] + vi_o2p_star[2] * vi_o2p_star[2])

                    vie_o2p=vi_o2p_starx+Unvertx #from neutral frame to ENU
                    vin_o2p=vi_o2p_stary+Unverty #from neutral frame to ENU
                    viu_o2p=vi_o2p_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_o2p=np.sqrt(vie_o2p*vie_o2p+vin_o2p*vin_o2p+viu_o2p*viu_o2p)
                    e_unit_o2p=[vie_o2p / vinorm_o2p, vin_o2p / vinorm_o2p, viu_o2p / vinorm_o2p]
                    
                    vi_mag_o2pl[lev, lat]=vinorm_o2p
                    vi_starxf_o2pl[lev, lat]=vie_o2p #output
                    vi_staryf_o2pl[lev, lat]=vin_o2p #output
                    vi_starzf_o2pl[lev, lat]=viu_o2p #output
                    
                    #NO+
                    vi_nop_star=(vNOp*omega_nop*Estar+omega_nop**2*(np.cross(Estar,b_unit)))/(bnorm*(vNOp**2+omega_nop**2))
                    vi_nop_starx=vi_nop_star[0] #m/s
                    vi_nop_stary=vi_nop_star[1] #m/s
                    vi_nop_starz=vi_nop_star[2] #m/s
                    vi_nop_starmag=np.sqrt(vi_nop_star[0] * vi_nop_star[0] + vi_nop_star[1] * vi_nop_star[1] + vi_nop_star[2] * vi_nop_star[2])

                    vie_nop=vi_nop_starx+Unvertx #from neutral frame to ENU
                    vin_nop=vi_nop_stary+Unverty #from neutral frame to ENU
                    viu_nop=vi_nop_starz+Unvertz #from neutral frame to ENU

                                       
                    vinorm_nop=np.sqrt(vie_nop*vie_nop+vin_nop*vin_nop+viu_nop*viu_nop)
                    e_unit_nop=[vie_nop / vinorm_nop, vin_nop / vinorm_nop, viu_nop / vinorm_nop]
                    
                    vi_mag_nopl[lev, lat]=vinorm_nop
                    vi_starxf_nopl[lev, lat]=vie_nop #output
                    vi_staryf_nopl[lev, lat]=vin_nop #output
                    vi_starzf_nopl[lev, lat]=viu_nop #output
                    
                    #Electron Velocity in neutral reference frame (formula derived through electron momentum equation)
                    ve_star=(-ven*omega_e*Estar+omega_e**2*(np.cross(Estar,b_unit)))/(bnorm*(ven**2+omega_e**2))
                    ve_starx=ve_star[0] #m/s
                    ve_stary=ve_star[1] #m/s
                    ve_starz=ve_star[2] #m/s
                    ve_starmag=np.sqrt(ve_star[0] * ve_star[0] + ve_star[1] * ve_star[1] + ve_star[2] * ve_star[2])

                    ve_xtemp=ve_starx+Unvertx #from neutral frame to ENU
                    ve_ytemp=ve_stary+Unverty #from neutral frame to ENU
                    ve_ztemp=ve_starz+Unvertz #from neutral frame to ENU
                  
                    vee_outl[lev, lat]=ve_xtemp
                    ven_outl[lev, lat]=ve_ytemp
                    veu_outl[lev, lat]=ve_ztemp    
                    
                    ########################################################################
#                     Magnetic parameters
                    ########################################################################
    
                    dipmag=np.arctan(Bz/np.sqrt(By**2+Bx**2))
                    sndip=np.sin(dipmag)
                    decmag=np.arctan2(By,Bx)
                    sndec=np.sin(decmag)
                    sn2dec=sndec**2
                    csdec=np.cos(decmag)
                    tm1=sn2dec+(1-sn2dec)*sndip**2
                    tm2=(1-sn2dec)+sn2dec*sndip**2
                    tm3=sndec*csdec*(1-sndip**2)
                    
                    ##########################################################################
#                   Ohmic Heating 
                    ########################################################################## 
                                        
                    A=E_T_vert+np.cross(Unvert,B)
#                     L=np.sqrt(A[0] * A[0] + A[1] * A[1] + A[2] * A[2])

                    Ohmic2=sP_tiegcm*np.dot(A,A)
#                     Ohmic2=sigmaPed*L*L
                    Ohmicl[lev, lat]=Ohmic2*1000 #mW/m^3
    
                    ##########################################################################
#                     Joule Heating - Frictional Heating
                    ##########################################################################
    
                    Joule_op=electron*NOp*(10**6)*np.dot(vi_op_star,A)
                    Joule_o2p=electron*NO2p*(10**6)*np.dot(vi_o2p_star,A)
                    Joule_nop=electron*NNOp*(10**6)*np.dot(vi_nop_star,A)
                    Joule1=Joule_op+Joule_o2p+Joule_nop
                    Joulel[lev, lat]=Joule1*1000 #mW/m^3
                    
                    Frictional_op=MO*NOp*(10**6)*vOp*vi_op_starmag*vi_op_starmag
                    Frictional_o2p=MO2*NO2p*(10**6)*vO2p*vi_o2p_starmag*vi_o2p_starmag
                    Frictional_nop=MNO*NNOp*(10**6)*vNOp*vi_nop_starmag*vi_nop_starmag
                    Frictional1=Frictional_op+Frictional_o2p+Frictional_nop
                    Frictionall[lev, lat]=Frictional1*1000 #mW/m^3
                    
                    rho=den_all[timer, lev, lat, lon]*1000
                    JH_rhol[lev, lat]=(Ohmic2/rho)*1000 #mW/kg
                    
                    ##########################################################################
#                   Convection Heating - Wind Correction
                    ##########################################################################
                                        
                    UNxB=np.cross(Unvert,B)
                    UNxBmag=np.sqrt(UNxB[0] * UNxB[0] + UNxB[1] * UNxB[1] + UNxB[2] * UNxB[2])
                    ExB=np.cross(E_T_vert,B)


                    Convenction_heating=sigmaPed*np.dot(E_T_vert,E_T_vert)
                    Convenction_heating_Out[lat, lon]=Convenction_heating*1000 #mW/m^3
                    
#                     Wind_heating=sigmaPed*UNxBmag*UNxBmag-2*sigmaPed*np.dot(Un,ExB)
                    Wind_heating=sP_tiegcm*bnorm**2*(tm2*Un_x**2+tm1*Un_y**2-2*tm3*Un_x*Un_y-2*(Un_x*Ui_x+Un_y*Ui_y))
                    Wind_heating_Outl[lev, lat]=Wind_heating*1000 #mW/m^3
        
                    #TIEGCM QWIND and QAMIE
                    QAMIE1=QAMIE[timer, lev, lat, lon]
                    QAMIE_Tl[lev, lat]=QAMIE1
                    QWIND1=QWIND[timer, lev, lat, lon]
                    QWIND_Tl[lev, lat]=QWIND1                               
                    
                    Ohmic_heating_OhmsLaw=Convenction_heating+Wind_heating
                    Ohmic_heating_OhmsLaw_Outl[lev, lat]=Ohmic_heating_OhmsLaw*1000 #mW/m^3
                    
                    ##########################################################################
#                   Ohmic per Pressure/ Pressure per Ohmic
                    ##########################################################################
                                   
                    Ohmic_pressure=(Ohmic2/pressuref_Pa)
                    Ohmic_Pressl[lev, lat]=Ohmic_pressure
                
                    pressure_ohmic_tmp=(1/Ohmic_pressure)
                    Press_Ohmicl[lev, lat]=pressure_ohmic_tmp
                    
                    ##########################################################################
#                   Electric Currents
                    ##########################################################################
                    
                    #perpendicular electric current density (A/m^2) (Ohm's LaW)
                    J_p_Ohmic=sigmaPed*Estar+sigmaHall*np.cross(b_unit,Estar)
                    J_p_Ohmicx=J_p_Ohmic[0]
                    J_p_Ohmicy=J_p_Ohmic[1]
                    J_p_Ohmicz=J_p_Ohmic[2]
                    
                    #Pedersen and Hall currents
                    J_Pedersen=sigmaPed*Estar
                    J_Hall=sigmaHall*np.cross(b_unit,Estar)
                    
                    Jpe=J_Pedersen[0]
                    Jpn=J_Pedersen[1]
                    Jpu=J_Pedersen[2]
                    Jhe=J_Hall[0]
                    Jhn=J_Hall[1]
                    Jhu=J_Hall[2]

                    
                    #####################
                    Jpnorm=np.sqrt(Jpn*Jpn+Jpu*Jpu+Jpe*Jpe)
                    Jp_unit=[Jpe / Jpnorm, Jpn / Jpnorm, Jpu / Jpnorm]
                    
                    Jhnorm=np.sqrt(Jhn*Jhn+Jhu*Jhu+Jhe*Jhe)
                    Jh_unit=[Jhe / Jhnorm, Jhn / Jhnorm, Jhu / Jhnorm]
                    
                    J_Pedel[lev, lat]=Jpe #output 
                    J_Pednl[lev, lat]=Jpn #output  
                    J_Pedul[lev, lat]=Jpu #output 
                    J_Hallel[lev, lat]=Jhe #output 
                    J_Hallnl[lev, lat]=Jhn #output 
                    J_Hallul[lev, lat]=Jhu #output 
                    J_Ohmel[lev, lat]=Jpe+Jhe #output 
                    J_Ohmnl[lev, lat]=Jpn+Jhn #output 
                    J_Ohmul[lev, lat]=Jpu+Jhu #output 
                    
                    J_magl[lev, lat]=np.sqrt((Jpe+Jhe)**2+(Jpn+Jhn)**2+(Jpu+Jhu)**2) #output 

                    #perpendicular electric current density (A/m^2) (densities)
                    J_den=electron*Ne*(vi_op_star-ve_star)
                    J_denx=J_den[0]
                    J_deny=J_den[1]
                    J_denz=J_den[2]
                    
                    ##########################################################################
#                   JxB forcing
                    ##########################################################################

                    JxB=np.cross(J_p_Ohmic,B)
                    JxBel[lev, lat]=JxB[0]
                    JxBnl[lev, lat]=JxB[1]
                    JxBul[lev, lat]=JxB[2]
                    
                    ##########################################################################
#                   Mechanical Power and Energy
                    ##########################################################################
                    
                    Mechanical_power=np.dot(Un,JxB)
                    Mechanical_power_Outl[lev, lat]=Mechanical_power
                    Energy=Ohmic_heating_OhmsLaw+Mechanical_power
                    Energy_Outl[lev, lat]=Energy
                    
                    ##########################################################################
#                   Cross Sections
                    ##########################################################################
                    N_neutral=(NO2+NN2+NO)*10**6
                    MN2=(mN2)/(NA*1000)
                    M_ion=MO+MO2+MNO
                    
                    cross=(vin/N_neutral)/(np.sqrt((2*boltzmann*Ti)/M_ion))
                    cross_sectionl[lev, lat]=cross
                    
                    cross_op=(vOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO))
                    cross_section_opl[lev, lat]=cross_op
                    
                    cross_o2p=(vO2p/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MO2))
                    cross_section_o2pl[lev, lat]=cross_o2p
                    
                    cross_nop=(vNOp/N_neutral)/(np.sqrt((2*boltzmann*Ti)/MNO))
                    cross_section_nopl[lev, lat]=cross_nop
                    
                    warnings.simplefilter('ignore')
                    
                    #print(Ohmic2*1000,Ohmic_heating_OhmsLaw*1000,Convenction_heating*1000,Wind_heating*1000 )
                    
                    
                    ##########################################################################
#                     Ion heating rates
                    ##########################################################################
    
                    qDTop_o=3*NOp*(10 ** 6)*boltzmann_si*vop_o*(MO/(MO+MO))*(Ti-Tn)
                    qDTop_o2=3*NOp*(10 ** 6)*boltzmann_si*vop_o2*(MO/(MO2+MO))*(Ti-Tn)
                    qDTop_n2=3*NOp*(10 ** 6)*boltzmann_si*vop_n2*(MO/(MN2+MO))*(Ti-Tn)
                    qDTo2p_o=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o*(MO2/(MO+MO2))*(Ti-Tn)
                    qDTo2p_o2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_o2*(MO2/(MO2+MO2))*(Ti-Tn)
                    qDTo2p_n2=3*NO2p*(10 ** 6)*boltzmann_si*vo2p_n2*(MO2/(MN2+MO2))*(Ti-Tn)
                    qDTnop_o=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o*(MNO/(MO+MNO))*(Ti-Tn)
                    qDTnop_o2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_o2*(MNO/(MO2+MNO))*(Ti-Tn)
                    qDTnop_n2=3*NNOp*(10 ** 6)*boltzmann_si*vnop_n2*(MNO/(MN2+MNO))*(Ti-Tn)
                    
                    qDTop_n=qDTop_o+qDTop_o2+qDTop_n2
                    qDTo2p_n=qDTo2p_o+qDTo2p_o2+qDTo2p_n2
                    qDTnop_n=qDTnop_o+qDTnop_o2+qDTnop_n2
                    
                    qDTi_n=qDTop_n+qDTo2p_n+qDTnop_n
                    
                    qDTop_ofl[lev, lat]=qDTop_o
                    qDTop_o2fl[lev, lat]=qDTop_o2
                    qDTop_n2fl[lev, lat]=qDTop_n2
                    qDTo2p_ofl[lev, lat]=qDTo2p_o
                    qDTo2p_o2fl[lev, lat]=qDTo2p_o2
                    qDTo2p_n2fl[lev, lat]=qDTo2p_n2
                    qDTnop_ofl[lev, lat]=qDTnop_o
                    qDTnop_o2fl[lev, lat]=qDTnop_o2
                    qDTnop_n2fl[lev, lat]=qDTnop_n2
                    
                    qDTop_nfl[lev, lat]=qDTop_n
                    qDTo2p_nfl[lev, lat]=qDTo2p_n
                    qDTnop_nfl[lev, lat]=qDTnop_n
                    
                    qDTi_nfl[lev, lat]=qDTi_n*1000 #mW/m^3

                    
    print("Calculation executed!")
    print("Total run time: %s seconds" % (time.time() - start_time))
    
warnings.simplefilter('ignore')

#window creation            
style = {'description_width': '150px'}
layout1stcolumn = {'width': '300px'}
layout2ndcolumn= {'width': '250px'}
layout3rdcolumn= {'width': '100px'}
button_layout={'width': '150px'}
style1 = {'description_width':'150px'}
layout1 = {'width':'850px'}
style2 = {'description_width':'95px'}
layout2 = {'width':'160px'}
layout3 = {'width':'350px'}
style3 = {'description_width':'60px'}
layout4 = {'width':'215px'}

tiegcm_file=widgets.Dropdown(options=sorted(glob.glob(DaedalusGlobals.TIEGCM_Files_Path +"TIEGCM_EVT1_2015_StPatricksDay_Rerun/tiegcm_dres.s_mar2015_amie_v1_*.nc")), description='TIE-GCM files: ', style=style1, layout=layout1)
orbit_file=widgets.Dropdown(options=sorted(glob.glob(DaedalusGlobals.Orbit_Files_Path +"DAED_ORB_Evt0_LLA*.csv")), description='Orbit files: ', style=style1, layout=layout1)
lat_value=widgets.Dropdown(
                        options=[('-88.75', 0), ('-86.25', 1), ('-83.75', 2),('-81.25', 3), ('-78.75', 4),('-76.25', 5), ('-73.75', 6),('-71.25', 7),
                        ('-68.75', 8), ('-66.25', 9), ('-63.75', 10),('-61.25', 11), ('-58.75', 12),('-56.25', 13), ('-53.75', 14),('-51.25', 15),
                        ('-48.75', 16), ('-46.25', 17), ('-43.75', 18),('-41.25', 19), ('-38.75', 20),('-36.25', 21), ('-33.75', 22),('-31.25', 23),
                        ('-28.75', 24), ('-26.25', 25), ('-23.75', 26),('-21.25', 27), ('-18.75', 28),('-16.25', 29), ('-13.75', 30),('-11.25', 31),
                        ('-8.75', 32), ('-6.25', 33), ('-3.75', 34),('-1.25', 35), ('1.25', 36),('3.75', 37), ('6.25', 38),('8.75', 39),
                        ('11.25', 40), ('13.75', 41), ('16.25', 42),('18.75', 43), ('21.25', 44),('23.75', 45), ('26.25', 46),('28.75', 47),
                        ('31.25', 48),('33.75', 49), ('36.25', 50),('38.75', 51), ('41.25', 52),('43.75', 53),
                        ('46.25', 54),('48.75', 55), ('51.25', 56),('53.75', 57), ('56.25', 58),('58.75', 59),
                        ('61.25', 60),('63.75', 61), ('66.25', 62),('68.75', 63), ('71.25', 64),('73.75', 65),
                        ('76.25', 66),('78.75', 67), ('81.25', 68),('83.75', 69), ('84.25', 70),('87.75', 71)],
                        value=61,
                        description='Latitude (deg):',
                        layout=layout1stcolumn, 
                        style=style
                        )
lon_value=widgets.Dropdown(
                        options=[('-180.0', 0), 
                                 ('-177.5', 1), ('-175.0', 2),('-172.5', 3), ('-170.0', 4),('-167.5', 5), ('-165.0', 6),('-162.5', 7), ('-160.0', 8), 
                                 ('-157.5', 9), ('-155.0', 10),('-152.5', 11), ('-150.0', 12),('-147.5', 13),('-145.0', 14),('-142.5', 15),('-140.0', 16), 
                                 ('-137.5', 17), ('-135.0', 18),('-132.5', 19), ('-130.0', 20),('-127.5', 21), ('-125.0', 22),('-122.5', 23),('-120.0', 24), 
                                 ('-117.5', 25), ('-115.0', 26),('-112.5', 27), ('-110.0', 28),('-107.5', 29), ('-105.0', 30),('-102.5', 31),('-100.0', 32), 
                                 ('-97.5', 33), ('-95.0', 34),('-92.5', 35),('-90.0', 36),('-87.5', 37),('-85.0', 38),('-82.5', 39),('-80.0', 40), 
                                 ('-77.5', 41), ('-75.0', 42),('-72.5', 43),('-70.0', 44),('-67.5', 45),('-65.0', 46),('-62.5', 47),('-60.0', 48),
                                 ('-57.5', 49), ('-55.0', 50),('-52.5', 51),('-50.0', 52),('-47.5', 53),('-45.0', 54),('-42.5', 55),('-40.0', 56),
                                 ('-37.5', 57), ('-35.0', 58),('-32.5', 59),('-30.0', 60),('-27.5', 61),('-25.0', 62),('-22.5', 63),('-20.0', 64),
                                 ('-17.5', 65), ('-15.0', 66),('-12.5', 67),('-10.0', 68),('-7.5', 69), ('-5.0', 70),('-2.5', 71),('0.0', 72),
                                 ('2.5', 73), ('5.0', 74),('7.5', 75),('10.0', 76),('12.5', 77), ('15.0', 78),('17.5', 79),('20.0', 80),('22.5', 81),
                                 ('25.0', 82), ('27.5', 83),('30.0', 84),('32.5', 85),('35.0', 86), ('37.5', 87),('40.0', 88),('42.5', 89),('45.0', 90),
                                 ('47.5', 91),('50.0', 92),('52.5', 93),('55.0', 94), ('57.5', 95),('60.0', 96),('62.5', 97),('65.0', 98),
                                 ('67.5', 99),('70.0', 100),('72.5', 101),('75.0', 102), ('77.5', 103),('80.0', 104),('82.5', 105),('85.0', 106),
                                 ('87.5', 107),('90.0', 108),('92.5', 109),('95.0', 110), ('97.5', 111),('100.0', 112),('102.5', 113),('105.0', 114),
                                 ('107.5', 115),('110.0', 116),('112.5', 117),('115.0', 118), ('117.5', 119),('120.0', 120),
                                 ('122.5', 121),('125.0', 122),('127.5', 123),('130.0', 124), ('132.5', 125),('135.0', 126),
                                 ('137.5', 127),('140.0', 128),('142.5', 129),('145.0', 130), ('147.5', 131),('150.0', 132),
                                 ('152.5', 133),('155.0', 134),('157.5', 135),('160.0', 136), ('162.5', 137),('165.0', 138),
                                 ('167.5', 139),('170.0', 140),('172.5', 141),('175.0', 142), ('177.5', 143),
                                ],
                        value=25,
                        description='Longitude (deg):',
                        layout=layout1stcolumn, 
                        style=style
                        )
plot_param=widgets.Dropdown(
            options=['Joule Heating','Frictional Heating','Ohmic Heating','Ohmic Heating per mass','Ohmic Heating per pressure',
                     'Pressure_Ohmic ratio', 'Convenction Heating', 'Ion Heating Rate',
                     'Wind Heating', 'Mechanical Power', 'Energy','Pedersen', 'Hall', 'Parallel','O','O2','N2', 'O+',
                     'O2+','NO+','Ne', 
                     'Ti','Tn','Te','νO+n','νO2+n','vNO+n','νin','νen', 'σ', 'σO+n','σO2+n','σNO+n','Potential','Pressure'],
            value='Joule Heating',
            description='Parameter to Plot:',
            disabled=False,
            style=style, 
            layout=layout1stcolumn
            )

quiver_back_param=widgets.Dropdown(
            options=['Potential', 'Joule Heating','Frictional Heating','Ohmic Heating','Convenction Heating','Ion Heating Rate',
                     'Wind Heating', 'Mechanical Power', 'Energy','Current','Pedersen','Hall','Parallel','Ion Drift'],
            value='Potential',
            description='Background:',
            disabled=False,
            style=style, 
            layout=layout1stcolumn
            )

quiver_vec_param=widgets.Dropdown(
            options=['Electric Field', 'Magnetic Field', 'Pedersen Current', 'Hall Current', 'Perpendicular Current', 'Ion Velocity',
                    'Neutral Winds','JxB'],
            value='Electric Field',
            description='Vector Field:',
            disabled=False,
            style=style, 
            layout=layout1stcolumn
            )
quiver_plot_param=widgets.Dropdown(
            options=['Vector','Streamplot','Divergence'],
            value='Vector',
            description='Projection:',
            disabled=False,
            style=style, 
            layout=layout1stcolumn
            )

timer_value= widgets.Dropdown( value=0, options=range(0,24),  description='TimeStep:', style=style, layout=layout1stcolumn)
pressure_level= widgets.Dropdown( value=0, options=range(0,57),  description='Pressure Level:', style=style, layout=layout1stcolumn)
heatings_checkbox   = widgets.Checkbox(value=True,  description="Plot Heating Rates", style=style1, layout=layout1 )
JHrho_checkbox   = widgets.Checkbox(value=False,  description="Plot Heating per mass", style=style1, layout=layout1 )
JHpress_checkbox   = widgets.Checkbox(value=False,  description="Plot Heating per pressure", style=style1, layout=layout1 )
pressure_heating_checkbox= widgets.Checkbox(value=False,  description="Plot Pressure/Heating ratio", style=style1, layout=layout1 )
pressure_heating_log_checkbox= widgets.Checkbox(value=False,  description="Plot Pressure/Heating ratio (log)", style=style1, layout=layout1 )
press_checkbox   = widgets.Checkbox(value=False,  description="Pressure", style=style1, layout=layout1 )
conductivities_checkbox   = widgets.Checkbox(value=False,  description="Plot Conductivities", style=style1, layout=layout1 )
frequencies_checkbox   = widgets.Checkbox(value=False,  description="Plot Frequencies", style=style1, layout=layout1 )
cross_checkbox   = widgets.Checkbox(value=False,  description="Plot Cross Sections", style=style1, layout=layout1 )
densities_checkbox   = widgets.Checkbox(value=False,  description="Plot Densities", style=style1, layout=layout1 )
temperatures_checkbox   = widgets.Checkbox(value=False,  description="Plot Temperatures", style=style1, layout=layout1 )
currents_checkbox   = widgets.Checkbox(value=False,  description="Plot Currents", style=style1, layout=layout1 )
efield_checkbox   = widgets.Checkbox(value=False,  description="Plot E field", style=style1, layout=layout1 )
velocities_checkbox   = widgets.Checkbox(value=False,  description="Plot Velocities", style=style1, layout=layout1 )
Joule_checkbox= widgets.Checkbox(value=True,  description="Map Plot",style=style1, layout=layout1 )
Joule_polar= widgets.Checkbox(value=True,  description="Polar Plot",style=style1, layout=layout1 )
Joule_ortho= widgets.Checkbox(value=True,  description="Orthographic Plot",style=style1, layout=layout3 )
Bounding_lat  = widgets.BoundedIntText(value=40, min=10, max=180, description='Bounding Latitude:', style=style1, layout=layout4)
North_plot= widgets.Checkbox(value=True,  description="Plot North Pole",style=style3, layout=layout3 )
South_plot= widgets.Checkbox(value=False,  description="Plot South Pole",style=style3, layout=layout3 )
center_lat  = widgets.BoundedIntText(value=45, min=-90, max=90, description='Center Latitude:', style=style1, layout=layout4)
center_lon  = widgets.BoundedIntText(value=45, min=-180, max=180, description='Center Longitude:', style=style1, layout=layout4)
quiver_checkbox= widgets.Checkbox(value=True,  description="Quiver Plot",style=style1, layout=layout1 )
orbit_checkbox= widgets.Checkbox(value=True,  description="Add Orbit",style=style1, layout=layout1 )
night_checkbox= widgets.Checkbox(value=True,  description="Add Nightshade",style=style1, layout=layout1)

def plot_heatings(timer,lat,lon):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
#     date=time_plot.strftime("%d %b %Y %H:%M:%S")
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=Ohmic1[0:-1], y=zg1,name="Ohmic",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=Joule1[0:-1], y=zg1,name="Joule",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=Frictional1[0:-1], y=zg1,name="Frictional",mode='lines',marker=dict(color='red')))
    fig1.add_trace(go.Scatter(x=wind1[0:-1], y=zg1,name="Wind",mode='lines',marker=dict(color='darkturquoise')))
    fig1.add_trace(go.Scatter(x=convection1[0:-1], y=zg1,name="Convection",mode='lines',marker=dict(color='greenyellow')))
    fig1.add_trace(go.Scatter(x=ohms_ohmic[0:-1], y=zg1,name="Wind+Convection",mode='lines',marker=dict(color='rosybrown')))
    fig1.add_trace(go.Scatter(x=qDTi_n[0:-1], y=zg1,name="Ion heating",mode='lines',marker=dict(color='cornflowerblue')))
    fig1.add_trace(go.Scatter(x=qDTe_n[0:-1], y=zg1,name="Electron heating",mode='lines',marker=dict(color='magenta')))
    fig1.add_trace(go.Scatter(x=Le1[0:-1], y=zg1,name="Electron Cooling",mode='lines',marker=dict(color='peachpuff')))
    fig1.add_trace(go.Scatter(x=qDTe_i[0:-1], y=zg1,name="Coulomb Collisions",mode='lines',marker=dict(color='gold')))
    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$W/m^{3}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Heating Rates %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(x=qDTop_o[0:-1], y=zg1,name="qDTop_o",mode='lines',marker=dict(color='aliceblue')))
    fig2.add_trace(go.Scatter(x=qDTop_o2[0:-1], y=zg1,name="qDTop_o2",mode='lines',marker=dict(color='blueviolet')))
    fig2.add_trace(go.Scatter(x=qDTop_n2[0:-1], y=zg1,name="qDTop_n2",mode='lines',marker=dict(color='brown')))
    fig2.add_trace(go.Scatter(x=qDTop_he[0:-1], y=zg1,name="qDTop_he",mode='lines',marker=dict(color='magenta')))
    fig2.add_trace(go.Scatter(x=qDTo2p_o[0:-1], y=zg1,name="qDTo2p_o",mode='lines',marker=dict(color='firebrick')))
    fig2.add_trace(go.Scatter(x=qDTo2p_o2[0:-1], y=zg1,name="qDTo2p_o2",mode='lines',marker=dict(color='gold')))
    fig2.add_trace(go.Scatter(x=qDTo2p_n2[0:-1], y=zg1,name="qDTo2p_n2",mode='lines',marker=dict(color='lightpink')))
    fig2.add_trace(go.Scatter(x=qDTo2p_he[0:-1], y=zg1,name="qDTo2p_he",mode='lines',marker=dict(color='crimson')))
    fig2.add_trace(go.Scatter(x=qDTnop_o[0:-1], y=zg1,name="qDTnop_o",mode='lines',marker=dict(color='olive')))
    fig2.add_trace(go.Scatter(x=qDTnop_o2[0:-1], y=zg1,name="qDTnop_o2",mode='lines',marker=dict(color='seagreen')))
    fig2.add_trace(go.Scatter(x=qDTnop_n2[0:-1], y=zg1,name="qDTnop_n2",mode='lines',marker=dict(color='teal')))
    fig2.add_trace(go.Scatter(x=qDTnop_he[0:-1], y=zg1,name="qDTnop_he",mode='lines',marker=dict(color='fuchsia')))
    fig2.add_trace(go.Scatter(x=qDTop_n[0:-1], y=zg1,name="qDTop_n",mode='lines',marker=dict(color='thistle')))
    fig2.add_trace(go.Scatter(x=qDTo2p_n[0:-1], y=zg1,name="qDTo2p_n",mode='lines',marker=dict(color='peachpuff')))
    fig2.add_trace(go.Scatter(x=qDTnop_n[0:-1], y=zg1,name="qDTnop_n",mode='lines',marker=dict(color='plum')))
    fig2.add_trace(go.Scatter(x=qDTi_n[0:-1], y=zg1,name="qDTi_n",mode='lines',marker=dict(color='cornflowerblue')))
    
    
    fig2.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$W/m^{3}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Ion Heating Rates %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig2.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.show()
    
    fig3 = go.Figure()

    fig3.add_trace(go.Scatter(x=Le_O2_rot[0:-1], y=zg1,name="O2 Rotational",mode='lines',marker=dict(color='fuchsia')))
    fig3.add_trace(go.Scatter(x=Le_N2_rot[0:-1], y=zg1,name="N2 Rotational",mode='lines',marker=dict(color='mediumspringgreen')))
    fig3.add_trace(go.Scatter(x=Le_O_fine[0:-1], y=zg1,name="O fine structure",mode='lines',marker=dict(color='papayawhip')))
    fig3.add_trace(go.Scatter(x=Le_O_1D[0:-1], y=zg1,name="O(1D) excitation",mode='lines',marker=dict(color='cornsilk')))
    fig3.add_trace(go.Scatter(x=Le_O2_vib[0:-1], y=zg1,name="O2 vibration",mode='lines',marker=dict(color='seagreen')))
    fig3.add_trace(go.Scatter(x=qDTe_o[0:-1], y=zg1,name="qDTe_o",mode='lines',marker=dict(color='aliceblue')))
    fig3.add_trace(go.Scatter(x=qDTe_o2[0:-1], y=zg1,name="qDTe_o2",mode='lines',marker=dict(color='blueviolet')))
    fig3.add_trace(go.Scatter(x=qDTe_n2[0:-1], y=zg1,name="qDTe_n2",mode='lines',marker=dict(color='brown')))
    fig3.add_trace(go.Scatter(x=qDTe_he[0:-1], y=zg1,name="qDTe_he",mode='lines',marker=dict(color='orange')))
    fig3.add_trace(go.Scatter(x=qDTe_n[0:-1], y=zg1,name="qDTe_n",mode='lines',marker=dict(color='red')))
    fig3.add_trace(go.Scatter(x=Le1[0:-1], y=zg1,name="Le",mode='lines',marker=dict(color='gold')))
  
    
    fig3.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$W/m^{3}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Electron Heating and Cooling Rates %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig3.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.show()
    
    fig4 = go.Figure()

    fig4.add_trace(go.Scatter(x=qDTe_op[0:-1], y=zg1,name="e_O+",mode='lines',marker=dict(color='fuchsia')))
    fig4.add_trace(go.Scatter(x=qDTe_o2p[0:-1], y=zg1,name="e_O2+",mode='lines',marker=dict(color='mediumspringgreen')))
    fig4.add_trace(go.Scatter(x=qDTe_np[0:-1], y=zg1,name="e_N+",mode='lines',marker=dict(color='papayawhip')))
    fig4.add_trace(go.Scatter(x=qDTe_nop[0:-1], y=zg1,name="e_NO+",mode='lines',marker=dict(color='cornsilk')))
    fig4.add_trace(go.Scatter(x=qDTe_i[0:-1], y=zg1,name="e_i",mode='lines',marker=dict(color='seagreen')))
    
    fig4.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$W/m^{3}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Heating from electron-ion collisions %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig4.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig4.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig4.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig4.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig4.show()
    
def plot_JH_rho(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=JH_rhov[0:-1], y=zg1,name="Ohmic heating per mass",mode='lines',marker=dict(color='orange'))) 

    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$W/kg$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Ohmic heating per mass %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_press_heat_log(timer):
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])    
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=pressure_ohmic[0:-1], y=zg1,name="Pressure/Heating ratio",mode='lines',marker=dict(color='orange'))) 

    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Pressure/Heating ratio %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_press_heat(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=pressure_ohmic[0:-1], y=zg1,name="Pressure/Heating ratio",mode='lines',marker=dict(color='orange'))) 

    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Pressure/Heating ratio %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_press(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=Pressure[0:-1], y=zg1,name="Pressure",mode='lines',marker=dict(color='#9c179e'))) 

    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$Pa$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Pressure %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_JH_press(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=ohmic_pressure[0:-1], y=zg1,name="Ohmic heating per pressure",mode='lines',marker=dict(color='#0d0887'))) 

    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$1/s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Ohmic heating per pressure %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_efield(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=E_e[0:-1], y=zg1,name="East",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=E_n[0:-1], y=zg1,name="North",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=E_u[0:-1], y=zg1,name="Up",mode='lines',marker=dict(color='red')))
    fig1.add_trace(go.Scatter(x=Ee_TIEGCM1[0:-1], y=zg1,name="East",mode='lines',marker=dict(color='darkturquoise'))) 
    fig1.add_trace(go.Scatter(x=En_TIEGCM1[0:-1], y=zg1,name="North",mode='lines',marker=dict(color='orange')))
    fig1.add_trace(go.Scatter(x=Eu_TIEGCM1[0:-1], y=zg1,name="Up",mode='lines',marker=dict(color='rosybrown')))
    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$V/m$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Electric FIeld (ENU)  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_temperatures(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=T_e[0:-1], y=zg1,name="Electron T",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=T_i[0:-1], y=zg1,name="Ion T",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=T_n[0:-1], y=zg1,name="Neutral T",mode='lines',marker=dict(color='red')))
    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$K$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Temperature  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
      
    
def plot_currents(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=J_pe[0:-1], y=zg1,name="East",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=J_pn[0:-1], y=zg1,name="North",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=J_pu[0:-1], y=zg1,name="Up",mode='lines',marker=dict(color='red')))
    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$A/m^{2}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Pedersen Currents (ENU)  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(x=J_he[0:-1], y=zg1,name="East",mode='lines',marker=dict(color='blue'))) 
    fig2.add_trace(go.Scatter(x=J_hn[0:-1], y=zg1,name="North",mode='lines',marker=dict(color='green')))
    fig2.add_trace(go.Scatter(x=J_hu[0:-1], y=zg1,name="Up",mode='lines',marker=dict(color='red')))
    
    fig2.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$A/m^{2}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Hall Currents (ENU)  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})

    fig2.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.show()
    
    fig3 = go.Figure()
    fig3.add_trace(go.Scatter(x=J_p_Ohmice[0:-1], y=zg1,name="Current (Ohm's <br> Law) East",mode='lines',marker=dict(color='blue'))) 
    fig3.add_trace(go.Scatter(x=J_p_Ohmicn[0:-1], y=zg1,name="Current (Ohm's <br> Law) North",mode='lines',marker=dict(color='green')))
    fig3.add_trace(go.Scatter(x=J_p_Ohmicu[0:-1], y=zg1,name="Current (Ohm's <br> Law) Up",mode='lines',marker=dict(color='red')))
    fig3.add_trace(go.Scatter(x=J_dene[0:-1], y=zg1,name="Current <br> (definition) East",mode='lines',marker=dict(color='darkturquoise'))) 
    fig3.add_trace(go.Scatter(x=J_denn[0:-1], y=zg1,name="Current <br> (definition) North",mode='lines',marker=dict(color='greenyellow')))
    fig3.add_trace(go.Scatter(x=J_denu[0:-1], y=zg1,name="Current <br> (definition) Up",mode='lines',marker=dict(color='rosybrown')))
    
    fig3.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$A/m^{2}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Perpendicular Currents (ENU)  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig3.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.show()

def plot_conductivities(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=sigmaPed1[0:-1], y=zg1[0:-1],name="Pedersen",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=sigmaHall1[0:-1], y=zg1[0:-1],name="Hall",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=sigma01[0:-1], y=zg1[0:-1],name="Parallel",mode='lines',marker=dict(color='red')))
    fig1.add_trace(go.Scatter(x=sigmaPed1TIEGCM[0:-1], y=zg1[0:-1],name="Pedersen (TIEGCM)",mode='lines',marker=dict(color='darkturquoise'))) 
    fig1.add_trace(go.Scatter(x=sigmaHall1TIEGCM[0:-1], y=zg1[0:-1],name="Hall (TIEGCM)",mode='lines',marker=dict(color='rosybrown')))
    
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$Si/m$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Conductivities  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_frequencies(timer):

    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=omega_e1[0:-1], y=zg1[0:-1],name="$$\Omega_{e}$$",mode='lines',marker=dict(color='blue')))
    fig1.add_trace(go.Scatter(x=omega_NOp1[0:-1], y=zg1[0:-1],name="$$\Omega_{NO+}$$",mode='lines',marker=dict(color='crimson')))
    fig1.add_trace(go.Scatter(x=omega_Op1[0:-1], y=zg1[0:-1],name="$$\Omega_{O+}$$",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=omega_O2p1[0:-1], y=zg1[0:-1],name="$$\Omega_{O2+}$$+",mode='lines',marker=dict(color='orange')))
    fig1.add_trace(go.Scatter(x=vOp1[0:-1], y=zg1[0:-1],name="$$v_{O+}$$",mode='lines',marker=dict(color='mediumseagreen')))
    fig1.add_trace(go.Scatter(x=ven1[0:-1], y=zg1[0:-1],name="$$v_{en}$$",mode='lines',marker=dict(color='dodgerblue')))
    fig1.add_trace(go.Scatter(x=vO2p1[0:-1], y=zg1[0:-1],name="$$v_{O2+}$$+",mode='lines',marker=dict(color='sandybrown')))
    fig1.add_trace(go.Scatter(x=vNOp1[0:-1], y=zg1[0:-1],name="$$v_{NO+}$$+",mode='lines',marker=dict(color='deeppink')))
    fig1.add_trace(go.Scatter(x=vin1[0:-1], y=zg1[0:-1],name="$$v_{in}$$+",mode='lines',marker=dict(color='mediumpurple')))
    fig1.add_trace(go.Scatter(x=vei[0:-1], y=zg1[0:-1],name="$$v_{ei}$$+",mode='lines',marker=dict(color='gold')))
    fig1.add_trace(go.Scatter(x=vop_n_SB[0:-1], y=zg1[0:-1],name="$$v_{O+} SB$$+",mode='lines',marker=dict(color='magenta')))
    fig1.add_trace(go.Scatter(x=vo2p_n_SB[0:-1], y=zg1[0:-1],name="$$v_{O2+} SB$$+",mode='lines',marker=dict(color='brown')))
    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="Frequency (Hz)",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Frequencies %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()   
    
    
def plot_cross_section(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=cross_sectionf[0:-1], y=zg1[0:-1],name="Ion Cross Section",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=cross_op_sectionf[0:-1], y=zg1[0:-1],name="O+ Cross Section",mode='lines',marker=dict(color='red'))) 
    fig1.add_trace(go.Scatter(x=cross_o2p_sectionf[0:-1], y=zg1[0:-1],name="O2+ Cross Section",mode='lines',marker=dict(color='green'))) 
    fig1.add_trace(go.Scatter(x=cross_nop_sectionf[0:-1], y=zg1[0:-1],name="NO+ Cross Section",mode='lines',marker=dict(color='orange'))) 

    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$m^{2}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Cross Section  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()   
    
    
    
def plot_densities(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=nO1[0:-1], y=zg1[0:-1],name="O",mode='lines',marker=dict(color='blue'))) 
    fig1.add_trace(go.Scatter(x=nO21[0:-1], y=zg1[0:-1],name="O2",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=nN21[0:-1], y=zg1[0:-1],name="N2",mode='lines',marker=dict(color='red')))
    fig1.add_trace(go.Scatter(x=Ne1[0:-1], y=zg1[0:-1],name="Ne",mode='lines',marker=dict(color='yellow')))
    fig1.add_trace(go.Scatter(x=NOp1[0:-1], y=zg1[0:-1],name="O+",mode='lines',marker=dict(color='orange')))
    fig1.add_trace(go.Scatter(x=NO2p1[0:-1], y=zg1[0:-1],name="O2+",mode='lines',marker=dict(color='purple')))
    fig1.add_trace(go.Scatter(x=NNOp1[0:-1], y=zg1[0:-1],name="NO+",mode='lines',marker=dict(color='darkslategray')))
    fig1.add_trace(go.Scatter(x=Argon[0:-1], y=zg1[0:-1],name="Ar",mode='lines',marker=dict(color='teal')))
    fig1.add_trace(go.Scatter(x=Helium[0:-1], y=zg1[0:-1],name="He",mode='lines',marker=dict(color='plum')))
    fig1.add_trace(go.Scatter(x=NitricOxide[0:-1], y=zg1[0:-1],name="NO",mode='lines',marker=dict(color='peachpuff')))
    fig1.add_trace(go.Scatter(x=Nitrogen_ion[0:-1], y=zg1[0:-1],name="N+",mode='lines',marker=dict(color='olive')))
    
    fig1.update_layout(xaxis_type="log",xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$cm^{-3}$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Densities  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show()
    
def plot_velocities(timer):
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    fig1 = go.Figure()
    fig1.add_trace(go.Scatter(x=vi_op_x1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O+ velocity (x)",mode='lines',marker=dict(color='blue')))
    fig1.add_trace(go.Scatter(x=vi_o2p_x1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O2+ velocity (x)",mode='lines',marker=dict(color='dodgerblue')))
    fig1.add_trace(go.Scatter(x=vi_nop_x1[0:-1], y=zg1[0:-1],name="Perpendicular <br> NO+ velocity (x)",mode='lines',marker=dict(color='lightsteelblue')))
    fig1.add_trace(go.Scatter(x=unvx1[0:-1], y=zg1[0:-1],name="Perpendicular <br> Neutral velocity (x)",mode='lines',marker=dict(color='green')))
    fig1.add_trace(go.Scatter(x=ExBx1[0:-1], y=zg1[0:-1],name="ExB drift <br> velocity (x)",mode='lines',marker=dict(color='red')))
     
    fig1.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$m/s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Veocities  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig1.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig1.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig1.show() 
    
    fig2 = go.Figure()
    fig2.add_trace(go.Scatter(x=vi_op_y1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O+ velocity (y)",mode='lines',marker=dict(color='blue'))) 
    fig2.add_trace(go.Scatter(x=vi_o2p_y1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O2+ velocity (y)",mode='lines',marker=dict(color='dodgerblue'))) 
    fig2.add_trace(go.Scatter(x=vi_nop_y1[0:-1], y=zg1[0:-1],name="Perpendicular <br> NO+ velocity (y)",mode='lines',marker=dict(color='lightsteelblue'))) 
    fig2.add_trace(go.Scatter(x=unvy1[0:-1], y=zg1[0:-1],name="Perpendicular <br> Neutral velocity (y)",mode='lines',marker=dict(color='green')))
    fig2.add_trace(go.Scatter(x=ExBy1[0:-1], y=zg1[0:-1],name="ExB drift <br> velocity (y)",mode='lines',marker=dict(color='red')))
       
    fig2.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$m/s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Veocities  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig2.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig2.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig2.show()
    
    fig3 = go.Figure()
    fig3.add_trace(go.Scatter(x=vi_op_z1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O+ velocity (z)",mode='lines',marker=dict(color='blue')))
    fig3.add_trace(go.Scatter(x=vi_o2p_z1[0:-1], y=zg1[0:-1],name="Perpendicular <br> O2+ velocity (z)",mode='lines',marker=dict(color='dodgerblue')))
    fig3.add_trace(go.Scatter(x=vi_nop_z1[0:-1], y=zg1[0:-1],name="Perpendicular <br> NO+ velocity (z)",mode='lines',marker=dict(color='lightsteelblue')))
    fig3.add_trace(go.Scatter(x=unvz1[0:-1], y=zg1[0:-1],name="Perpendicular <br> Neutral velocity (z)",mode='lines',marker=dict(color='green')))
    fig3.add_trace(go.Scatter(x=ExBz1[0:-1], y=zg1[0:-1],name="ExB drift <br> velocity (z)",mode='lines',marker=dict(color='red')))
      
    fig3.update_layout(xaxis_showexponent='all', xaxis_exponentformat = 'power',
    yaxis_tick0 = 60,yaxis_dtick = 20,xaxis_title="$m/s$",yaxis_title="Altitude (km)",width=750,height=750,
    title={'text':'Veocities  %s <br> lattitude=%s longitude=%s' % (time_plot.strftime("%d %b %Y %H:%M:%S"),lat_out[0],lon_out[0]),
           'y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'})    
    fig3.update_xaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_yaxes(showgrid=True, gridwidth=0.5, gridcolor='grey')
    fig3.update_xaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.update_yaxes(showline=True, linewidth=2, linecolor='black', mirror=True)
    fig3.show()
    
def Lat_Alt_plot(param,timer):
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptimel[timer])
    if param == 'Pedersen':
        parameter = sigmaPedfl
    if param == 'Joule Heating':
        parameter = Joulel
        
    if param == 'Pressure_Ohmic ratio':
        parameter = Press_Ohmicl
    if param == 'O+':
        parameter = NOpfl
    if param == 'O2+':
        parameter = NO2pfl
    if param == 'NO+':
        parameter = NNOpfl
    if param == 'σNO+n':
        parameter = cross_section_nopl
    if param == 'σO2+n':
        parameter = cross_section_o2pl
    if param == 'σ':
        parameter = cross_sectionl
    if param == 'vNO+n':
        parameter = vNOpfl
        
    if param == 'Ion Heating Rate':
        parameter = qDTi_nfl
        
        
    if param == 'Frictional Heating':
        parameter = Frictionall
    if param == 'Ohmic Heating':
        parameter = Ohmicl
    if param == 'Ohmic Heating per mass':
        parameter = JH_rhol
    if param == 'Ohmic Heating per pressure':
        parameter = Ohmic_Pressl
    if param == 'Convenction Heating':
        parameter = Convenction_heating_Outl
    if param == 'Wind Heating':
        parameter = Wind_heating_Outl
    if param == 'Energy':
        parameter = Energy_Outl
    if param == 'Mechanical Power':
        parameter = Mechanical_power_Outl
        
    if param == 'Ti':
        parameter = Ti_Outl
    if param == 'Te':
        parameter = Te_Outl
    if param == 'Tn':
        parameter = Tn_Outl
    if param == 'νO+n':
        parameter = vOpfl
    if param == 'νO2+n':
        parameter = vO2pfl
    if param == 'νin':
        parameter = vinfl
    if param == 'νen':
        parameter = venfl
    if param == 'σO+n':
        parameter = cross_section_opl
    if param == 'Parallel':
        parameter = sigma_parl
        
    if param == 'Hall':
        parameter = sigmaHallfl
    if param == 'O':
        parameter = NOfl
    if param == 'O2':
        parameter = NO2fl
    if param == 'N2':
        parameter = NN2fl
    if param == 'Ne':
        parameter = Nefl
    if param == 'Potential':
        parameter = Potfl
    if param == 'Pressure':
        parameter = Pressure_2Dl 
    x_value=maplatl[:]
    y_value=mapaltl[:]
    X,Y= np.meshgrid(x_value,y_value)
  
    fig = plt.figure(figsize=(15,4))
   
   
    z_min=parameter.min()
    z_max=parameter.max()






    
    if param == 'Joule Heating':
        plt.title("Joule Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Frictional Heating':
        plt.title("Frictional Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Ohmic Heating':
        plt.title("Ohmic Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Ohmic Heating per mass':
        plt.title("Ohmic Heating per Mass (mW/kg) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Ohmic Heating per pressure':
        plt.title("Ohmic Heating per pressure (1/s) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='gist_ncar'
    if param == 'Convenction Heating':
        plt.title("Convenction Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Wind Heating':
        plt.title("Wind Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Energy':
        plt.title("Energy Dissipation/Generation (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'
    if param == 'Mechanical Power':
        plt.title("Mechanical Power (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'        
    if param == 'Ion Heating Rate':
        plt.title("Ion Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='jet'        
    if param == 'Pressure_Ohmic ratio':
        plt.title("Pressure/Heating Ratio (s) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='gist_ncar'
    if param == 'O+':
        plt.title("O+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'O2+':
        plt.title("O2+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'NO+':
        plt.title("NO+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'σNO+n':
        plt.title("NO+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'σO2+n':
        plt.title("O2+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'σ':
        plt.title("Ion cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'vNO+n':
        plt.title("NO+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    
    if param == 'Ti':
        plt.title("Ion Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='gnuplot'
    if param == 'Te':
        plt.title("Electron Temeperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='gnuplot'
    if param == 'Tn':
        plt.title("Neutral Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='gnuplot'
    if param == 'νO+n':
        plt.title("O+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'νO2+n':
        plt.title("O2+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'νin':
        plt.title("Ion-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'νen':
        plt.title("Electron-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'σO+n':
        plt.title("O+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='CMRmap'
    if param == 'Parallel':
        plt.title("Parallel Conductivity (Si/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='afmhot'

    if param == 'Pedersen':
        plt.title("Pendersen Conductivity ($10^{-5}$ mho/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='afmhot'
    if param == 'Hall':
        plt.title("Hall Conductivity (Si/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='afmhot'
    if param == 'O':
        plt.title("O ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'O2':
        plt.title("$O_{2}$ ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'N2':
        plt.title("$N_{2}$ ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'Ne':
        plt.title("Electron Density ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        cmp='cubehelix'
    if param == 'Pressure':
        plt.title("Pressure (Pa) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    
#     divider = make_axes_locatable(ax)
#     cax1 = divider.append_axes("right", size="5%", pad=0.2, aspect=20, label='[w/m^3]')
#     cbar = plt.colorbar(cs, cax = cax1)
#     divider = make_axes_locatable(ax1)
#     cax1 = divider.append_axes("right", size="5%", pad=0.2, aspect=20)
#     cbar = plt.colorbar(sc, cax = cax1)
    sc = plt.imshow(parameter, cmap =cmp, vmin = z_min, vmax = z_max, 
                     extent =[X.min(), X.max(), Y.min(), Y.max()], 
                      interpolation ='bicubic', origin ='lower',aspect='auto') 

    plt.colorbar()
    plt.xlabel('Latitude (deg)')
    plt.ylabel('Altitude (km)')
    plt.show()
def Joule_map(param,timer):

    x_value=maplon[:]
    y_value=maplat[:][::-1]
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    if param == 'Pedersen':
        parameter = sigmaPedf
    if param == 'Joule Heating':
        parameter = Joule
        
    if param == 'Pressure_Ohmic ratio':
        parameter = Press_Ohmic
    if param == 'O+':
        parameter = NOpf
    if param == 'O2+':
        parameter = NO2pf
    if param == 'NO+':
        parameter = NNOpf
    if param == 'σNO+n':
        parameter = cross_section_nop
    if param == 'σO2+n':
        parameter = cross_section_o2p
    if param == 'σ':
        parameter = cross_section
    if param == 'vNO+n':
        parameter = vNOpf
        
    if param == 'Ion Heating Rate':
        parameter = qDTi_nf
        
        
    if param == 'Frictional Heating':
        parameter = Frictional
    if param == 'Ohmic Heating':
        parameter = Ohmic
    if param == 'Ohmic Heating per mass':
        parameter = JH_rho
    if param == 'Ohmic Heating per pressure':
        parameter = Ohmic_Press
    if param == 'Convenction Heating':
        parameter = Convenction_heating_Out
    if param == 'Wind Heating':
        parameter = Wind_heating_Out
    if param == 'Energy':
        parameter = Energy_Out
    if param == 'Mechanical Power':
        parameter = Mechanical_power_Out
        
    if param == 'Ti':
        parameter = Ti_Out
    if param == 'Te':
        parameter = Te_Out
    if param == 'Tn':
        parameter = Tn_Out
    if param == 'νO+n':
        parameter = vOpf
    if param == 'νO2+n':
        parameter = vO2pf
    if param == 'νin':
        parameter = vinf
    if param == 'νen':
        parameter = venf
    if param == 'σO+n':
        parameter = cross_section_op
    if param == 'Parallel':
        parameter = sigma_par
        
    if param == 'Hall':
        parameter = sigmaHallf
    if param == 'O':
        parameter = NOf
    if param == 'O2':
        parameter = NO2f
    if param == 'N2':
        parameter = NN2f
    if param == 'Ne':
        parameter = Nef
    if param == 'Potential':
        parameter = Potf
    if param == 'Pressure':
        parameter = Pressure_2D
        
    plt.rcParams['figure.figsize'] = (15, 15)
    fig = plt.figure()
    ax1 = fig.add_subplot(1, 1, 1,  aspect='equal')
  
    # llcrnrlat,llcrnrlon,urcrnrlat,urcrnrlon
    # are the lat/lon values of the lower left and upper right corners
    # of the map.
    # resolution = 'c' means use crude resolution coastlines.
    m = Basemap(projection='cyl',llcrnrlat=-90,urcrnrlat=90,\
                llcrnrlon=-180,urcrnrlon=180,resolution='c')
    m.drawcoastlines()
    if param == 'Pedersen':
        sc=m.imshow(parameter,cmap='afmhot',interpolation = 'bicubic')
    if param == 'Joule Heating':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Ohmic Heating per mass':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Ohmic Heating per pressure':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Frictional Heating':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Ohmic Heating':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Convenction Heating':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Wind Heating':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Energy':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')
    if param == 'Mechanical Power':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')

    if param == 'Ion Heating Rate':
        sc=m.imshow(parameter,cmap='jet',interpolation = 'bicubic')

    if param == 'Pressure_Ohmic ratio':
        sc=m.imshow(parameter,cmap='gist_ncar',interpolation = 'bicubic')
    if param == 'O+':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'O2+':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'NO+':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'σNO+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'σO2+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'σ':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'vNO+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    
        
    if param == 'Ti':
        sc=m.imshow(parameter,cmap='gnuplot',interpolation = 'bicubic')
    if param == 'Te':
        sc=m.imshow(parameter,cmap='gnuplot',interpolation = 'bicubic')
    if param == 'Tn':
        sc=m.imshow(parameter,cmap='gnuplot',interpolation = 'bicubic')
    if param == 'νO+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'νO2+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'νin':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'νen':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'σO+n':
        sc=m.imshow(parameter,cmap='CMRmap',interpolation = 'bicubic')
    if param == 'Parallel':
        sc=m.imshow(parameter,cmap='afmhot',interpolation = 'bicubic')
        
    if param == 'Ne':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'Hall':
        sc=m.imshow(parameter,cmap='afmhot',interpolation = 'bicubic')
    if param == 'O':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'O2':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'N2':
        sc=m.imshow(parameter,cmap='cubehelix',interpolation = 'bicubic')
    if param == 'Potential':
        sc=m.imshow(parameter,cmap='BrBG',interpolation = 'bicubic')
    if param == 'Pressure':
        sc=m.imshow(parameter,cmap='RdPu',interpolation = 'bicubic')
        
        
    if night_checkbox.value == True:
        CS=m.nightshade(time_plot, alpha=0.3)
        
    #m.fillcontinents(color='coral',lake_color='aqua')
    # draw parallels and meridians.
    m.drawparallels(np.arange(-90.,91.,30.))
    m.drawmeridians(np.arange(-180.,181.,60.))
    #m.drawmapboundary(fill_color='aqua')
    plt.xticks(np.arange(-180.,181.,60.))
    plt.yticks(np.arange(-90.,91.,30.))
    plt.xlabel('Lon (deg)')
    plt.ylabel('Lat (deg)')
    
  
    if param == 'Joule Heating':
        plt.title("Joule Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Frictional Heating':
        plt.title("Frictional Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating':
        plt.title("Ohmic Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating per mass':
        plt.title("Ohmic Heating per Mass (mW/kg) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating per pressure':
        plt.title("Ohmic Heating per pressure (1/s) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Convenction Heating':
        plt.title("Convenction Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Wind Heating':
        plt.title("Wind Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Energy':
        plt.title("Energy Dissipation/Generation (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Mechanical Power':
        plt.title("Mechanical Power (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    if param == 'Ion Heating Rate':
        plt.title("Ion Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    if param == 'Pressure_Ohmic ratio':
        plt.title("Pressure/Heating Ratio (s) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O+':
        plt.title("O+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O2+':
        plt.title("O2+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'NO+':
        plt.title("NO+ Density ($cm^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σNO+n':
        plt.title("NO+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σO2+n':
        plt.title("O2+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σ':
        plt.title("Ion cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'vNO+n':
        plt.title("NO+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    
    if param == 'Ti':
        plt.title("Ion Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Te':
        plt.title("Electron Temeperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Tn':
        plt.title("Neutral Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νO+n':
        plt.title("O+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νO2+n':
        plt.title("O2+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νin':
        plt.title("Ion-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νen':
        plt.title("Electron-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σO+n':
        plt.title("O+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Parallel':
        plt.title("Parallel Conductivity (Si/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))

    if param == 'Pedersen':
        plt.title("Pendersen Conductivity ($10^{-5}$ mho/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Hall':
        plt.title("Hall Conductivity (Si/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O':
        plt.title("O ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O2':
        plt.title("$O_{2}$ ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'N2':
        plt.title("$N_{2}$ ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ne':
        plt.title("Electron Density ($m^{-3}$) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Pressure':
        plt.title("Pressure (Pa) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    
        
    divider = make_axes_locatable(ax1)
    cax1 = divider.append_axes("right", size="5%", pad=0.2, aspect=20, label='[w/m^3]')
    cbar = plt.colorbar(sc, cax = cax1)
    plt.show()
    

   
    
def quiver_plot(ploting,back,vec,timer):
    x_value=maplon[:]
    y_value=maplat[:]
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    m = Basemap(projection='npstere',boundinglat=40,lon_0=0,resolution='l', round=True,)
        
    if back == 'Potential':
        background=Potf
        cmap='BrBG'
    if back == 'Joule Heating':
        background = Joule
        cmap='jet'
    if back == 'Pedersen':
        background = sigmaPedf
        cmap='afmhot'
    if back == 'Hall':
        background = sigmaHallf
        cmap='afmhot'
    if back == 'Current':
        background = J_mag
        cmap='viridis'
    if back == 'Frictional Heating':
        background = Frictional
        cmap='jet'
    if back == 'Ohmic Heating':
        background = Ohmic
        cmap='jet'
    if back == 'Convenction Heating':
        background = Convenction_heating_Out
        cmap='jet'
    if back == 'Wind Heating':
        background = Wind_heating_Out
        cmap='jet'
    if back == 'Energy':
        background = Energy_Out
        cmap='jet'
    if back == 'Mechanical Power':
        background = Mechanical_power_Out
        cmap='jet'
    if back == 'Ion Drift':
        background = vi_mag
        cmap='ocean'
    if back == 'Parallel':
        background = sigma_par
        cmap='afmhot'

    
    if vec == 'Electric Field':
        Veast=Evertx
        Vnorth=Everty
    if vec == 'Magnetic Field':
        Veast=Bxf
        Vnorth=Byf
    if vec == 'Pedersen Current':
        Veast=J_Pede
        Vnorth=J_Pedn
    if vec == 'Hall Current':
        Veast=J_Halle
        Vnorth=J_Halln
    if vec == 'Perpendicular Current':
        Veast=J_Ohme
        Vnorth=J_Ohmn
    if vec == 'Ion Velocity':
        Veast=vi_starxf
        Vnorth=vi_staryf
    if vec == 'Neutral Winds':
        Veast=Unef
        Vnorth=Unnf
    if vec == 'JxB':
        Veast=JxBe
        Vnorth=JxBn
    
        
    Ee2,lonsout=addcyclic(Veast,x_value)
    En2,lonsout=addcyclic(Vnorth,x_value)
    
    
    
    
    Potf2, lonsout=addcyclic(background,x_value)
    lonsout,parameter=m.shiftdata(lonsout, datain = Potf2, lon_0=0)
    
    lon, lat = np.meshgrid(lonsout,y_value)
    
    

    x, y = m(lon, lat)

    
    fig = plt.figure(figsize=(15,15))
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
 
    
    Eeproj,Enproj,xx,yy = m.transform_vector(Ee2,En2,lonsout,y_value,144,72,returnxy=True,masked=True)
    
    Emag=np.sqrt(Eeproj**2+Enproj**2)
    
    if ploting == 'Streamplot':
        cf=m.contourf(x,y,Potf2,50,cmap=cmap)
        cbar=plt.colorbar(cf,fraction=0.046, pad=0.04)
        if back == 'Potential':
            cbar.ax.set_ylabel('Electric Potential (V)', rotation=270, size=20, labelpad=30)
        if back == 'Joule Heating':
            cbar.ax.set_ylabel('Joule Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Frictional Heating':
            cbar.ax.set_ylabel('Frictional Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Ohmic Heating':
            cbar.ax.set_ylabel('Ohmic Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Convenction Heating':
            cbar.ax.set_ylabel('Convenction Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Wind Heating':
            cbar.ax.set_ylabel('Wind Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Mechanical Power':
            cbar.ax.set_ylabel('Mechanical Power ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Energy':
            cbar.ax.set_ylabel('Energy Dissipation/Generation ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Ion Drift':
            cbar.ax.set_ylabel('Ion Drift($m/s$)', rotation=270, size=20, labelpad=30)
        if back == 'Pedersen':
            cbar.ax.set_ylabel('Penersen Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Hall':
            cbar.ax.set_ylabel('Hall Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Parallel':
            cbar.ax.set_ylabel('Parallel Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Current':
            cbar.ax.set_ylabel('Current Density ($A/m^{2}$)', rotation=270, size=20, labelpad=30)
            
            
            
            
    if ploting == 'Vector':
        cf=m.contourf(x,y,Potf2,50,cmap=cmap)
        cbar=plt.colorbar(cf,fraction=0.046, pad=0.04)
        if back == 'Potential':
            cbar.ax.set_ylabel('Electric Potential (V)', rotation=270, size=20, labelpad=30)
        if back == 'Joule Heating':
            cbar.ax.set_ylabel('Joule Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Frictional Heating':
            cbar.ax.set_ylabel('Frictional Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Ohmic Heating':
            cbar.ax.set_ylabel('Ohmic Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Convenction Heating':
            cbar.ax.set_ylabel('Convenction Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Wind Heating':
            cbar.ax.set_ylabel('Wind Heating ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Mechanical Power':
            cbar.ax.set_ylabel('Mechanical Power ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Energy':
            cbar.ax.set_ylabel('Energy Dissipation/Generation ($mW/m^{3}$)', rotation=270, size=20, labelpad=30)
        if back == 'Ion Drift':
            cbar.ax.set_ylabel('Ion Drift($m/s$)', rotation=270, size=20, labelpad=30)
        if back == 'Pedersen':
            cbar.ax.set_ylabel('Penersen Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Hall':
            cbar.ax.set_ylabel('Hall Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Parallel':
            cbar.ax.set_ylabel('Parallel Conductivity ($10^{-5} mho/m$)', rotation=270, size=20, labelpad=30)
        if back == 'Current':
            cbar.ax.set_ylabel('Current Density ($A/m^{2}$)', rotation=270, size=20, labelpad=30)
    
   
    if ploting == 'Vector':
        vecplot=m.quiver(xx[::2],yy[::2],Eeproj[::2],Enproj[::2],units='width')
        if vec == 'Neutral Winds':
            qk = plt.quiverkey(vecplot, 0.1, 0.01, 200, '200 m/s', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.85, 'Neutral Winds', fontsize=25, fontweight='bold')
        if vec == 'Ion Velocity':
            qk = plt.quiverkey(vecplot, 0.1, 0.01, 200, '200 m/s', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.85, 'Ion Velocity', fontsize=25, fontweight='bold')
        if vec == 'Electric Field':
            qk = plt.quiverkey(vecplot, 0.1, 0.01, 0.1, '0.1 V/m', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.85, 'Electric Field', fontsize=25, fontweight='bold')
        if vec == 'Pedersen Current':
            qk = plt.quiverkey(vecplot, 0.1, 0.01, 10**(-5), '$10^{-5}$ $A/m^{2}$', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.87, 'Pedersen current density', fontsize=25, fontweight='bold')
        if vec == 'Hall Current':
            qk = plt.quiverkey(vecplot, 0.1, 0.01, 10**(-6), '$10^{-6}$ $A/m^{2}$', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.87, 'Hall current density', fontsize=25, fontweight='bold')
        if vec == 'Peprendicular Current':
#             qk = plt.quiverkey(vecplot, 0.1, 0.01, 10**(-6), '$10^{-6}$ $A/m^{2}$', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.87, 'Perpendicular current density', fontsize=25, fontweight='bold')
        if vec == 'JxB':
#             qk = plt.quiverkey(vecplot, 0.1, 0.01, 10**(-6), '$10^{-6}$ $N/m^{3}$', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.87, 'JxB', fontsize=25, fontweight='bold')
        if vec == 'Magnetic Field':
#             qk = plt.quiverkey(vecplot, 0.1, 0.01, 10**(-9), '$10^{-9}$ $T$', labelpos='W',fontproperties={'size': 20})
            fig.text(0.1, 0.87, 'Magnetic Field', fontsize=25, fontweight='bold')


    if ploting == 'Streamplot':
        m.streamplot(xx,yy,Eeproj,Enproj, density=[3, 3],linewidth=2)
        if vec == 'Neutral Winds':
            fig.text(0.1, 0.85, 'Neutral Winds', fontsize=25, fontweight='bold')
        if vec == 'Ion Velocity':
             fig.text(0.1, 0.85, 'Ion Velocity', fontsize=25, fontweight='bold')
        if vec == 'Electric Field':
             fig.text(0.1, 0.85, 'Electric Field', fontsize=25, fontweight='bold')
        if vec == 'Pedersen Current':
             fig.text(0.1, 0.87, 'Pedersen current density', fontsize=25, fontweight='bold')
        if vec == 'Hall Current':
             fig.text(0.1, 0.87, 'Hall current density', fontsize=25, fontweight='bold')
        if vec == 'Peprendicular Current':
             fig.text(0.1, 0.87, 'Perpendicular current density', fontsize=25, fontweight='bold')
        if vec == 'JxB':
             fig.text(0.1, 0.87, 'JxB', fontsize=25, fontweight='bold')
        if vec == 'Magnetic Field':
             fig.text(0.1, 0.87, 'Magnetic Field', fontsize=25, fontweight='bold')
        
    if night_checkbox.value == True:
        m.nightshade(time_plot)
    
def Joule_ortho_plot(param, center_lat,center_lon,timer):
    x_value=maplon[:]
    y_value=maplat[:]
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    
    if param == 'Pedersen':
        parameter = sigmaPedf
    if param == 'Joule Heating':
        parameter = Joule
    if param == 'Hall':
        parameter = sigmaHallf
    if param == 'O':
        parameter = NOf
    if param == 'O2':
        parameter = NO2f
    if param == 'N2':
        parameter = NN2f
    if param == 'Ne':
        parameter = Nef
    if param == 'Potential':
        parameter = Potf

    if param == 'Ion Heating Rate':
        parameter = qDTi_nf
        
            
    if param == 'Pressure_Ohmic ratio':
        parameter = Press_Ohmic
    if param == 'O+':
        parameter = NOpf
    if param == 'O2+':
        parameter = NO2pf
    if param == 'NO+':
        parameter = NNOpf
    if param == 'σNO+n':
        parameter = cross_section_nop
    if param == 'σO2+n':
        parameter = cross_section_o2p
    if param == 'σ':
        parameter = cross_section
    if param == 'vNO+n':
        parameter = vNOpf
        
    if param == 'Frictional Heating':
        parameter = Frictional
    if param == 'Ohmic Heating':
        parameter = Ohmic
    if param == 'Ohmic Heating per mass':
        parameter = JH_rho
    if param == 'Ohmic Heating per pressure':
        parameter = Ohmic_Press
    if param == 'Convenction Heating':
        parameter = Convenction_heating_Out
    if param == 'Wind Heating':
        parameter = Wind_heating_Out
    if param == 'Energy':
        parameter = Energy_Out
    if param == 'Mechanical Power':
        parameter = Mechanical_power_Out
    if param == 'Ti':
        parameter = Ti_Out
    if param == 'Te':
        parameter = Te_Out
    if param == 'Tn':
        parameter = Tn_Out
    if param == 'νO+n':
        parameter = vOpf
    if param == 'νO2+n':
        parameter = vO2pf
    if param == 'νin':
        parameter = vinf
    if param == 'νen':
        parameter = venf
    if param == 'σO+n':
        parameter = cross_section 
    if param == 'Parallel':
        parameter = sigma_par
    if param == 'Pressure':
        parameter = Pressure_2D
               

    m = Basemap(projection='ortho',lat_0=center_lat,lon_0=center_lon,resolution='l')
    parameter, lons=addcyclic(parameter,x_value)
    lons, parameter = m.shiftdata(lons, datain = parameter, lon_0=0)
    
    lon, lat = np.meshgrid(lons,y_value)
    x, y = m(lon, lat)
    fig = plt.figure(figsize=(17,7))
#     m.fillcontinents(color='gray',lake_color='gray')
    m.drawcoastlines()
#     m.bluemarble()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    m.bluemarble()
    if night_checkbox.value == True:
        CS=m.nightshade(time_plot)
    if param == 'Joule Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Joule Heating Rate (mW/m^3)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    if param == 'Frictional Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Frictional Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Ohmic Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating per mass':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Ohmic Heating per Mass (mW/kg) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ohmic Heating per pressure':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Ohmic Heating per Mass (mW/(Pa*m^3)) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Convenction Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Convenction Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Wind Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Wind Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Energy':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Energy Dissipation/Generation (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Mechanical Power':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Mechanical Power (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S")) 
        
    if param == 'Ion Heating Rate':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.title("Ion Heating Rate (mW/m^3) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    
    if param == 'Pressure_Ohmic ratio':
        cs = m.contourf(x,y,parameter,60,cmap='gist_ncar')
        plt.title("Pressure/Heating ratio (s) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S")) 
    if param == 'O+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("O+ Density ($cm^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O2+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title(")2+ Density ($cm^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'NO+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("NO+ Density ($cm^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("NO+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("O2+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σ':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("Ion cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'vNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("NO+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    if param == 'Ti':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.title("Ion Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Te':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.title("Electron Temeperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Tn':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.title("Neutral Temperature (K) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("O+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("O2+-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νin':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("Ion-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'νen':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("Electron-Neutral collision frequency (Hz) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'σO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.title("O+ cross section (m^2) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Parallel':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.title("Parallel Conductivity (Si/m) - %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    if param == 'Pedersen':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.title("Pendersen Conductivity ($10^{-5}$ mho/m)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Hall':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.title("Hall Conductivity ($10^{-5}$ mho/m)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("O ($m_{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'O2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("$O_{2}$ ($m^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'N2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("$N_{2}$ ($m^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Ne':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.title("Electron Density ($m^{-3}$)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Potential':
        cs = m.contourf(x,y,parameter,60,cmap='BrBG')
        plt.title("Electirc Potential (kV)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
    if param == 'Pressure':
        cs = m.contourf(x,y,parameter,60,cmap='RdPu')
        plt.title("Pressure (Pa)- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
        
    plt.colorbar();

def Joule_polar_plot(param, Bound_lat, orbit_file,timer):
    
    x_value=maplon[:]
    y_value=maplat[:]
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
   
    if param == 'Pedersen':
        parameter = sigmaPedf
    if param == 'Joule Heating':
        parameter = Joule
    if param == 'Hall':
        parameter = sigmaHallf
    if param == 'O':
        parameter = NOf
    if param == 'O2':
        parameter = NO2f
    if param == 'N2':
        parameter = NN2f
    if param == 'Ne':
        parameter = Nef
    if param == 'Potential':
        parameter = Potf
    if param == 'Frictional Heating':
        parameter = Frictional
    if param == 'Ohmic Heating':
        parameter = Ohmic
    if param == 'Ohmic Heating per mass':
        parameter = JH_rho
    if param == 'Ohmic Heating per pressure':
        parameter = Ohmic_Press
    if param == 'Convenction Heating':
        parameter = Convenction_heating_Out
    if param == 'Wind Heating':
        parameter = Wind_heating_Out
    if param == 'Energy':
        parameter = Energy_Out
    if param == 'Mechanical Power':
        parameter = Mechanical_power_Out   

    if param == 'Ion Heating Rate':
        parameter = qDTi_nf
        
    if param == 'Pressure_Ohmic ratio':
        parameter = Press_Ohmic
    if param == 'O+':
        parameter = NOpf
    if param == 'O2+':
        parameter = NO2pf
    if param == 'NO+':
        parameter = NNOpf
    if param == 'σNO+n':
        parameter = cross_section_nop
    if param == 'σO2+n':
        parameter = cross_section_o2p
    if param == 'σ':
        parameter = cross_section
    if param == 'vNO+n':
        parameter = vNOpf
        
    if param == 'Ti':
        parameter = Ti_Out
    if param == 'Te':
        parameter = Te_Out
    if param == 'Tn':
        parameter = Tn_Out
    if param == 'νO+n':
        parameter = vOpf
    if param == 'νO2+n':
        parameter = vO2pf
    if param == 'νin':
        parameter = vinf
    if param == 'νen':
        parameter = venf
    if param == 'σO+n':
        parameter = cross_section  
    if param == 'Parallel':
        parameter = sigma_par
    if param == 'Pressure':
        parameter = Pressure_2D
    
    #m.fillcontinents(color='gray',lake_color='gray')
    m = Basemap(projection='npstere',boundinglat=Bound_lat,lon_0=0,resolution='l', round=True,)
    parameter, lons=addcyclic(parameter,x_value)
    lons, parameter = m.shiftdata(lons, datain = parameter, lon_0=0)
    
    lon, lat = np.meshgrid(lons,y_value)
    x, y = m(lon, lat)
    fig = plt.figure(figsize=(15,7))
    #m.fillcontinents(color='gray',lake_color='gray')
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    
   
    if param == 'Joule Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
        
    if param == 'Frictional Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating per mass':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating per pressure':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Convenction Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Wind Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Energy':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Mechanical Power':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar(); 
    if param == 'Ion Heating Rate':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
        
    if param == 'Pressure_Ohmic ratio':
        cs = m.contourf(x,y,parameter,60,cmap='gist_ncar')
        plt.colorbar();
    if param == 'O+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'O2+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'NO+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'σNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'σO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'σ':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'vNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
        
        
    if param == 'Ti':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'Te':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'Tn':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'νO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νin':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νen':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'σO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'Parallel':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar(); 

    if param == 'Pedersen':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar();
    if param == 'Hall':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar();
    if param == 'O':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'O2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'N2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'Ne':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'Potential':
        cs = m.contourf(x,y,parameter,60,cmap='BrBG')
        plt.colorbar();
        m.contour(x,y,parameter,20,alpha=0.7, colors='k')
    if param == 'Pressure':
        cs = m.contourf(x,y,parameter,60,cmap='RdPu')
        plt.colorbar();
        m.contour(x,y,parameter,20,alpha=0.7, colors='k')
  
   
    if night_checkbox.value == True:
        CS=m.nightshade(time_plot, alpha=0.3)
#     cbJH=plt.colorbar();
    
    if orbit_checkbox.value == True:
        input_file=pd.read_csv(orbit_file,sep=',')
        daed_lat=np.array(input_file['Lat_GEOD(deg)'], dtype=float)
        daed_lon=np.array(input_file['Lon_GEOD(deg)'], dtype=float)
        daed_alt=np.array(input_file['Height_WGS84 (km)'], dtype=float)
        daed_x,daed_y=m(daed_lon,daed_lat)
        m.scatter(daed_x,daed_y,c='k', s=7,marker='o')
        
#         plt.scatter(daed_x,daed_y,c=daed_alt, cmap='afmhot', s=10,marker='o')
#         cb=plt.colorbar();
#         cb.set_label('Daedalus Altitude (km)')
        
    if param == 'Joule Heating':
#         plt.title("Joule Heating Rate (mW/m^3)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Joule Heating Rate [$mW/m^{3}$]')
        fig.text(0.35, 0.90, 'Joule Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
        
    if param == 'Ion Heating Rate':
#         plt.title("Joule Heating Rate (mW/m^3)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Joule Heating Rate [$mW/m^{3}$]')
        fig.text(0.35, 0.90, 'Ion Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
        
    if param == 'Frictional Heating':
        fig.text(0.35, 0.90, 'Frictional Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Ohmic Heating':
        fig.text(0.35, 0.90, 'Ohmic Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Ohmic Heating per mass':
        fig.text(0.35, 0.90, 'Ohmic Heating per Mass', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/kg$]" , fontsize=17)
    if param == 'Ohmic Heating per pressure':
        fig.text(0.35, 0.90, 'Ohmic Heating per Pressure', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$1/s$]" , fontsize=17)
    if param == 'Convenction Heating':
        fig.text(0.35, 0.90, 'Convenction Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Wind Heating':
        fig.text(0.35, 0.90, 'Wind Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Energy':
        fig.text(0.35, 0.90, 'Energy Dissipation/Generation', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Mechanical Power':
        fig.text(0.35, 0.90, 'Mechanical Power Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)  
        
        
    if param == 'Pressure_Ohmic ratio':
        fig.text(0.35, 0.90, 'Pressure/Heaitng ratio', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$s$]" , fontsize=17)
    if param == 'O+':
        fig.text(0.35, 0.90, 'O+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'O2+':
        fig.text(0.35, 0.90, 'O2+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'NO+':
        fig.text(0.35, 0.90, 'NO+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'σNO+n':
        fig.text(0.35, 0.90, 'NO+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σO2+n':
        fig.text(0.35, 0.90, 'O2+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σ':
        fig.text(0.35, 0.90, 'Ion Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'vNO+n':
        fig.text(0.35, 0.90, 'NO+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
        
    if param == 'Ti':
        fig.text(0.35, 0.90, 'Ion Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$K$]" , fontsize=17)  
    if param == 'Te':
        fig.text(0.35, 0.90, 'Electron Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$K$]" , fontsize=17)  
    if param == 'Tn':
        fig.text(0.35, 0.90, 'Neutral Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)  
    if param == 'νO+n':
        fig.text(0.35, 0.90, 'O+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νO2+n':
        fig.text(0.35, 0.90, 'O2+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νin':
        fig.text(0.35, 0.90, 'Ion-Neutral Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νen':
        fig.text(0.35, 0.90, 'Electron-Neutral Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σO+n':
        fig.text(0.35, 0.90, 'O+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$m^{2}$]" , fontsize=17)  
    if param == 'Parallel':
        fig.text(0.35, 0.90, 'Pendersen Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)  
    
     
    if param == 'Pedersen':
#         plt.title("Pendersen Conductivity ($10^{-5}$ mho/m)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Pendersen Conductivity ($10^{-5}$ mho/m)')
        fig.text(0.35, 0.90, 'Pendersen Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.64, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)
        
    if param == 'Hall':
#         plt.title("Hall Conductivity (Si/m)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Hall Conductivity (Si/m)')
        fig.text(0.35, 0.90, 'Hall Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.64, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)
        
    if param == 'O':
#         plt.title("O ($cm_{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('O ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Atomic Oxygen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'O2':
#         plt.title("$O_{2}$ ($cm^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$O_{2}$ ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Molecular Oxygen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'N2':
#         plt.title("$N_{2}$ ($cm^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$N_{2}$ ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Molecular Nitrogen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'Ne':
#         plt.title("Electron Density ($m^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$N_{e}$ ($m^{-3}$)')
        fig.text(0.35, 0.90, 'Electron Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
    if param == 'Potential':
        fig.text(0.35, 0.90, 'Electric Potential', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$kV$]" , fontsize=17)
    if param == 'Pressure':
        fig.text(0.35, 0.90, 'Pressure', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$Pa$]" , fontsize=17)
                
   

def Joule_polar_plot_South(param,Bound_lat,timer):
    
    x_value=maplon[:]
    y_value=maplat[:]
    
    time_begin=datetime.datetime(2015,3,15,0,0,0)
    time_plot=time_begin+datetime.timedelta(minutes=maptime[timer])
    
    X,Y = np.meshgrid(x_value,y_value)
    if param == 'Pedersen':
        parameter = sigmaPedf
    if param == 'Joule Heating':
        parameter = Joule
    
    if param == 'Hall':
        parameter = sigmaHallf
    if param == 'O':
        parameter = NOf
    if param == 'O2':
        parameter = NO2f
    if param == 'N2':
        parameter = NN2f 
    if param == 'Ne':
        parameter = Nef
    if param == 'Potential':
        parameter = Potf
    if param == 'Frictional Heating':
        parameter = Frictional
    if param == 'Ohmic Heating':
        parameter = Ohmic
    if param == 'Ohmic Heating per mass':
        parameter = JH_rho
    if param == 'Ohmic Heating per pressure':
        parameter = Ohmic_Press
    if param == 'Convenction Heating':
        parameter = Convenction_heating_Out
    if param == 'Wind Heating':
        parameter = Wind_heating_Out
    if param == 'Energy':
        parameter = Energy_Out
    if param == 'Mechanical Power':
        parameter = Mechanical_power_Out  
        
    if param == 'Pressure_Ohmic ratio':
        parameter = Press_Ohmic
    if param == 'O+':
        parameter = NOpf
    if param == 'O2+':
        parameter = NO2pf
    if param == 'NO+':
        parameter = NNOpf
    if param == 'σNO+n':
        parameter = cross_section_nop
    if param == 'σO2+n':
        parameter = cross_section_o2p
    if param == 'σ':
        parameter = cross_section
    if param == 'vNO+n':
        parameter = vNOpf

    if param == 'Ion Heating Rate':
        parameter = qDTi_nf
        
    if param == 'Ti':
        parameter = Ti_Out
    if param == 'Te':
        parameter = Te_Out
    if param == 'Tn':
        parameter = Tn_Out
    if param == 'νO+n':
        parameter = vOpf
    if param == 'νO2+n':
        parameter = vO2pf
    if param == 'νin':
        parameter = vinf
    if param == 'νen':
        parameter = venf
    if param == 'σO+n':
        parameter = cross_section
    if param == 'Parallel':
        parameter = sigma_par
    if param == 'Pressure':
        parameter = Pressure_2D
        
   
    fig = plt.figure(figsize=(15,7))
    #m.fillcontinents(color='gray',lake_color='gray')
    m = Basemap(projection='spstere',boundinglat=-Bound_lat,lon_0=0,resolution='l', round=True,)
    parameter, lons=addcyclic(parameter,x_value)
    lons, parameter = m.shiftdata(lons, datain = parameter, lon_0=0)
    
    lon, lat = np.meshgrid(lons,y_value)
    x, y = m(lon, lat)
    fig = plt.figure(figsize=(15,7))
    #m.fillcontinents(color='gray',lake_color='gray')
    m.drawcoastlines()
    m.drawparallels(np.arange(-80.,81.,20.))
    m.drawmeridians(np.arange(-180.,181.,20.))
    m.drawmapboundary(fill_color='white')
    
       
    if param == 'Joule Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Frictional Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating per mass':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Ohmic Heating per pressure':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Convenction Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
        
    if param == 'Ion Heating Rate':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
        
    if param == 'Pressure_Ohmic ratio':
        cs = m.contourf(x,y,parameter,60,cmap='gist_ncar')
        plt.colorbar();
    if param == 'O+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'O2+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'NO+':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'σNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'σO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'σ':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
    if param == 'vNO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar();
        
    if param == 'Wind Heating':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Energy':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();
    if param == 'Mechanical Power':
        cs = m.contourf(x,y,parameter,60,cmap='jet')
        plt.colorbar();  
    if param == 'Pedersen':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar();
    if param == 'Hall':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar();
    if param == 'O':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'O2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'N2':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'Ne':
        cs = m.contourf(x,y,parameter,60,cmap='cubehelix')
        plt.colorbar();
    if param == 'Potential':
        cs = m.contourf(x,y,parameter,60,cmap='BrBG')
        plt.colorbar();
        m.contour(x,y,parameter,20,alpha=0.7, colors='k')
    if param == 'Ti':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'Te':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'Tn':
        cs = m.contourf(x,y,parameter,60,cmap='gnuplot')
        plt.colorbar(); 
    if param == 'νO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νO2+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νin':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'νen':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'σO+n':
        cs = m.contourf(x,y,parameter,60,cmap='CMRmap')
        plt.colorbar(); 
    if param == 'Parallel':
        cs = m.contourf(x,y,parameter,60,cmap='afmhot')
        plt.colorbar(); 
    if param == 'Pressure':
        cs = m.contourf(x,y,parameter,60,cmap='RdPu')
        plt.colorbar();     
    
    
    if night_checkbox.value == True:
        CS=m.nightshade(time_plot)
        
        
    if param == 'Joule Heating':
#         plt.title("Joule Heating Rate (mW/m^3)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Joule Heating Rate [$mW/m^{3}$]')
        fig.text(0.35, 0.90, 'Joule Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    
    if param == 'Frictional Heating':
        fig.text(0.35, 0.90, 'Frictional Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Ohmic Heating':
        fig.text(0.35, 0.90, 'Ohmic Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Ohmic Heating per mass':
        fig.text(0.35, 0.90, 'Ohmic Heating per Mass', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/kg$]" , fontsize=17)
    if param == 'Ohmic Heating per pressure':
        fig.text(0.35, 0.90, 'Ohmic Heating per Pressure', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$1/s$]" , fontsize=17)
    if param == 'Convenction Heating':
        fig.text(0.35, 0.90, 'Convenction Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Wind Heating':
        fig.text(0.35, 0.90, 'Wind Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Energy':
        fig.text(0.35, 0.90, 'Energy Dissipation/Generation', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)
    if param == 'Mechanical Power':
        fig.text(0.35, 0.90, 'Mechanical Power Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)   
        
    if param == 'Ion Heating Rate':
        fig.text(0.35, 0.90, 'Ion Heating Rate', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17) 
        
    if param == 'Ti':
        fig.text(0.35, 0.90, 'Ion Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$K$]" , fontsize=17)  
    if param == 'Te':
        fig.text(0.35, 0.90, 'Electron Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$K$]" , fontsize=17)  
    if param == 'Tn':
        fig.text(0.35, 0.90, 'Neutral Temperature', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$mW/m^{3}$]" , fontsize=17)  
    if param == 'νO+n':
        fig.text(0.35, 0.90, 'O+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νO2+n':
        fig.text(0.35, 0.90, 'O2+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νin':
        fig.text(0.35, 0.90, 'Ion-Neutral Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'νen':
        fig.text(0.35, 0.90, 'Electron-Neutral Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σO+n':
        fig.text(0.35, 0.90, 'O+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$m^{2}$]" , fontsize=17)  
    if param == 'Parallel':
        fig.text(0.35, 0.90, 'Pendersen Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)  
    if param == 'Pressure_Ohmic ratio':
        fig.text(0.35, 0.90, 'Pressure/Heaitng ratio', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$s$]" , fontsize=17)
    if param == 'O+':
        fig.text(0.35, 0.90, 'O+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'O2+':
        fig.text(0.35, 0.90, 'O2+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'NO+':
        fig.text(0.35, 0.90, 'NO+ Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$cm^{-3}$]" , fontsize=17)
    if param == 'σNO+n':
        fig.text(0.35, 0.90, 'NO+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σO2+n':
        fig.text(0.35, 0.90, 'O2+ Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'σ':
        fig.text(0.35, 0.90, 'Ion Cross Section', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
    if param == 'vNO+n':
        fig.text(0.35, 0.90, 'NO+ Collision Frequency', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.68, 0.90, "[$Hz$]" , fontsize=17)  
        
    if param == 'Pedersen':
#         plt.title("Pendersen Conductivity ($10^{-5}$ mho/m)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Pendersen Conductivity ($10^{-5}$ mho/m)')
        fig.text(0.35, 0.90, 'Pendersen Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.64, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)
        
    if param == 'Hall':
#         plt.title("Hall Conductivity (Si/m)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('Hall Conductivity (Si/m)')
        fig.text(0.35, 0.90, 'Hall Conductivity', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.64, 0.90, "[$10^{-5} mho/m$]" , fontsize=17)
        
    if param == 'O':
#         plt.title("O ($cm_{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('O ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Atomic Oxygen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'O2':
#         plt.title("$O_{2}$ ($cm^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$O_{2}$ ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Molecular Oxygen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'N2':
#         plt.title("$N_{2}$ ($cm^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$N_{2}$ ($cm^{-3}$)')
        fig.text(0.35, 0.90, 'Molecular Nitrogen', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'Ne':
#         plt.title("Electron Density ($m^{-3}$)_North Pole- %s" % time_plot.strftime("%d %b %Y %H:%M:%S"))
#         cbJH.set_label('$N_{e}$ ($m^{-3}$)')
        fig.text(0.35, 0.90, 'Electron Density', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$m^{-3}$]" , fontsize=17)
        
    if param == 'Potential':
        fig.text(0.35, 0.90, 'Electric Potential', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$kV$]" , fontsize=17)
    if param == 'Pressure':
        fig.text(0.35, 0.90, 'Pressure', fontsize=17, fontweight='bold')
        fig.text(0.35, 0.13, "%s" % time_plot.strftime("%d %b %Y"), fontsize=15)
        fig.text(0.68, 0.13, "%s" % time_plot.strftime("%H:%M:%S"), fontsize=15)
        fig.text(0.70, 0.90, "[$Pa$]" , fontsize=17)        

    
def Exec_Btn_Clicked( b ):
    print( "Calculation started..." )
    run(tiegcm_file.value,lat_value.value,lon_value.value,timer_value.value)
    if heatings_checkbox.value == True:
        print( "Plotting heating rates..." )
        plot_heatings(timer_value.value,lat_value,lon_value)
    if JHrho_checkbox.value == True:
        print( "Plotting Ohmic heating per mass..." )
        plot_JH_rho(timer_value.value)
    if pressure_heating_checkbox.value == True:
        print( "Plotting Pressure/Heating ratio..." )
        plot_press_heat(timer_value.value)
    if pressure_heating_log_checkbox.value == True:
        print( "Plotting Pressure/Heating ratio..." )
        plot_press_heat_log(timer_value.value)
    if JHpress_checkbox.value == True:
        print( "Plotting Ohmic heating per pressure..." )
        plot_JH_press(timer_value.value)
    if press_checkbox.value == True:
        print( "Plotting pressure..." )
        plot_press(timer_value.value)
    if conductivities_checkbox.value == True:
        print( "Plotting conductivities..." )
        plot_conductivities(timer_value.value)
    if frequencies_checkbox.value == True:
        print( "Plotting frequencies..." )
        plot_frequencies(timer_value.value)
    if densities_checkbox.value == True:
        print( "Plotting densities..." )
        plot_densities(timer_value.value)
    if velocities_checkbox.value == True:
        print( "Plotting velocities..." )
        plot_velocities(timer_value.value)
        efield_checkbox
    if efield_checkbox.value == True:
        print( "Plotting electric fields..." )
        plot_efield(timer_value.value)
    if currents_checkbox.value == True:
        print( "Plotting electric currents..." )
        plot_currents(timer_value.value)
    if temperatures_checkbox.value == True:
        print( "Plotting temperatures..." )
        plot_temperatures(timer_value.value)
    if cross_checkbox.value == True:
        print( "Plotting cross sections..." )
        plot_cross_section(timer_value.value)
        
        
        
        
        
def Exec_Map_Clicked( b ):
    print( "Calculation started..." )

    run_map(tiegcm_file.value,timer_value.value,pressure_level.value)
    if Joule_checkbox.value == True:
        print ("Ploting Map...")
        Joule_map(plot_param.value,timer_value.value)    
    if Joule_polar.value == True:
        if North_plot.value == True:
            print ("Plotting Polar Plot (North)")
            Joule_polar_plot(plot_param.value, Bounding_lat.value, orbit_file.value,timer_value.value)
        if South_plot.value == True:
            print ("Plotting Polar Plot (South)")
            Joule_polar_plot_South(plot_param.value,Bounding_lat.value,timer_value.value)
    if Joule_ortho.value == True:
        print ("Plotting Ortho Plot")
        Joule_ortho_plot(plot_param.value,center_lat.value,center_lon.value,timer_value.value)
    if quiver_checkbox.value == True:
        print ("Plotting Quiver Plot")
        quiver_plot(quiver_plot_param.value,quiver_back_param.value, quiver_vec_param.value,timer_value.value)

def Exec_LatAlt_clicked (b):
    lat_alt(tiegcm_file.value,timer_value.value,lon_value.value)
    Lat_Alt_plot(plot_param.value,timer_value.value)
    
    
    
def createGUI():
    ## the top level visual elements
    MainPanel = widgets.VBox() 
    MainTab = widgets.Tab() 
    VerticalPanel = widgets.VBox()
    MapPanel = widgets.VBox()
    LatAltPanel= widgets.VBox()
    
    MainTab.children = [ VerticalPanel,    MapPanel , LatAltPanel]
    MainTab.set_title(0, 'Vertical Profiles')
    MainTab.set_title(1, 'Maps')
    MainTab.set_title(2, 'Latitude-Altitude')
    MainPanel.children = [MainTab ]   
    

    PlotVerticalPanel = widgets.VBox()
    PlotVerticalPanel.children = [lat_value,lon_value,timer_value,widgets.VBox([heatings_checkbox,JHrho_checkbox, JHpress_checkbox,pressure_heating_checkbox,pressure_heating_log_checkbox,conductivities_checkbox,frequencies_checkbox,temperatures_checkbox,
                                 densities_checkbox,velocities_checkbox,efield_checkbox,currents_checkbox,cross_checkbox, press_checkbox])]
    
    QuiverPanel = widgets.HBox()
    QuiverPanel.children =[quiver_checkbox,quiver_plot_param,quiver_back_param,quiver_vec_param]
    
    Exec_Btn = widgets.Button (description='Calculate Products',tooltip="Click here to calculate Daedalus products",)
    Exec_Btn.style.button_color = 'MediumTurquoise'
    Exec_Btn.on_click( Exec_Btn_Clicked )
    VerticalPanel.children = [tiegcm_file, PlotVerticalPanel, Exec_Btn ]
    
    PlotMapPanel = widgets.VBox()
    PlotMapPanel.children = [pressure_level,timer_value, plot_param]
    Map_Btn = widgets.Button (description='Calculate Products',tooltip="Click here to calculate Daedalus products",)
    Map_Btn.style.button_color = 'YellowGreen'
    Map_Btn.on_click( Exec_Map_Clicked )
    MapPanel.children = [ tiegcm_file, PlotMapPanel,Joule_checkbox, widgets.HBox([Joule_polar, North_plot, South_plot, Bounding_lat]), widgets.HBox([Joule_ortho,center_lat,center_lon]),QuiverPanel,widgets.HBox([orbit_checkbox,orbit_file]), night_checkbox, Map_Btn ]
    
    LatAlt=widgets.VBox()
    LatAlt.children =[lon_value,timer_value]

    LatAlt_Btn = widgets.Button (description='Calculate Products',tooltip="Click here to calculate Daedalus products",)
    LatAlt_Btn.style.button_color = 'YellowGreen'
    LatAltPanel.children = [tiegcm_file, LatAlt,plot_param, LatAlt_Btn]
    LatAlt_Btn.on_click( Exec_LatAlt_clicked )

    return MainPanel
display( createGUI() )
# Out:
# VBox(children=(Tab(children=(VBox(children=(Dropdown(description='TIE-GCM files: ', layout=Layout(width='850px…
# Calculation started...
# Calculation executed!
# Total run time: 10.997546672821045 seconds
# Plotting Polar Plot (North)
# Calculation started...
# Calculation executed!
# Total run time: 11.094490051269531 seconds
# Plotting Polar Plot (North)
# Calculation started...
# Calculation executed!
# Total run time: 10.956777334213257 seconds
# Plotting Polar Plot (North)
